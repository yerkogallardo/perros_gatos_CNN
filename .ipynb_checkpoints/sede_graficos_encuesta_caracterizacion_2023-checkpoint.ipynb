# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

from wordcloud import WordCloud, STOPWORDS
from stop_words import get_stop_words
from unidecode import unidecode

#Librerías necesarias para la limpieza de datos
import string
import re
import nltk
nltk.download('stopwords')
nltk.download('punkt')
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer
from nltk.corpus import stopwords

import textwrap
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\yerko.gallardo\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\yerko.gallardo\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
df = pd.read_pickle('df_procesado.pkl')

# %% [markdown]
# ## Un preprocesado para separar carreras y sedes
#
# Añadido 07-07-23
#
# Agregar posteriormente al notebook de procesado

# %%
df.drop(df[df['sede'] == 'No informa'].index, inplace=True)

# %%
df['sede'] = df['sede'].str.replace('División', '').str.strip()

# %%
df['carrera_sede'] = df['plan_estudio_descripcion'] + ' - ' + df['sede']

# %%
##############

# %%
## Diccionario de Definiciones de variables
def_dic = {
    'declaracion_uso_datos': 'Declaro que los datos suministrados son verdaderos y autorizo a la Universidad Mayor a tratar los mismos en los términos de la ley Nº 19.628, con la finalidad de obtener el perfil socioeducativo y...',
    't_desde_egreso': 'Desde que egresaste de la Enseñanza Media, ¿Cuánto tiempo trascurrió para que ingresaras a la Educación Superior?',
    'razon_ingreso_tardio_ed_mayor':"¿Puedes indicarnos a qué factor atribuyes principalmente que tu ingreso a la Educación Superior no fuera antes?",
    'estudia_antes_edsup':'¿Estudiaste en alguna Institución de Educación Superior antes de ingresar a la Universidad Mayor?',
    'finalizo_est_antes_edsup':'Si tu respuesta anterior fue afirmativa, indícanos si finalizaste tus estudios',
    'estado_civil':'¿Cuál es tu estado civil?',
    'tiene_hijos':"¿Tienes hijos/as?",
    'red_apoyo':'Indícanos si cuentas con una red de apoyo para sus cuidados.',
    'quien_red_apoyo':'En caso de contar con una red de apoyo, indícanos cual identificarías como principal.',
    'etnia':"¿A qué etnia o cultura originaria perteneces?",
    'genero_se_identifica':'¿Con cuál género te identificas?',
    'orientacion_sexual':"¿Cuál es tu orientación sexual?",
    'sistema_salud':'¿A qué sistema de salud estás afiliado?',
    'sis_salud_afiliado':'¿A qué sistema de salud estás afiliado?',
    'declara_discapacidad': '¿Deseas declarar algún tipo de discapacidad o condición específica que requiera apoyos, para facilitar tu participación académica?',
    'situacion_discapacidad': 'Declara algún tipo de discapacidad o condición específica que requiera apoyos para facilitar su participación académica.',
    'acreditacion_discapacidad':"En caso de que hayas referido alguna discapacidad, indícanos de qué forma está acreditada.",
    'condicion_dificultad_clases': '¿Deseas declarar alguna enfermedad o condición específica que pueda afectar tu asistencia a clases, el desarrollo de clases online o a distancia, o bien, tu rendimiento académico?',
    'comentario_dificultad':'Declara enfermedad o condición especifica que puede afectar a la asistencia a clases, desarrollo online o a distancio o el rendimiento académico',
    'cuidados_dentro_campus':"Para contextos de clases presenciales. ¿Deseas declarar alguna condición o enfermedad que requiera cuidados dentro del Campus o sala de clases?",
    'comentar_situacion_cuidados_campus':'Declara alguna condición o enfermedad que requiere cuidados dentro del Campus o en la sala de clases.',
    'contacto_emergencia': 'En caso de que se presente una emergencia o accidente que afecte tu salud física y/o mental, ¿Deseas registrar el contacto de alguna persona de referencia para que informemos? De ser así, Indica n...',
    'estudios_familiar': '¿Alguno de los siguientes integrantes de tu familia se tituló de alguna carrera de la Educación Superior ya sea en alguna Universidad, Instituto Profesional o Centro de Formación Técnica?',
    'tramo_registro_social': 'Según el Registro Social de Hogares, ¿Cuál es tu tramo de calificación socioeconómica?',
    'cuantos_convive_2023': 'Incluyéndote ¿Con cuántas personas convivirás durante el año académico 2023?',
    'situacion_laboral_jefe_hogar': '¿Cuál es la situación laboral del/la jefe(a) de tu hogar?',
    'situacion_laboral': "¿Actualmente trabajas?",
    'horas_semanales_laboral': "En caso de que la respuesta anterior sea afirmativa, ¿Cuántas horas semanales dedicas a esta actividad?",
    'dependencia_grupo_familiar': 'Hay algún integrante de tu grupo familiar que dependa de otro para realizar sus actividades cotidianas por condiciones de salud?',
    'dependientes_de_estudiante': '¿Existen personas que dependan de ti?',
    'quien_depende_estudiante': "Indícanos sobre quien depende de ti, a qué tipo de persona(s) corresponde.",
    'horas_cuidado_estudiante': "Respecto al cuidado que otorgas a otro(s), indícanos cuántas horas semanales dedicas a esta actividad.",
    'lugar_estudio_alumno': '¿En qué lugar desarrollarás principalmente tus actividades de estudio?',
    'acceso_medio_digital': 'En lo referente al uso de tecnologías ¿Posees acceso a algún medio digital?',
    'uso_exclusivo_medio_digital': 'Indícanos si el medio tecnológico que posees es de tu uso exclusivo.',
    'acceso_internet_alumno': 'Respecto a la conectividad, ¿Cuentas con acceso a internet en tu hogar o residencia?',
    'factores_dificultad_estudio': 'Al iniciar tu período académico universitario, ¿Crees que alguno de estos factores podría dificultar tu aprendizaje en asignaturas que se dicten de manera online o a distancia?',
    'dificultad_trayecto': '¿Durante tu trayectoria académica has presentado alguna barrera que ha dificultado tu proceso aprendizaje?',
    'situacion_dificultad': 'Comenta que ha presentado alguna barrera que ha dificultado el proceso de aprendizaje',
    'mayores_habilidades': 'Según tu percepción ¿En qué áreas del aprendizaje sientes mayor habilidad en este momento? Puedes seleccionar más de una alternativa',
    'area_aprendizaje_quiere_potenciar': '¿Qué área del aprendizaje quisieras potenciar en tu proceso académico? Puedes seleccionar más de una alternativa',
    'apoyo_pedadogico_requiere': '¿Crees que alguno de estos apoyos pedagógicos pudiera facilitar tu aprendizaje?',
    'requiere_pares_mentores': 'Considerando que la Universidad cuenta con el Programa “Pares Mentores”, el cual tiene como objetivo que un alumno de primer año se adapte a la vida universitaria, creando lazos con un estudiante ...',
    'tiempo_traslado': '¿Cuánto tiempo tardas en trasladarte desde tu lugar de residencia a la Universidad? ',
    'medio_transporte': '¿Qué medio de transporte utilizas para desplazarte a la Universidad?',
    'actividades_de_interes': 'Señala cuál(es) de estas actividades es(son) de tu interés: Puedes seleccionar más de una opción',
    'preferencias_estudio': 'Respecto a tus preferencias, habitualmente:',
    'practica_deporte_hobbie': '¿Prácticas algún deporte o hobby?',
    'indica_deporte_hobbie': 'Deportes o hobbies declarado por los alumnos.',
    'preferencia_act_extracurricular': 'Indícanos cuál de estas actividades sería de tu interés. Puedes seleccionar más de una opción.',
    'genero_identifica_mfo': '¿Con cuál género te identificas?'
}

# %%
## Diccionario de Definiciones y número de pregunta
num_dic = {
    '1': 'Declaro que los datos suministrados son verdaderos y autorizo a la Universidad Mayor a tratar los mismos en los términos de la ley Nº 19.628, con la finalidad de obtener el perfil socioeducativo y...',
    '2': 'Desde que egresaste de la Enseñanza Media, ¿Cuánto tiempo trascurrió para que ingresaras a la Educación Superior?',
    '3':"¿Puedes indicarnos a qué factor atribuyes principalmente que tu ingreso a la Educación Superior no fuera antes?",
    '4':'¿Estudiaste en alguna Institución de Educación Superior antes de ingresar a la Universidad Mayor?',
    '5':'Si tu respuesta anterior fue afirmativa, indícanos si finalizaste tus estudios',
    '6':'¿Cuál es tu estado civil?',
    '7':"¿Tienes hijos/as?",
    '8':'Indícanos si cuentas con una red de apoyo para sus cuidados.',
    '9':'En caso de contar con una red de apoyo, indícanos cual identificarías como principal.',
    '10':"¿A qué etnia o cultura originaria perteneces?",
    '11':'¿Con cuál género te identificas?',
    '12':"¿Cuál es tu orientación sexual?",
    '13':'¿A qué sistema de salud estás afiliado?',
    '13':'¿A qué sistema de salud estás afiliado?',
    '14': '¿Deseas declarar algún tipo de discapacidad o condición específica que requiera apoyos, para facilitar tu participación académica?',
    '15': 'Declara algún tipo de discapacidad o condición específica que requiera apoyos para facilitar su participación académica.',
    '16':"En caso de que hayas referido alguna discapacidad, indícanos de qué forma está acreditada.",
    '17': '¿Deseas declarar alguna enfermedad o condición específica que pueda afectar tu asistencia a clases, el desarrollo de clases online o a distancia, o bien, tu rendimiento académico?',
    '18':'Declara enfermedad o condición especifica que puede afectar a la asistencia a clases, desarrollo online o a distancio o el rendimiento académico',
    '19':"Para contextos de clases presenciales. ¿Deseas declarar alguna condición o enfermedad que requiera cuidados dentro del Campus o sala de clases?",
    '20':'Declara alguna condición o enfermedad que requiere cuidados dentro del Campus o en la sala de clases.',
    '21': 'En caso de que se presente una emergencia o accidente que afecte tu salud física y/o mental, ¿Deseas registrar el contacto de alguna persona de referencia para que informemos? De ser así, Indica n...',
    '22': '¿Alguno de los siguientes integrantes de tu familia se tituló de alguna carrera de la Educación Superior ya sea en alguna Universidad, Instituto Profesional o Centro de Formación Técnica?',
    '23': 'Según el Registro Social de Hogares, ¿Cuál es tu tramo de calificación socioeconómica?',
    '24': 'Incluyéndote ¿Con cuántas personas convivirás durante el año académico 2023?',
    '25': '¿Cuál es la situación laboral del/la jefe(a) de tu hogar?',
    '26': "¿Actualmente trabajas?",
    '27': "En caso de que la respuesta anterior sea afirmativa, ¿Cuántas horas semanales dedicas a esta actividad?",
    '28': 'Hay algún integrante de tu grupo familiar que dependa de otro para realizar sus actividades cotidianas por condiciones de salud?',
    '29': '¿Existen personas que dependan de ti?',
    '30': "Indícanos sobre quien depende de ti, a qué tipo de persona(s) corresponde.",
    '31': "Respecto al cuidado que otorgas a otro(s), indícanos cuántas horas semanales dedicas a esta actividad.",
    '32': '¿En qué lugar desarrollarás principalmente tus actividades de estudio?',
    '33': 'En lo referente al uso de tecnologías ¿Posees acceso a algún medio digital?',
    '34': 'Indícanos si el medio tecnológico que posees es de tu uso exclusivo.',
    '35': 'Respecto a la conectividad, ¿Cuentas con acceso a internet en tu hogar o residencia?',
    '36': 'Al iniciar tu período académico universitario, ¿Crees que alguno de estos factores podría dificultar tu aprendizaje en asignaturas que se dicten de manera online o a distancia?',
    '37': '¿Durante tu trayectoria académica has presentado alguna barrera que ha dificultado tu proceso aprendizaje?',
    '38': 'Comenta que ha presentado alguna barrera que ha dificultado el proceso de aprendizaje',
    '39': 'Según tu percepción ¿En qué áreas del aprendizaje sientes mayor habilidad en este momento? Puedes seleccionar más de una alternativa',
    '40': '¿Qué área del aprendizaje quisieras potenciar en tu proceso académico? Puedes seleccionar más de una alternativa',
    '41': '¿Crees que alguno de estos apoyos pedagógicos pudiera facilitar tu aprendizaje?',
    '42': 'Considerando que la Universidad cuenta con el Programa “Pares Mentores”, el cual tiene como objetivo que un alumno de primer año se adapte a la vida universitaria, creando lazos con un estudiante ...',
    '43': '¿Cuánto tiempo tardas en trasladarte desde tu lugar de residencia a la Universidad? ',
    '44': '¿Qué medio de transporte utilizas para desplazarte a la Universidad?',
    '45': 'Señala cuál(es) de estas actividades es(son) de tu interés: Puedes seleccionar más de una opción',
    '46': 'Respecto a tus preferencias, habitualmente:',
    '47': '¿Prácticas algún deporte o hobby?',
    '48': 'Deportes o hobbies declarado por los alumnos.',
    '49': 'Indícanos cuál de estas actividades sería de tu interés. Puedes seleccionar más de una opción.',
    '11': '¿Con cuál género te identificas?'
}

# %%
## Lista de variables que se realizará Wordcloud
wcloud = ['quien_red_apoyo', 'situacion_discapacidad', 'comentario_dificultad', 'comentar_situacion_cuidados_campus',
          'dependientes_de_estudiante', 'quien_depende_estudiante', 'factores_dificultad_estudio', 'situacion_dificultad',
          'indica_deporte_hobbie', 'genero_se_identifica', 'razon_ingreso_tardio_ed_mayor']

# %%
df[wcloud].fillna('', inplace=True)
# Out:
# C:\Users\yerko.gallardo\AppData\Local\Temp\ipykernel_7552\832272366.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[wcloud].fillna('', inplace=True)

# %%
from nltk.corpus import stopwords
stop_words_esp = set(stopwords.words('spanish'))


import nltk
nltk.download('stopwords')

stop_words_esp = get_stop_words('spanish')
stop_words_esp += ["\u200b", "\xa0", "para", "como", "puede","cómo", "hacer", "forma", "parte", "hace", "además", "según", "pueden", "ser", 'apoyo']
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\yerko.gallardo\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
## Función de procesado de palabras wordcloud
def text_preproc(df, column):
    df['text'] = df[column].fillna('')
    df['text'] = df['text'].str.lower()
    # Remove all punctuations, numbers, and special characters
    df['text'] = df['text'].str.replace('[^\w\s]', '', regex=False)
    # Remove stop words
    #stop_words_esp = set(stopwords.words('spanish'))
    df['text'] = df['text'].apply(lambda x: ' '.join([word for word in word_tokenize(x) if word.lower() not in stop_words_esp]))
    # Tokenize the text data
    df['text'] = df['text'].apply(word_tokenize)
    # Convert words with accents to words without accents
    df['text'] = df['text'].apply(lambda x: [unidecode(word) for word in x])
    # Text with all the words
    words = ' '.join(df['text'].explode().replace(np.nan, '', regex=True))
    return words

# %%
def wrap_labels(ax, width, break_long_words=False):
    labels = []
    for label in ax.get_yticklabels():
        text = label.get_text()
        labels.append(textwrap.fill(text, width=width, break_long_words=break_long_words))
    ax.set_yticklabels(labels)

# %%
# Asignar los valores de la nueva columna genero_identifica_mfo
df['genero_identifica_mfo'] = np.where(df['genero_se_identifica'].isin(['Femenino', 'Masculino']), df['genero_se_identifica'], 'Otro')

# %%
graficar = ['declaracion_uso_datos', 't_desde_egreso', 'estudia_antes_edsup', 'finalizo_est_antes_edsup', 'estado_civil',
            'tiene_hijos', 'red_apoyo', 'etnia', 'declara_discapacidad', 'cuidados_dentro_campus', 'tramo_registro_social',
            'cuantos_convive_2023', 'situacion_laboral', 'horas_semanales_laboral', 'dependencia_grupo_familiar', 
            'horas_cuidado_estudiante', 'acceso_medio_digital', 'uso_exclusivo_medio_digital', 'acceso_internet_alumno',
            'dificultad_trayecto', 'requiere_pares_mentores', 'tiempo_traslado', 'medio_transporte', 'practica_deporte_hobbie', 
            'orientacion_sexual','condicion_dificultad_clases', 'situacion_laboral_jefe_hogar', 'lugar_estudio_alumno', 'genero_identifica_mfo']

# %%
nuevo_df = pd.DataFrame(df, columns=graficar)
# Seleccionar todas las columnas con tipo de dato "object"
columnas_object = nuevo_df.select_dtypes(include=['object']).columns
# Cambiar el tipo de dato de las columnas seleccionadas a "categorical"
nuevo_df[columnas_object] = nuevo_df[columnas_object].astype('category')

# %%
def graficar_mod(df, column):
    # Obtener los valores y sus frecuencias, ordenados de forma descendente
    value_counts = df[column].value_counts().sort_values(ascending=False)
    # Crear un DataFrame ordenado con los valores y sus frecuencias
    data = pd.DataFrame({column: value_counts.index, 'Cantidad de estudiantes': value_counts.values})
    # Crear el gráfico de barras utilizando Seaborn
    fig, ax = plt.subplots(figsize=(8,6))
    ax = sns.barplot(x='Cantidad de estudiantes', y=column, data=data, order=value_counts.index)
    wrap_labels(ax, 60)
    # Configurar el título y las etiquetas de los ejes
    titulo = def_dic[column] if column in def_dic else None
    plt.title('Gráfico de ' + column)
    plt.xlabel('Cantidad de estudiantes')
    plt.ylabel(column)
    ax.set_xlim(right=ax.get_xlim()[1] * 1.1)
    descripcion_recortada = '\n'.join(textwrap.wrap(titulo, width=60))
    plt.text(0.5, -0.20, descripcion_recortada, ha='center', va='center', transform=ax.transAxes)
    # Agregar los valores en las barras
    for p in ax.patches:
        width = p.get_width()
        height = p.get_height()
        x, y = p.get_xy() 
        value = int(width)
        ax.annotate(f'{value}', (x + width, y + height/2), ha='left', va='center')
    nombre_archivo = f"gra_{column}.png" if titulo else "wordcloud.png"
    # Guardar el gráfico en una imagen
    plt.savefig(os.path.join(ruta, nombre_archivo))
    plt.close()

# %% [markdown]
# # Preguntas con respuestas múltiples
#
# Se crea un diccionario con los nombres de las variables que se usarán para construir los gráficos, con estas variables viene el valor de la cantidad de respuestas originales.
#
# La variable pasa por un ciclo for que primero convierte los valores a dummies para poder contar las coincidencias, se tienen en cuenta las respuestas originales y en el conteo las que sobrepasan de este valor se consideran como otros.

# %%
## Esta función cuenta realiza la suma de los valores dummies, los junta en un nuevo dataset y los ordena
def rep_otros(dataset, num): 
    sum_values = dataset.sum().sort_values(ascending=False)
    sorted_dataset = dataset[sum_values.index]
    originales = sorted_dataset.iloc[:, :num]
    columnas_a_contar = sorted_dataset.iloc[:, num:]
    suma_total_coincidencias = columnas_a_contar.sum().sum()
    nueva_fila = pd.DataFrame({'Otros': [suma_total_coincidencias]})
    multi_un = pd.concat([originales, nueva_fila], ignore_index=True).fillna(0)
    sum_values = multi_un.sum().sort_values(ascending=False)
    sorted_dataset = multi_un[sum_values.index]
    multi_sorted = sorted_dataset.copy()
    return multi_sorted

# %%
## Esta función toma lo que entrega la función rep_otros y crea los gráficos de acuerdo a lo ingresado
def gra_multi_resp(multi, op):
    multi_sor = rep_otros(multi, op)
    column = 'preferencia_act_extracurricular'
    fig, ax = plt.subplots(figsize=(8,6))
    sns.barplot(x=multi_sor.sum().values, y=multi_sor.columns, ax=ax, order=multi_sor.sum().sort_values(ascending=False).index)
    plt.yticks(fontsize=8)
    wrap_labels(ax, 40)
    titulo = def_dic[column] if column in def_dic else None
    plt.title('Gráfico de ' + column)
    plt.xlabel('Cantidad de estudiantes')
    plt.ylabel(column)
    ax.set_xlim(right=ax.get_xlim()[1] * 1.1)
    descripcion_recortada = '\n'.join(textwrap.wrap(titulo, width=60))
    plt.text(0.5, -0.20, descripcion_recortada, ha='center', va='center', transform=ax.transAxes)
    # Agregar los valores en las barras
    for p in ax.patches:
        width = p.get_width()
        height = p.get_height()
        x, y = p.get_xy() 
        value = int(width)
        ax.annotate(f'{value}', (x + width, y + height/2), ha='left', va='center')
    nombre_archivo = f"opmulti_{multi}.png" if titulo else "wordcloud.png"
    # Guardar el gráfico en una imagen
    plt.savefig(os.path.join(ruta, nombre_archivo))
    plt.close()

# %%
## Diccionario con las variables a graficar y con la cantidad de respuestas originales
multi_dic = {
    'acreditacion_discapacidad': 5,
    'estudios_familiar': 6,
    'mayores_habilidades': 8,
    'area_aprendizaje_quiere_potenciar': 8,
    'apoyo_pedadogico_requiere': 5,
    'actividades_de_interes': 8,
    'preferencias_estudio': 6,
    'preferencia_act_extracurricular': 4,
}

# %%
carreras = df['carrera_sede'].value_counts()

# %%
directorio_base = "carreras"

# %%
for carr in carreras.index:
    ruta = os.path.join(directorio_base, carr)
    if not os.path.exists(ruta):
        os.makedirs(ruta)
        print(f"Directorio '{ruta}' creado!")
    else:
        print(f"Directorio '{ruta}' ya existe!")
# Out:
# Directorio 'carreras\MEDICINA VETERINARIA - Santiago' creado!
# Directorio 'carreras\PSICOLOGÍA - Santiago' creado!
# Directorio 'carreras\TECNOLOGÍA MÉDICA - Santiago' creado!
# Directorio 'carreras\ADMINISTRACIÓN PÚBLICA  CONT. (ON-LINE) - Santiago' creado!
# Directorio 'carreras\ING. CIVIL INDUSTRIAL  (CONTI.-ONL) - Santiago' creado!
# Directorio 'carreras\ANIMACIÓN DIGITAL - Santiago' creado!
# Directorio 'carreras\ARQUITECTURA - Santiago' creado!
# Directorio 'carreras\KINESIOLOGÍA - Santiago' creado!
# Directorio 'carreras\INGENIERÍA  EN LOGÍSTICA ( CONT. ONLINE) - Santiago' creado!
# Directorio 'carreras\DERECHO - Santiago' creado!
# Directorio 'carreras\ING. PREVENCIÓN EN RIESGOS CON.(ON-LINE) - Santiago' creado!
# Directorio 'carreras\INGENIERÍA COMERCIAL (DIURNO) - Santiago' creado!
# Directorio 'carreras\ENFERMERÍA - Santiago' creado!
# Directorio 'carreras\INGENIERÍA  CIVIL  EN  COMP. E  INF. - Santiago' creado!
# Directorio 'carreras\OBSTETRICIA Y PUERICULTURA - Santiago' creado!
# Directorio 'carreras\ENFERMERÍA - Temuco' creado!
# Directorio 'carreras\INGENIERÍA CIVIL INDUSTRIAL - Santiago' creado!
# Directorio 'carreras\DISEÑO - Santiago' creado!
# Directorio 'carreras\INGENIERÍA INDUSTRIAL (ONL) - Santiago' creado!
# Directorio 'carreras\INGENIERÍA EN ADMINISTRACIÓN (ON-LINE) - Santiago' creado!
# Directorio 'carreras\MEDICINA - Santiago' creado!
# Directorio 'carreras\BACHILLERATO EN CIENCIAS DE LA SALUD - Santiago' creado!
# Directorio 'carreras\ODONTOLOGÍA - Santiago' creado!
# Directorio 'carreras\PSICOLOGÍA - Temuco' creado!
# Directorio 'carreras\TERAPIA OCUPACIONAL - Santiago' creado!
# Directorio 'carreras\PSICOLOGÍA (B) - Santiago' creado!
# Directorio 'carreras\GEOLOGÍA - Santiago' creado!
# Directorio 'carreras\INGENIERÍA EN INFORMÁTICA (ONL) - Santiago' creado!
# Directorio 'carreras\OBSTETRICIA Y PUERICULTURA - Temuco' creado!
# Directorio 'carreras\NUTRICIÓN Y DIETÉTICA - Santiago' creado!
# Directorio 'carreras\ING. EN ADMINISTRACIÓN (CONTIN, ONLINE) - Santiago' creado!
# Directorio 'carreras\DERECHO (V) - Santiago' creado!
# Directorio 'carreras\MEDICINA - Temuco' creado!
# Directorio 'carreras\CINE - Santiago' creado!
# Directorio 'carreras\DERECHO - Temuco' creado!
# Directorio 'carreras\AGRONOMÍA - Santiago' creado!
# Directorio 'carreras\INGENIERÍA EN ADMINISTRACIÓN - Santiago' creado!
# Directorio 'carreras\INGENIERÍA EN CIBERSEGURIDAD (CONT.-ONL) - Santiago' creado!
# Directorio 'carreras\ARQUITECTURA - Temuco' creado!
# Directorio 'carreras\TECNOLOGÍA MÉDICA - Temuco' creado!
# Directorio 'carreras\FONOAUDIOLOGÍA - Santiago' creado!
# Directorio 'carreras\PEDAGOGÍA EN EDUC. FÍSICA, DEP. Y RECR. - Santiago' creado!
# Directorio 'carreras\PEDAG. EN EDUCACIÓN DIFERENCIAL C/DISC. - Santiago' creado!
# Directorio 'carreras\MEDICINA VETERINARIA - Temuco' creado!
# Directorio 'carreras\INGENIERÍA COMERCIAL (ONLINE) - Santiago' creado!
# Directorio 'carreras\INGENIERÍA CIVIL ELECTRÓNICA - Santiago' creado!
# Directorio 'carreras\ANIMACIÓN DIGITAL (T) - Temuco' creado!
# Directorio 'carreras\ING. EN MEDIO AMBIENTE Y SUSTENTABILIDAD - Santiago' creado!
# Directorio 'carreras\PEDAGOGÍA EN  EDUCACIÓN PARVULARIA - Santiago' creado!
# Directorio 'carreras\TERAPIA OCUPACIONAL - Temuco' creado!
# Directorio 'carreras\CONTADOR PÚBLICO Y AUDITOR (CONT.-ONL) - Santiago' creado!
# Directorio 'carreras\FONOAUDIOLOGÍA - Temuco' creado!
# Directorio 'carreras\ADMINISTRACIÓN PÚBLICA (ONLINE) - Santiago' creado!
# Directorio 'carreras\ADMINISTRACIÓN PÚBLICA - Santiago' creado!
# Directorio 'carreras\INGENIERIA COMERCIAL (CONT_ONL) - Santiago' creado!
# Directorio 'carreras\KINESIOLOGÍA - Temuco' creado!
# Directorio 'carreras\TEATRO - Santiago' creado!
# Directorio 'carreras\BIOTECNOLOGÍA - Santiago' creado!
# Directorio 'carreras\INGENIERÍA EN CONSTRUCCIÓN  - Santiago' creado!
# Directorio 'carreras\ODONTOLOGÍA - Temuco' creado!
# Directorio 'carreras\BACHILLERATO EN CIENCIAS DE LA SALUD - Temuco' creado!
# Directorio 'carreras\INGENIERÍA COMERCIAL (DIURNO) - Temuco' creado!
# Directorio 'carreras\NUTRICIÓN Y DIETÉTICA - Temuco' creado!
# Directorio 'carreras\INGENIERÍA FORESTAL - Santiago' creado!
# Directorio 'carreras\TÉC. UNIV. EN CIBERSEGURIDAD - Santiago' creado!
# Directorio 'carreras\PSICOLOGÍA (V) - Santiago' creado!
# Directorio 'carreras\PSICOPEDAGOGÍA (ONL) - Santiago' creado!
# Directorio 'carreras\CONTADOR PÚBLICO Y AUDITOR (ONL) - Santiago' creado!
# Directorio 'carreras\INGENIERÍA EN CONSTRUCCIÓN  - Temuco' creado!
# Directorio 'carreras\PEDAGOGÍA EN ARTES MUSICALES - Santiago' creado!
# Directorio 'carreras\TÉC. UNIV. EN ADMINISTRACIÓN PÚBLICA - Santiago' creado!
# Directorio 'carreras\PEDAGOGÍA EN INGLÉS PARA ED BÁSIC Y MED. - Santiago' creado!
# Directorio 'carreras\INGENIERÍA CIVIL INDUSTRIAL (T) - Temuco' creado!
# Directorio 'carreras\TÉC. UNIV. EN MKT Y GESTION COMERCIAL - Santiago' creado!
# Directorio 'carreras\TÉC. UNIV. EN CONTABILIDAD GENERAL - Santiago' creado!
# Directorio 'carreras\TÉC. UNIV. EN ADMINISTRACIÓN DE EMPRESAS - Santiago' creado!
# Directorio 'carreras\AGRONOMÍA - Temuco' creado!
# Directorio 'carreras\INGENIERÍA COMERCIAL (V) - Santiago' creado!
# Directorio 'carreras\INGENIERÍA EN ADMINISTRACIÓN (V) - Santiago' creado!
# Directorio 'carreras\TURISMO SUSTENTABLE - Temuco' creado!
# Directorio 'carreras\TÉC. UNIV. EN TELC. CONECTIVIDAD Y REDES - Santiago' creado!
# Directorio 'carreras\TÉC. UNIV. EN LOGÍSTICA - Santiago' creado!
# Directorio 'carreras\DATA SCIENCE - Santiago' creado!
# Directorio 'carreras\ADMINISTRACIÓN PÚBLICA (CONTINUIDAD) - Santiago' creado!
# Directorio 'carreras\ING. EN ADMINISTRACIÓN (CONTINUIDAD) - Santiago' creado!
# Directorio 'carreras\PEDAGOGÍA EN EDUCACIÓN DIFERENCIAL C/M - Santiago' creado!
# Directorio 'carreras\INGENIERÍA COMERCIAL (ORIENTE) - Santiago' creado!
# Directorio 'carreras\DERECHO (ORIENTE) - Santiago' creado!
# Directorio 'carreras\INGENIERIA COMERCIAL (CONTINUIDAD) - Santiago' creado!
# Directorio 'carreras\TÉC. UNIV. EN PROGRAMACIÓN COMPUTACIONAL - Santiago' creado!
# Directorio 'carreras\INTERPRETE MUSICAL SUPERIOR EN PIANO - Santiago' creado!
# Directorio 'carreras\PERIODISMO - Santiago' creado!
# Directorio 'carreras\SOCIOLOGÍA  (CONTINUIDAD) - Santiago' creado!
# Directorio 'carreras\INGENIERÍA INDUSTRIAL (V) - Santiago' creado!
# Directorio 'carreras\TÉC. UNIV. EN GESTIÓN DE PERSONAS - Santiago' creado!
# Directorio 'carreras\PSICOPEDAGOGÍA - Santiago' creado!
# Directorio 'carreras\CONTADOR PÚBLICO AUDITOR (CONTINUIDAD) - Santiago' creado!
# Directorio 'carreras\INTERPRETE MUSICAL SUP.  FLAUTA TRAVERSA - Santiago' creado!
# Directorio 'carreras\INGENIERÍA EN ADMINISTRACIÓN (SEMIPR.) - Santiago' creado!
# Directorio 'carreras\INTERPRETACIÓN MUSICAL BÁSICO (6) C/M - Santiago' creado!
# Directorio 'carreras\COMPOSICION MUSICAL SUPERIOR - Santiago' creado!
# Directorio 'carreras\SOCIOLOGÍA (blended) - Santiago' creado!
# Directorio 'carreras\TÉC. UNIV. EN TECNOLOGÍAS DE LA INFORM. - Santiago' creado!
# Directorio 'carreras\INTERPRETACIÓN MUSICAL SUPERIOR C/M. - Santiago' creado!
# Directorio 'carreras\INTERP. MUSICAL SUPERIOR EN CORNO - Santiago' creado!
# Directorio 'carreras\CONSTRUCCIÓN  CIVIL - Santiago' creado!
# Directorio 'carreras\INTERPRETE MUSICAL SUPERIOR EN VIOLÍN - Santiago' creado!
# Directorio 'carreras\INTERPRETE MUSICAL SUPERIOR VIOLONCELLO - Santiago' creado!
# Directorio 'carreras\INTERPRETACIÓN MUSICAL BÁSICO (8) C/M - Santiago' creado!
# Directorio 'carreras\SOCIOLOGÍA (V) - Santiago' creado!

# %%
def text_preproc(df, column):
    df.loc[:, 'text'] = df[column].fillna('')
    df.loc[:, 'text'] = df['text'].str.lower()
    # Remove all punctuations, numbers, and special characters
    df.loc[:, 'text'] = df['text'].str.replace('[^\w\s]', '', regex=False)
    # Remove stop words
    df.loc[:, 'text'] = df['text'].apply(lambda x: ' '.join([word for word in word_tokenize(x) if word.lower() not in stop_words_esp]))
    # Tokenize the text data
    df.loc[:, 'text'] = df['text'].apply(word_tokenize)
    # Convert words with accents to words without accents
    df.loc[:, 'text'] = df['text'].apply(lambda x: [unidecode(word) for word in x])
    # Text with all the words
    words = ' '.join(df['text'].explode().replace(np.nan, '', regex=True))
    
    words_count = len(words.split())
    if words_count == 0:
        print(f"No se encontraron palabras después del preprocesamiento para la columna '{column}'.")
        return None  # Return None if there are no words
    
    print(f"Número de palabras después del preprocesamiento para la columna '{column}': {words_count}")
    return words

# %%
for carr in carreras.index:
    ruta = os.path.join(directorio_base, carr)
    df_carrera = df[df['carrera_sede'] == carr]
    for cloud in wcloud:
        words = text_preproc(df_carrera, cloud)
        
        if words:
            wordcloud = WordCloud(width=800, height=400, background_color='white', stopwords=STOPWORDS, collocations=False).generate(words)
            plt.figure(figsize=(8,6))
            plt.imshow(wordcloud, interpolation='bilinear')
            plt.axis('off')
            
            titulo = def_dic.get(cloud)
            plt.xlim(right=plt.xlim()[1] * 1.1)
            descripcion_recortada = '\n'.join(textwrap.wrap(titulo, width=60))
            plt.text(0.5, -0.20, descripcion_recortada, ha='center', va='center', transform=plt.gca().transAxes)
            
            num_titulo = next((clave for clave, valor in num_dic.items() if valor == titulo), None)
            nombre_archivo = f"{num_titulo}_wordcloud_{cloud}.png" if titulo else "wordcloud.png"
            plt.tight_layout()
            # Guardar el gráfico en una imagen
            plt.savefig(os.path.join(ruta, nombre_archivo))
            plt.close()
            print(f"Gráfico guardado en '{ruta}/{nombre_archivo}'!")
        else:
            print(f"No se encontraron palabras para generar la nube de palabras en la columna '{cloud}'.")
# Out:
# C:\Users\yerko.gallardo\AppData\Local\Temp\ipykernel_7552\554020761.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, 'text'] = df[column].fillna('')
# C:\Users\yerko.gallardo\AppData\Local\Temp\ipykernel_7552\554020761.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, 'text'] = df['text'].str.lower()
# C:\Users\yerko.gallardo\AppData\Local\Temp\ipykernel_7552\554020761.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, 'text'] = df['text'].str.replace('[^\w\s]', '', regex=False)
# C:\Users\yerko.gallardo\AppData\Local\Temp\ipykernel_7552\554020761.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, 'text'] = df['text'].apply(lambda x: ' '.join([word for word in word_tokenize(x) if word.lower() not in stop_words_esp]))
# C:\Users\yerko.gallardo\AppData\Local\Temp\ipykernel_7552\554020761.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, 'text'] = df['text'].apply(word_tokenize)
# C:\Users\yerko.gallardo\AppData\Local\Temp\ipykernel_7552\554020761.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, 'text'] = df['text'].apply(lambda x: [unidecode(word) for word in x])
# Número de palabras después del preprocesamiento para la columna 'quien_red_apoyo': 8
# Gráfico guardado en 'carreras\MEDICINA VETERINARIA - Santiago/9_wordcloud_quien_red_apoyo.png'!
# Número de palabras después del preprocesamiento para la columna 'situacion_discapacidad': 92
# Gráfico guardado en 'carreras\MEDICINA VETERINARIA - Santiago/15_wordcloud_situacion_discapacidad.png'!
# Número de palabras después del preprocesamiento para la columna 'comentario_dificultad': 296
# Gráfico guardado en 'carreras\MEDICINA VETERINARIA - Santiago/18_wordcloud_comentario_dificultad.png'!
# Número de palabras después del preprocesamiento para la columna 'comentar_situacion_cuidados_campus': 145
# Gráfico guardado en 'carreras\MEDICINA VETERINARIA - Santiago/20_wordcloud_comentar_situacion_cuidados_campus.png'!
# Número de palabras después del preprocesamiento para la columna 'dependientes_de_estudiante': 61
# Gráfico guardado en 'carreras\MEDICINA VETERINARIA - Santiago/29_wordcloud_dependientes_de_estudiante.png'!
# Número de palabras después del preprocesamiento para la columna 'quien_depende_estudiante': 71
# Gráfico guardado en 'carreras\MEDICINA VETERINARIA - Santiago/30_wordcloud_quien_depende_estudiante.png'!
# Número de palabras después del preprocesamiento para la columna 'factores_dificultad_estudio': 410
# Gráfico guardado en 'carreras\MEDICINA VETERINARIA - Santiago/36_wordcloud_factores_dificultad_estudio.png'!
# Número de palabras después del preprocesamiento para la columna 'situacion_dificultad': 373
# Gráfico guardado en 'carreras\MEDICINA VETERINARIA - Santiago/38_wordcloud_situacion_dificultad.png'!
# Número de palabras después del preprocesamiento para la columna 'indica_deporte_hobbie': 177
# Gráfico guardado en 'carreras\MEDICINA VETERINARIA - Santiago/48_wordcloud_indica_deporte_hobbie.png'!
# Número de palabras después del preprocesamiento para la columna 'genero_se_identifica': 172
# Gráfico guardado en 'carreras\MEDICINA VETERINARIA - Santiago/11_wordcloud_genero_se_identifica.png'!
# Número de palabras después del preprocesamiento para la columna 'razon_ingreso_tardio_ed_mayor': 321
# Gráfico guardado en 'carreras\MEDICINA VETERINARIA - Santiago/3_wordcloud_razon_ingreso_tardio_ed_mayor.png'!
# Número de palabras después del preprocesamiento para la columna 'quien_red_apoyo': 4
# Gráfico guardado en 'carreras\PSICOLOGÍA - Santiago/9_wordcloud_quien_red_apoyo.png'!
# Número de palabras después del preprocesamiento para la columna 'situacion_discapacidad': 85
# C:\Users\yerko.gallardo\AppData\Local\Temp\ipykernel_7552\554020761.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, 'text'] = df[column].fillna('')
# C:\Users\yerko.gallardo\AppData\Local\Temp\ipykernel_7552\554020761.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, 'text'] = df['text'].str.lower()
# C:\Users\yerko.gallardo\AppData\Local\Temp\ipykernel_7552\554020761.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, 'text'] = df['text'].str.replace('[^\w\s]', '', regex=False)
# C:\Users\yerko.gallardo\AppData\Local\Temp\ipykernel_7552\554020761.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, 'text'] = df['text'].apply(lambda x: ' '.join([word for word in word_tokenize(x) if word.lower() not in stop_words_esp]))
# C:\Users\yerko.gallardo\AppData\Local\Temp\ipykernel_7552\554020761.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, 'text'] = df['text'].apply(word_tokenize)
# C:\Users\yerko.gallardo\AppData\Local\Temp\ipykernel_7552\554020761.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, 'text'] = df['text'].apply(lambda x: [unidecode(word) for word in x])
# Gráfico guardado en 'carreras\PSICOLOGÍA - Santiago/15_wordcloud_situacion_discapacidad.png'!
# Número de palabras después del preprocesamiento para la columna 'comentario_dificultad': 216
# Gráfico guardado en 'carreras\PSICOLOGÍA - Santiago/18_wordcloud_comentario_dificultad.png'!
# Número de palabras después del preprocesamiento para la columna 'comentar_situacion_cuidados_campus': 63
# Gráfico guardado en 'carreras\PSICOLOGÍA - Santiago/20_wordcloud_comentar_situacion_cuidados_campus.png'!
# Número de palabras después del preprocesamiento para la columna 'dependientes_de_estudiante': 38
# Gráfico guardado en 'carreras\PSICOLOGÍA - Santiago/29_wordcloud_dependientes_de_estudiante.png'!
# Número de palabras después del preprocesamiento para la columna 'quien_depende_estudiante': 63
# Gráfico guardado en 'carreras\PSICOLOGÍA - Santiago/30_wordcloud_quien_depende_estudiante.png'!
# Número de palabras después del preprocesamiento para la columna 'factores_dificultad_estudio': 271
# Gráfico guardado en 'carreras\PSICOLOGÍA - Santiago/36_wordcloud_factores_dificultad_estudio.png'!
# Número de palabras después del preprocesamiento para la columna 'situacion_dificultad': 207
# Gráfico guardado en 'carreras\PSICOLOGÍA - Santiago/38_wordcloud_situacion_dificultad.png'!
# Número de palabras después del preprocesamiento para la columna 'indica_deporte_hobbie': 179
# Gráfico guardado en 'carreras\PSICOLOGÍA - Santiago/48_wordcloud_indica_deporte_hobbie.png'!
# Número de palabras después del preprocesamiento para la columna 'genero_se_identifica': 124
# Gráfico guardado en 'carreras\PSICOLOGÍA - Santiago/11_wordcloud_genero_se_identifica.png'!
# Número de palabras después del preprocesamiento para la columna 'razon_ingreso_tardio_ed_mayor': 228
# Gráfico guardado en 'carreras\PSICOLOGÍA - Santiago/3_wordcloud_razon_ingreso_tardio_ed_mayor.png'!
# Número de palabras después del preprocesamiento para la columna 'quien_red_apoyo': 6
# C:\Users\yerko.gallardo\AppData\Local\Temp\ipykernel_7552\554020761.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, 'text'] = df[column].fillna('')
# C:\Users\yerko.gallardo\AppData\Local\Temp\ipykernel_7552\554020761.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, 'text'] = df['text'].str.lower()
# C:\Users\yerko.gallardo\AppData\Local\Temp\ipykernel_7552\554020761.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, 'text'] = df['text'].str.replace('[^\w\s]', '', regex=False)
# C:\Users\yerko.gallardo\AppData\Local\Temp\ipykernel_7552\554020761.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, 'text'] = df['text'].apply(lambda x: ' '.join([word for word in word_tokenize(x) if word.lower() not in stop_words_esp]))
# C:\Users\yerko.gallardo\AppData\Local\Temp\ipykernel_7552\554020761.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, 'text'] = df['text'].apply(word_tokenize)
# C:\Users\yerko.gallardo\AppData\Local\Temp\ipykernel_7552\554020761.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, 'text'] = df['text'].apply(lambda x: [unidecode(word) for word in x])
# Gráfico guardado en 'carreras\TECNOLOGÍA MÉDICA - Santiago/9_wordcloud_quien_red_apoyo.png'!
# Número de palabras después del preprocesamiento para la columna 'situacion_discapacidad': 36
# Gráfico guardado en 'carreras\TECNOLOGÍA MÉDICA - Santiago/15_wordcloud_situacion_discapacidad.png'!
# Número de palabras después del preprocesamiento para la columna 'comentario_dificultad': 238
# Gráfico guardado en 'carreras\TECNOLOGÍA MÉDICA - Santiago/18_wordcloud_comentario_dificultad.png'!
# Número de palabras después del preprocesamiento para la columna 'comentar_situacion_cuidados_campus': 9
# Gráfico guardado en 'carreras\TECNOLOGÍA MÉDICA - Santiago/20_wordcloud_comentar_situacion_cuidados_campus.png'!
# Número de palabras después del preprocesamiento para la columna 'dependientes_de_estudiante': 47
# Gráfico guardado en 'carreras\TECNOLOGÍA MÉDICA - Santiago/29_wordcloud_dependientes_de_estudiante.png'!
# Número de palabras después del preprocesamiento para la columna 'quien_depende_estudiante': 61
# Gráfico guardado en 'carreras\TECNOLOGÍA MÉDICA - Santiago/30_wordcloud_quien_depende_estudiante.png'!
# Número de palabras después del preprocesamiento para la columna 'factores_dificultad_estudio': 246
# Gráfico guardado en 'carreras\TECNOLOGÍA MÉDICA - Santiago/36_wordcloud_factores_dificultad_estudio.png'!
# Número de palabras después del preprocesamiento para la columna 'situacion_dificultad': 227
# Gráfico guardado en 'carreras\TECNOLOGÍA MÉDICA - Santiago/38_wordcloud_situacion_dificultad.png'!
# Número de palabras después del preprocesamiento para la columna 'indica_deporte_hobbie': 139
# Gráfico guardado en 'carreras\TECNOLOGÍA MÉDICA - Santiago/48_wordcloud_indica_deporte_hobbie.png'!
# Número de palabras después del preprocesamiento para la columna 'genero_se_identifica': 107
# Gráfico guardado en 'carreras\TECNOLOGÍA MÉDICA - Santiago/11_wordcloud_genero_se_identifica.png'!
# Número de palabras después del preprocesamiento para la columna 'razon_ingreso_tardio_ed_mayor': 230
# Gráfico guardado en 'carreras\TECNOLOGÍA MÉDICA - Santiago/3_wordcloud_razon_ingreso_tardio_ed_mayor.png'!
# Número de palabras después del preprocesamiento para la columna 'quien_red_apoyo': 116
# C:\Users\yerko.gallardo\AppData\Local\Temp\ipykernel_7552\554020761.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, 'text'] = df[column].fillna('')
# C:\Users\yerko.gallardo\AppData\Local\Temp\ipykernel_7552\554020761.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, 'text'] = df['text'].str.lower()
# C:\Users\yerko.gallardo\AppData\Local\Temp\ipykernel_7552\554020761.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, 'text'] = df['text'].str.replace('[^\w\s]', '', regex=False)
# C:\Users\yerko.gallardo\AppData\Local\Temp\ipykernel_7552\554020761.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, 'text'] = df['text'].apply(lambda x: ' '.join([word for word in word_tokenize(x) if word.lower() not in stop_words_esp]))
# C:\Users\yerko.gallardo\AppData\Local\Temp\ipykernel_7552\554020761.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, 'text'] = df['text'].apply(word_tokenize)
# C:\Users\yerko.gallardo\AppData\Local\Temp\ipykernel_7552\554020761.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, 'text'] = df['text'].apply(lambda x: [unidecode(word) for word in x])
# Gráfico guardado en 'carreras\ADMINISTRACIÓN PÚBLICA  CONT. (ON-LINE) - Santiago/9_wordcloud_quien_red_apoyo.png'!
# Número de palabras después del preprocesamiento para la columna 'situacion_discapacidad': 36
# Gráfico guardado en 'carreras\ADMINISTRACIÓN PÚBLICA  CONT. (ON-LINE) - Santiago/15_wordcloud_situacion_discapacidad.png'!
# Número de palabras después del preprocesamiento para la columna 'comentario_dificultad': 74
# Gráfico guardado en 'carreras\ADMINISTRACIÓN PÚBLICA  CONT. (ON-LINE) - Santiago/18_wordcloud_comentario_dificultad.png'!
# No se encontraron palabras después del preprocesamiento para la columna 'comentar_situacion_cuidados_campus'.
# No se encontraron palabras para generar la nube de palabras en la columna 'comentar_situacion_cuidados_campus'.
# Número de palabras después del preprocesamiento para la columna 'dependientes_de_estudiante': 165
# Gráfico guardado en 'carreras\ADMINISTRACIÓN PÚBLICA  CONT. (ON-LINE) - Santiago/29_wordcloud_dependientes_de_estudiante.png'!
# Número de palabras después del preprocesamiento para la columna 'quien_depende_estudiante': 523
# Gráfico guardado en 'carreras\ADMINISTRACIÓN PÚBLICA  CONT. (ON-LINE) - Santiago/30_wordcloud_quien_depende_estudiante.png'!
# Número de palabras después del preprocesamiento para la columna 'factores_dificultad_estudio': 249
# Gráfico guardado en 'carreras\ADMINISTRACIÓN PÚBLICA  CONT. (ON-LINE) - Santiago/36_wordcloud_factores_dificultad_estudio.png'!
# Número de palabras después del preprocesamiento para la columna 'situacion_dificultad': 352
# Gráfico guardado en 'carreras\ADMINISTRACIÓN PÚBLICA  CONT. (ON-LINE) - Santiago/38_wordcloud_situacion_dificultad.png'!
# Número de palabras después del preprocesamiento para la columna 'indica_deporte_hobbie': 73
# Gráfico guardado en 'carreras\ADMINISTRACIÓN PÚBLICA  CONT. (ON-LINE) - Santiago/48_wordcloud_indica_deporte_hobbie.png'!
# Número de palabras después del preprocesamiento para la columna 'genero_se_identifica': 102
# Gráfico guardado en 'carreras\ADMINISTRACIÓN PÚBLICA  CONT. (ON-LINE) - Santiago/11_wordcloud_genero_se_identifica.png'!
# Número de palabras después del preprocesamiento para la columna 'razon_ingreso_tardio_ed_mayor': 236
# Gráfico guardado en 'carreras\ADMINISTRACIÓN PÚBLICA  CONT. (ON-LINE) - Santiago/3_wordcloud_razon_ingreso_tardio_ed_mayor.png'!
# Número de palabras después del preprocesamiento para la columna 'quien_red_apoyo': 80
# C:\Users\yerko.gallardo\AppData\Local\Temp\ipykernel_7552\554020761.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, 'text'] = df[column].fillna('')
# C:\Users\yerko.gallardo\AppData\Local\Temp\ipykernel_7552\554020761.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, 'text'] = df['text'].str.lower()
# C:\Users\yerko.gallardo\AppData\Local\Temp\ipykernel_7552\554020761.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, 'text'] = df['text'].str.replace('[^\w\s]', '', regex=False)
# C:\Users\yerko.gallardo\AppData\Local\Temp\ipykernel_7552\554020761.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, 'text'] = df['text'].apply(lambda x: ' '.join([word for word in word_tokenize(x) if word.lower() not in stop_words_esp]))
# C:\Users\yerko.gallardo\AppData\Local\Temp\ipykernel_7552\554020761.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, 'text'] = df['text'].apply(word_tokenize)
# C:\Users\yerko.gallardo\AppData\Local\Temp\ipykernel_7552\554020761.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, 'text'] = df['text'].apply(lambda x: [unidecode(word) for word in x])
# Gráfico guardado en 'carreras\ING. CIVIL INDUSTRIAL  (CONTI.-ONL) - Santiago/9_wordcloud_quien_red_apoyo.png'!
# Número de palabras después del preprocesamiento para la columna 'situacion_discapacidad': 3
# Gráfico guardado en 'carreras\ING. CIVIL INDUSTRIAL  (CONTI.-ONL) - Santiago/15_wordcloud_situacion_discapacidad.png'!
# Número de palabras después del preprocesamiento para la columna 'comentario_dificultad': 85
# Gráfico guardado en 'carreras\ING. CIVIL INDUSTRIAL  (CONTI.-ONL) - Santiago/18_wordcloud_comentario_dificultad.png'!
# No se encontraron palabras después del preprocesamiento para la columna 'comentar_situacion_cuidados_campus'.
# No se encontraron palabras para generar la nube de palabras en la columna 'comentar_situacion_cuidados_campus'.
# Número de palabras después del preprocesamiento para la columna 'dependientes_de_estudiante': 130
# Gráfico guardado en 'carreras\ING. CIVIL INDUSTRIAL  (CONTI.-ONL) - Santiago/29_wordcloud_dependientes_de_estudiante.png'!
# Número de palabras después del preprocesamiento para la columna 'quien_depende_estudiante': 464
# Gráfico guardado en 'carreras\ING. CIVIL INDUSTRIAL  (CONTI.-ONL) - Santiago/30_wordcloud_quien_depende_estudiante.png'!
# Número de palabras después del preprocesamiento para la columna 'factores_dificultad_estudio': 207
# Gráfico guardado en 'carreras\ING. CIVIL INDUSTRIAL  (CONTI.-ONL) - Santiago/36_wordcloud_factores_dificultad_estudio.png'!
# Número de palabras después del preprocesamiento para la columna 'situacion_dificultad': 79
# Gráfico guardado en 'carreras\ING. CIVIL INDUSTRIAL  (CONTI.-ONL) - Santiago/38_wordcloud_situacion_dificultad.png'!
# Número de palabras después del preprocesamiento para la columna 'indica_deporte_hobbie': 155
# Gráfico guardado en 'carreras\ING. CIVIL INDUSTRIAL  (CONTI.-ONL) - Santiago/48_wordcloud_indica_deporte_hobbie.png'!
# Número de palabras después del preprocesamiento para la columna 'genero_se_identifica': 96
# Gráfico guardado en 'carreras\ING. CIVIL INDUSTRIAL  (CONTI.-ONL) - Santiago/11_wordcloud_genero_se_identifica.png'!
# Número de palabras después del preprocesamiento para la columna 'razon_ingreso_tardio_ed_mayor': 280
# Gráfico guardado en 'carreras\ING. CIVIL INDUSTRIAL  (CONTI.-ONL) - Santiago/3_wordcloud_razon_ingreso_tardio_ed_mayor.png'!
# No se encontraron palabras después del preprocesamiento para la columna 'quien_red_apoyo'.
# No se encontraron palabras para generar la nube de palabras en la columna 'quien_red_apoyo'.
# Número de palabras después del preprocesamiento para la columna 'situacion_discapacidad': 61
# C:\Users\yerko.gallardo\AppData\Local\Temp\ipykernel_7552\554020761.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, 'text'] = df[column].fillna('')
# C:\Users\yerko.gallardo\AppData\Local\Temp\ipykernel_7552\554020761.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, 'text'] = df['text'].str.lower()
# C:\Users\yerko.gallardo\AppData\Local\Temp\ipykernel_7552\554020761.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, 'text'] = df['text'].str.replace('[^\w\s]', '', regex=False)
# C:\Users\yerko.gallardo\AppData\Local\Temp\ipykernel_7552\554020761.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, 'text'] = df['text'].apply(lambda x: ' '.join([word for word in word_tokenize(x) if word.lower() not in stop_words_esp]))
# C:\Users\yerko.gallardo\AppData\Local\Temp\ipykernel_7552\554020761.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, 'text'] = df['text'].apply(word_tokenize)
# C:\Users\yerko.gallardo\AppData\Local\Temp\ipykernel_7552\554020761.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, 'text'] = df['text'].apply(lambda x: [unidecode(word) for word in x])
# Gráfico guardado en 'carreras\ANIMACIÓN DIGITAL - Santiago/15_wordcloud_situacion_discapacidad.png'!
# Número de palabras después del preprocesamiento para la columna 'comentario_dificultad': 188
# Gráfico guardado en 'carreras\ANIMACIÓN DIGITAL - Santiago/18_wordcloud_comentario_dificultad.png'!
# Número de palabras después del preprocesamiento para la columna 'comentar_situacion_cuidados_campus': 14
# Gráfico guardado en 'carreras\ANIMACIÓN DIGITAL - Santiago/20_wordcloud_comentar_situacion_cuidados_campus.png'!
# Número de palabras después del preprocesamiento para la columna 'dependientes_de_estudiante': 32
# Gráfico guardado en 'carreras\ANIMACIÓN DIGITAL - Santiago/29_wordcloud_dependientes_de_estudiante.png'!
# Número de palabras después del preprocesamiento para la columna 'quien_depende_estudiante': 40
# Gráfico guardado en 'carreras\ANIMACIÓN DIGITAL - Santiago/30_wordcloud_quien_depende_estudiante.png'!
# Número de palabras después del preprocesamiento para la columna 'factores_dificultad_estudio': 231
# Gráfico guardado en 'carreras\ANIMACIÓN DIGITAL - Santiago/36_wordcloud_factores_dificultad_estudio.png'!
# Número de palabras después del preprocesamiento para la columna 'situacion_dificultad': 186
# Gráfico guardado en 'carreras\ANIMACIÓN DIGITAL - Santiago/38_wordcloud_situacion_dificultad.png'!
# Número de palabras después del preprocesamiento para la columna 'indica_deporte_hobbie': 274
# Gráfico guardado en 'carreras\ANIMACIÓN DIGITAL - Santiago/48_wordcloud_indica_deporte_hobbie.png'!
# Número de palabras después del preprocesamiento para la columna 'genero_se_identifica': 131
# Gráfico guardado en 'carreras\ANIMACIÓN DIGITAL - Santiago/11_wordcloud_genero_se_identifica.png'!
# Número de palabras después del preprocesamiento para la columna 'razon_ingreso_tardio_ed_mayor': 171
# Gráfico guardado en 'carreras\ANIMACIÓN DIGITAL - Santiago/3_wordcloud_razon_ingreso_tardio_ed_mayor.png'!
# Número de palabras después del preprocesamiento para la columna 'quien_red_apoyo': 1
# Gráfico guardado en 'carreras\ARQUITECTURA - Santiago/9_wordcloud_quien_red_apoyo.png'!
# Número de palabras después del preprocesamiento para la columna 'situacion_discapacidad': 58
# C:\Users\yerko.gallardo\AppData\Local\Temp\ipykernel_7552\554020761.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, 'text'] = df[column].fillna('')
# C:\Users\yerko.gallardo\AppData\Local\Temp\ipykernel_7552\554020761.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, 'text'] = df['text'].str.lower()
# C:\Users\yerko.gallardo\AppData\Local\Temp\ipykernel_7552\554020761.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, 'text'] = df['text'].str.replace('[^\w\s]', '', regex=False)
# C:\Users\yerko.gallardo\AppData\Local\Temp\ipykernel_7552\554020761.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, 'text'] = df['text'].apply(lambda x: ' '.join([word for word in word_tokenize(x) if word.lower() not in stop_words_esp]))
# C:\Users\yerko.gallardo\AppData\Local\Temp\ipykernel_7552\554020761.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, 'text'] = df['text'].apply(word_tokenize)
# C:\Users\yerko.gallardo\AppData\Local\Temp\ipykernel_7552\554020761.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, 'text'] = df['text'].apply(lambda x: [unidecode(word) for word in x])
# Gráfico guardado en 'carreras\ARQUITECTURA - Santiago/15_wordcloud_situacion_discapacidad.png'!
# Número de palabras después del preprocesamiento para la columna 'comentario_dificultad': 132
# Gráfico guardado en 'carreras\ARQUITECTURA - Santiago/18_wordcloud_comentario_dificultad.png'!
# Número de palabras después del preprocesamiento para la columna 'comentar_situacion_cuidados_campus': 17
# Gráfico guardado en 'carreras\ARQUITECTURA - Santiago/20_wordcloud_comentar_situacion_cuidados_campus.png'!
# Número de palabras después del preprocesamiento para la columna 'dependientes_de_estudiante': 22
# Gráfico guardado en 'carreras\ARQUITECTURA - Santiago/29_wordcloud_dependientes_de_estudiante.png'!
# Número de palabras después del preprocesamiento para la columna 'quien_depende_estudiante': 32
# Gráfico guardado en 'carreras\ARQUITECTURA - Santiago/30_wordcloud_quien_depende_estudiante.png'!
# Número de palabras después del preprocesamiento para la columna 'factores_dificultad_estudio': 235
# Gráfico guardado en 'carreras\ARQUITECTURA - Santiago/36_wordcloud_factores_dificultad_estudio.png'!
# Número de palabras después del preprocesamiento para la columna 'situacion_dificultad': 166
# Gráfico guardado en 'carreras\ARQUITECTURA - Santiago/38_wordcloud_situacion_dificultad.png'!
# Número de palabras después del preprocesamiento para la columna 'indica_deporte_hobbie': 173
# Gráfico guardado en 'carreras\ARQUITECTURA - Santiago/48_wordcloud_indica_deporte_hobbie.png'!
# Número de palabras después del preprocesamiento para la columna 'genero_se_identifica': 87
# Gráfico guardado en 'carreras\ARQUITECTURA - Santiago/11_wordcloud_genero_se_identifica.png'!
# Número de palabras después del preprocesamiento para la columna 'razon_ingreso_tardio_ed_mayor': 135
# Gráfico guardado en 'carreras\ARQUITECTURA - Santiago/3_wordcloud_razon_ingreso_tardio_ed_mayor.png'!
# Número de palabras después del preprocesamiento para la columna 'quien_red_apoyo': 10
# Gráfico guardado en 'carreras\KINESIOLOGÍA - Santiago/9_wordcloud_quien_red_apoyo.png'!
# Número de palabras después del preprocesamiento para la columna 'situacion_discapacidad': 9
# C:\Users\yerko.gallardo\AppData\Local\Temp\ipykernel_7552\554020761.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, 'text'] = df[column].fillna('')
# C:\Users\yerko.gallardo\AppData\Local\Temp\ipykernel_7552\554020761.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, 'text'] = df['text'].str.lower()
# C:\Users\yerko.gallardo\AppData\Local\Temp\ipykernel_7552\554020761.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, 'text'] = df['text'].str.replace('[^\w\s]', '', regex=False)
# C:\Users\yerko.gallardo\AppData\Local\Temp\ipykernel_7552\554020761.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, 'text'] = df['text'].apply(lambda x: ' '.join([word for word in word_tokenize(x) if word.lower() not in stop_words_esp]))
# C:\Users\yerko.gallardo\AppData\Local\Temp\ipykernel_7552\554020761.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, 'text'] = df['text'].apply(word_tokenize)
# C:\Users\yerko.gallardo\AppData\Local\Temp\ipykernel_7552\554020761.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, 'text'] = df['text'].apply(lambda x: [unidecode(word) for word in x])
# Gráfico guardado en 'carreras\KINESIOLOGÍA - Santiago/15_wordcloud_situacion_discapacidad.png'!
# Número de palabras después del preprocesamiento para la columna 'comentario_dificultad': 38
# Gráfico guardado en 'carreras\KINESIOLOGÍA - Santiago/18_wordcloud_comentario_dificultad.png'!
# Número de palabras después del preprocesamiento para la columna 'comentar_situacion_cuidados_campus': 24
# Gráfico guardado en 'carreras\KINESIOLOGÍA - Santiago/20_wordcloud_comentar_situacion_cuidados_campus.png'!
# Número de palabras después del preprocesamiento para la columna 'dependientes_de_estudiante': 38
# Gráfico guardado en 'carreras\KINESIOLOGÍA - Santiago/29_wordcloud_dependientes_de_estudiante.png'!
# Número de palabras después del preprocesamiento para la columna 'quien_depende_estudiante': 57
# Gráfico guardado en 'carreras\KINESIOLOGÍA - Santiago/30_wordcloud_quien_depende_estudiante.png'!
# Número de palabras después del preprocesamiento para la columna 'factores_dificultad_estudio': 192
# Gráfico guardado en 'carreras\KINESIOLOGÍA - Santiago/36_wordcloud_factores_dificultad_estudio.png'!
# Número de palabras después del preprocesamiento para la columna 'situacion_dificultad': 126
# Gráfico guardado en 'carreras\KINESIOLOGÍA - Santiago/38_wordcloud_situacion_dificultad.png'!
# Número de palabras después del preprocesamiento para la columna 'indica_deporte_hobbie': 122
# Gráfico guardado en 'carreras\KINESIOLOGÍA - Santiago/48_wordcloud_indica_deporte_hobbie.png'!
# Número de palabras después del preprocesamiento para la columna 'genero_se_identifica': 81
# Gráfico guardado en 'carreras\KINESIOLOGÍA - Santiago/11_wordcloud_genero_se_identifica.png'!
# Número de palabras después del preprocesamiento para la columna 'razon_ingreso_tardio_ed_mayor': 166
# Gráfico guardado en 'carreras\KINESIOLOGÍA - Santiago/3_wordcloud_razon_ingreso_tardio_ed_mayor.png'!
# Número de palabras después del preprocesamiento para la columna 'quien_red_apoyo': 88
# Gráfico guardado en 'carreras\INGENIERÍA  EN LOGÍSTICA ( CONT. ONLINE) - Santiago/9_wordcloud_quien_red_apoyo.png'!
# Número de palabras después del preprocesamiento para la columna 'situacion_discapacidad': 4
# C:\Users\yerko.gallardo\AppData\Local\Temp\ipykernel_7552\554020761.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, 'text'] = df[column].fillna('')
# C:\Users\yerko.gallardo\AppData\Local\Temp\ipykernel_7552\554020761.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, 'text'] = df['text'].str.lower()
# C:\Users\yerko.gallardo\AppData\Local\Temp\ipykernel_7552\554020761.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, 'text'] = df['text'].str.replace('[^\w\s]', '', regex=False)
# C:\Users\yerko.gallardo\AppData\Local\Temp\ipykernel_7552\554020761.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, 'text'] = df['text'].apply(lambda x: ' '.join([word for word in word_tokenize(x) if word.lower() not in stop_words_esp]))
# C:\Users\yerko.gallardo\AppData\Local\Temp\ipykernel_7552\554020761.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, 'text'] = df['text'].apply(word_tokenize)
# C:\Users\yerko.gallardo\AppData\Local\Temp\ipykernel_7552\554020761.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, 'text'] = df['text'].apply(lambda x: [unidecode(word) for word in x])
# Gráfico guardado en 'carreras\INGENIERÍA  EN LOGÍSTICA ( CONT. ONLINE) - Santiago/15_wordcloud_situacion_discapacidad.png'!
# Número de palabras después del preprocesamiento para la columna 'comentario_dificultad': 64
# Gráfico guardado en 'carreras\INGENIERÍA  EN LOGÍSTICA ( CONT. ONLINE) - Santiago/18_wordcloud_comentario_dificultad.png'!
# No se encontraron palabras después del preprocesamiento para la columna 'comentar_situacion_cuidados_campus'.
# No se encontraron palabras para generar la nube de palabras en la columna 'comentar_situacion_cuidados_campus'.
# Número de palabras después del preprocesamiento para la columna 'dependientes_de_estudiante': 106
# Gráfico guardado en 'carreras\INGENIERÍA  EN LOGÍSTICA ( CONT. ONLINE) - Santiago/29_wordcloud_dependientes_de_estudiante.png'!
# Número de palabras después del preprocesamiento para la columna 'quien_depende_estudiante': 474
# Gráfico guardado en 'carreras\INGENIERÍA  EN LOGÍSTICA ( CONT. ONLINE) - Santiago/30_wordcloud_quien_depende_estudiante.png'!
# Número de palabras después del preprocesamiento para la columna 'factores_dificultad_estudio': 151
# Gráfico guardado en 'carreras\INGENIERÍA  EN LOGÍSTICA ( CONT. ONLINE) - Santiago/36_wordcloud_factores_dificultad_estudio.png'!
# Número de palabras después del preprocesamiento para la columna 'situacion_dificultad': 54
# Gráfico guardado en 'carreras\INGENIERÍA  EN LOGÍSTICA ( CONT. ONLINE) - Santiago/38_wordcloud_situacion_dificultad.png'!
# Número de palabras después del preprocesamiento para la columna 'indica_deporte_hobbie': 136
# Gráfico guardado en 'carreras\INGENIERÍA  EN LOGÍSTICA ( CONT. ONLINE) - Santiago/48_wordcloud_indica_deporte_hobbie.png'!
# Número de palabras después del preprocesamiento para la columna 'genero_se_identifica': 75
# Gráfico guardado en 'carreras\INGENIERÍA  EN LOGÍSTICA ( CONT. ONLINE) - Santiago/11_wordcloud_genero_se_identifica.png'!
# Número de palabras después del preprocesamiento para la columna 'razon_ingreso_tardio_ed_mayor': 196
# Gráfico guardado en 'carreras\INGENIERÍA  EN LOGÍSTICA ( CONT. ONLINE) - Santiago/3_wordcloud_razon_ingreso_tardio_ed_mayor.png'!
# Número de palabras después del preprocesamiento para la columna 'quien_red_apoyo': 36
# C:\Users\yerko.gallardo\AppData\Local\Temp\ipykernel_7552\554020761.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, 'text'] = df[column].fillna('')
# C:\Users\yerko.gallardo\AppData\Local\Temp\ipykernel_7552\554020761.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, 'text'] = df['text'].str.lower()
# C:\Users\yerko.gallardo\AppData\Local\Temp\ipykernel_7552\554020761.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, 'text'] = df['text'].str.replace('[^\w\s]', '', regex=False)
# C:\Users\yerko.gallardo\AppData\Local\Temp\ipykernel_7552\554020761.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, 'text'] = df['text'].apply(lambda x: ' '.join([word for word in word_tokenize(x) if word.lower() not in stop_words_esp]))
# C:\Users\yerko.gallardo\AppData\Local\Temp\ipykernel_7552\554020761.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, 'text'] = df['text'].apply(word_tokenize)
# C:\Users\yerko.gallardo\AppData\Local\Temp\ipykernel_7552\554020761.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, 'text'] = df['text'].apply(lambda x: [unidecode(word) for word in x])
# Gráfico guardado en 'carreras\DERECHO - Santiago/9_wordcloud_quien_red_apoyo.png'!
# Número de palabras después del preprocesamiento para la columna 'situacion_discapacidad': 15
# Gráfico guardado en 'carreras\DERECHO - Santiago/15_wordcloud_situacion_discapacidad.png'!
# Número de palabras después del preprocesamiento para la columna 'comentario_dificultad': 106
# Gráfico guardado en 'carreras\DERECHO - Santiago/18_wordcloud_comentario_dificultad.png'!
# Número de palabras después del preprocesamiento para la columna 'comentar_situacion_cuidados_campus': 17
# Gráfico guardado en 'carreras\DERECHO - Santiago/20_wordcloud_comentar_situacion_cuidados_campus.png'!
# Número de palabras después del preprocesamiento para la columna 'dependientes_de_estudiante': 43
# Gráfico guardado en 'carreras\DERECHO - Santiago/29_wordcloud_dependientes_de_estudiante.png'!
# Número de palabras después del preprocesamiento para la columna 'quien_depende_estudiante': 83
# Gráfico guardado en 'carreras\DERECHO - Santiago/30_wordcloud_quien_depende_estudiante.png'!
# Número de palabras después del preprocesamiento para la columna 'factores_dificultad_estudio': 145
# Gráfico guardado en 'carreras\DERECHO - Santiago/36_wordcloud_factores_dificultad_estudio.png'!
# Número de palabras después del preprocesamiento para la columna 'situacion_dificultad': 131
# Gráfico guardado en 'carreras\DERECHO - Santiago/38_wordcloud_situacion_dificultad.png'!
# Número de palabras después del preprocesamiento para la columna 'indica_deporte_hobbie': 70
# Gráfico guardado en 'carreras\DERECHO - Santiago/48_wordcloud_indica_deporte_hobbie.png'!
# Número de palabras después del preprocesamiento para la columna 'genero_se_identifica': 70
# Gráfico guardado en 'carreras\DERECHO - Santiago/11_wordcloud_genero_se_identifica.png'!
# ...
#   df.loc[:, 'text'] = df['text'].apply(word_tokenize)
# C:\Users\yerko.gallardo\AppData\Local\Temp\ipykernel_7552\554020761.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, 'text'] = df['text'].apply(lambda x: [unidecode(word) for word in x])
# Gráfico guardado en 'carreras\INTERPRETE MUSICAL SUPERIOR EN VIOLÍN - Santiago/36_wordcloud_factores_dificultad_estudio.png'!
# No se encontraron palabras después del preprocesamiento para la columna 'situacion_dificultad'.
# No se encontraron palabras para generar la nube de palabras en la columna 'situacion_dificultad'.
# No se encontraron palabras después del preprocesamiento para la columna 'indica_deporte_hobbie'.
# No se encontraron palabras para generar la nube de palabras en la columna 'indica_deporte_hobbie'.
# Número de palabras después del preprocesamiento para la columna 'genero_se_identifica': 1
# Gráfico guardado en 'carreras\INTERPRETE MUSICAL SUPERIOR EN VIOLÍN - Santiago/11_wordcloud_genero_se_identifica.png'!
# Número de palabras después del preprocesamiento para la columna 'razon_ingreso_tardio_ed_mayor': 2
# Gráfico guardado en 'carreras\INTERPRETE MUSICAL SUPERIOR EN VIOLÍN - Santiago/3_wordcloud_razon_ingreso_tardio_ed_mayor.png'!
# No se encontraron palabras después del preprocesamiento para la columna 'quien_red_apoyo'.
# No se encontraron palabras para generar la nube de palabras en la columna 'quien_red_apoyo'.
# No se encontraron palabras después del preprocesamiento para la columna 'situacion_discapacidad'.
# No se encontraron palabras para generar la nube de palabras en la columna 'situacion_discapacidad'.
# No se encontraron palabras después del preprocesamiento para la columna 'comentario_dificultad'.
# No se encontraron palabras para generar la nube de palabras en la columna 'comentario_dificultad'.
# No se encontraron palabras después del preprocesamiento para la columna 'comentar_situacion_cuidados_campus'.
# No se encontraron palabras para generar la nube de palabras en la columna 'comentar_situacion_cuidados_campus'.
# No se encontraron palabras después del preprocesamiento para la columna 'dependientes_de_estudiante'.
# No se encontraron palabras para generar la nube de palabras en la columna 'dependientes_de_estudiante'.
# No se encontraron palabras después del preprocesamiento para la columna 'quien_depende_estudiante'.
# No se encontraron palabras para generar la nube de palabras en la columna 'quien_depende_estudiante'.
# Número de palabras después del preprocesamiento para la columna 'factores_dificultad_estudio': 4
# C:\Users\yerko.gallardo\AppData\Local\Temp\ipykernel_7552\554020761.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, 'text'] = df[column].fillna('')
# C:\Users\yerko.gallardo\AppData\Local\Temp\ipykernel_7552\554020761.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, 'text'] = df['text'].str.lower()
# C:\Users\yerko.gallardo\AppData\Local\Temp\ipykernel_7552\554020761.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, 'text'] = df['text'].str.replace('[^\w\s]', '', regex=False)
# C:\Users\yerko.gallardo\AppData\Local\Temp\ipykernel_7552\554020761.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, 'text'] = df['text'].apply(lambda x: ' '.join([word for word in word_tokenize(x) if word.lower() not in stop_words_esp]))
# C:\Users\yerko.gallardo\AppData\Local\Temp\ipykernel_7552\554020761.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, 'text'] = df['text'].apply(word_tokenize)
# C:\Users\yerko.gallardo\AppData\Local\Temp\ipykernel_7552\554020761.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, 'text'] = df['text'].apply(lambda x: [unidecode(word) for word in x])
# Gráfico guardado en 'carreras\INTERPRETE MUSICAL SUPERIOR VIOLONCELLO - Santiago/36_wordcloud_factores_dificultad_estudio.png'!
# Número de palabras después del preprocesamiento para la columna 'situacion_dificultad': 7
# Gráfico guardado en 'carreras\INTERPRETE MUSICAL SUPERIOR VIOLONCELLO - Santiago/38_wordcloud_situacion_dificultad.png'!
# No se encontraron palabras después del preprocesamiento para la columna 'indica_deporte_hobbie'.
# No se encontraron palabras para generar la nube de palabras en la columna 'indica_deporte_hobbie'.
# Número de palabras después del preprocesamiento para la columna 'genero_se_identifica': 2
# Gráfico guardado en 'carreras\INTERPRETE MUSICAL SUPERIOR VIOLONCELLO - Santiago/11_wordcloud_genero_se_identifica.png'!
# Número de palabras después del preprocesamiento para la columna 'razon_ingreso_tardio_ed_mayor': 2
# Gráfico guardado en 'carreras\INTERPRETE MUSICAL SUPERIOR VIOLONCELLO - Santiago/3_wordcloud_razon_ingreso_tardio_ed_mayor.png'!
# No se encontraron palabras después del preprocesamiento para la columna 'quien_red_apoyo'.
# No se encontraron palabras para generar la nube de palabras en la columna 'quien_red_apoyo'.
# No se encontraron palabras después del preprocesamiento para la columna 'situacion_discapacidad'.
# No se encontraron palabras para generar la nube de palabras en la columna 'situacion_discapacidad'.
# Número de palabras después del preprocesamiento para la columna 'comentario_dificultad': 8
# C:\Users\yerko.gallardo\AppData\Local\Temp\ipykernel_7552\554020761.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, 'text'] = df[column].fillna('')
# C:\Users\yerko.gallardo\AppData\Local\Temp\ipykernel_7552\554020761.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, 'text'] = df['text'].str.lower()
# C:\Users\yerko.gallardo\AppData\Local\Temp\ipykernel_7552\554020761.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, 'text'] = df['text'].str.replace('[^\w\s]', '', regex=False)
# C:\Users\yerko.gallardo\AppData\Local\Temp\ipykernel_7552\554020761.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, 'text'] = df['text'].apply(lambda x: ' '.join([word for word in word_tokenize(x) if word.lower() not in stop_words_esp]))
# C:\Users\yerko.gallardo\AppData\Local\Temp\ipykernel_7552\554020761.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, 'text'] = df['text'].apply(word_tokenize)
# C:\Users\yerko.gallardo\AppData\Local\Temp\ipykernel_7552\554020761.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, 'text'] = df['text'].apply(lambda x: [unidecode(word) for word in x])
# Gráfico guardado en 'carreras\INTERPRETACIÓN MUSICAL BÁSICO (8) C/M - Santiago/18_wordcloud_comentario_dificultad.png'!
# No se encontraron palabras después del preprocesamiento para la columna 'comentar_situacion_cuidados_campus'.
# No se encontraron palabras para generar la nube de palabras en la columna 'comentar_situacion_cuidados_campus'.
# No se encontraron palabras después del preprocesamiento para la columna 'dependientes_de_estudiante'.
# No se encontraron palabras para generar la nube de palabras en la columna 'dependientes_de_estudiante'.
# No se encontraron palabras después del preprocesamiento para la columna 'quien_depende_estudiante'.
# No se encontraron palabras para generar la nube de palabras en la columna 'quien_depende_estudiante'.
# Número de palabras después del preprocesamiento para la columna 'factores_dificultad_estudio': 1
# Gráfico guardado en 'carreras\INTERPRETACIÓN MUSICAL BÁSICO (8) C/M - Santiago/36_wordcloud_factores_dificultad_estudio.png'!
# Número de palabras después del preprocesamiento para la columna 'situacion_dificultad': 7
# Gráfico guardado en 'carreras\INTERPRETACIÓN MUSICAL BÁSICO (8) C/M - Santiago/38_wordcloud_situacion_dificultad.png'!
# Número de palabras después del preprocesamiento para la columna 'indica_deporte_hobbie': 11
# Gráfico guardado en 'carreras\INTERPRETACIÓN MUSICAL BÁSICO (8) C/M - Santiago/48_wordcloud_indica_deporte_hobbie.png'!
# Número de palabras después del preprocesamiento para la columna 'genero_se_identifica': 1
# Gráfico guardado en 'carreras\INTERPRETACIÓN MUSICAL BÁSICO (8) C/M - Santiago/11_wordcloud_genero_se_identifica.png'!
# No se encontraron palabras después del preprocesamiento para la columna 'razon_ingreso_tardio_ed_mayor'.
# No se encontraron palabras para generar la nube de palabras en la columna 'razon_ingreso_tardio_ed_mayor'.
# Número de palabras después del preprocesamiento para la columna 'quien_red_apoyo': 2
# C:\Users\yerko.gallardo\AppData\Local\Temp\ipykernel_7552\554020761.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, 'text'] = df[column].fillna('')
# C:\Users\yerko.gallardo\AppData\Local\Temp\ipykernel_7552\554020761.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, 'text'] = df['text'].str.lower()
# C:\Users\yerko.gallardo\AppData\Local\Temp\ipykernel_7552\554020761.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, 'text'] = df['text'].str.replace('[^\w\s]', '', regex=False)
# C:\Users\yerko.gallardo\AppData\Local\Temp\ipykernel_7552\554020761.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, 'text'] = df['text'].apply(lambda x: ' '.join([word for word in word_tokenize(x) if word.lower() not in stop_words_esp]))
# C:\Users\yerko.gallardo\AppData\Local\Temp\ipykernel_7552\554020761.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, 'text'] = df['text'].apply(word_tokenize)
# C:\Users\yerko.gallardo\AppData\Local\Temp\ipykernel_7552\554020761.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, 'text'] = df['text'].apply(lambda x: [unidecode(word) for word in x])
# Gráfico guardado en 'carreras\SOCIOLOGÍA (V) - Santiago/9_wordcloud_quien_red_apoyo.png'!
# Número de palabras después del preprocesamiento para la columna 'situacion_discapacidad': 18
# Gráfico guardado en 'carreras\SOCIOLOGÍA (V) - Santiago/15_wordcloud_situacion_discapacidad.png'!
# No se encontraron palabras después del preprocesamiento para la columna 'comentario_dificultad'.
# No se encontraron palabras para generar la nube de palabras en la columna 'comentario_dificultad'.
# No se encontraron palabras después del preprocesamiento para la columna 'comentar_situacion_cuidados_campus'.
# No se encontraron palabras para generar la nube de palabras en la columna 'comentar_situacion_cuidados_campus'.
# No se encontraron palabras después del preprocesamiento para la columna 'dependientes_de_estudiante'.
# No se encontraron palabras para generar la nube de palabras en la columna 'dependientes_de_estudiante'.
# No se encontraron palabras después del preprocesamiento para la columna 'quien_depende_estudiante'.
# No se encontraron palabras para generar la nube de palabras en la columna 'quien_depende_estudiante'.
# Número de palabras después del preprocesamiento para la columna 'factores_dificultad_estudio': 1
# Gráfico guardado en 'carreras\SOCIOLOGÍA (V) - Santiago/36_wordcloud_factores_dificultad_estudio.png'!
# Número de palabras después del preprocesamiento para la columna 'situacion_dificultad': 15
# Gráfico guardado en 'carreras\SOCIOLOGÍA (V) - Santiago/38_wordcloud_situacion_dificultad.png'!
# No se encontraron palabras después del preprocesamiento para la columna 'indica_deporte_hobbie'.
# No se encontraron palabras para generar la nube de palabras en la columna 'indica_deporte_hobbie'.
# Número de palabras después del preprocesamiento para la columna 'genero_se_identifica': 1
# Gráfico guardado en 'carreras\SOCIOLOGÍA (V) - Santiago/11_wordcloud_genero_se_identifica.png'!
# Número de palabras después del preprocesamiento para la columna 'razon_ingreso_tardio_ed_mayor': 2
# Gráfico guardado en 'carreras\SOCIOLOGÍA (V) - Santiago/3_wordcloud_razon_ingreso_tardio_ed_mayor.png'!

# %%
for carr in carreras.index:
    ruta = os.path.join(directorio_base, carr)
    
    df_carrera = df[df['carrera_sede'] == carr]
    
    nuevo_df = pd.DataFrame(df_carrera, columns=graficar)
    # Seleccionar todas las columnas con tipo de dato "object"
    columnas_object = nuevo_df.select_dtypes(include=['object']).columns
    # Cambiar el tipo de dato de las columnas seleccionadas a "categorical"
    nuevo_df[columnas_object] = nuevo_df[columnas_object].astype('category')    
    for column in graficar:
        # graficar_mod(df_carrera, gr)
        # Obtener los valores y sus frecuencias, ordenados de forma descendente
        value_counts = df_carrera[column].value_counts().sort_values(ascending=False)
        # Verificar si hay valores únicos disponibles
        if len(value_counts) == 0:
            print(f"No hay valores únicos disponibles para la columna '{column}'.")
            continue
        # Crear un DataFrame ordenado con los valores y sus frecuencias
        data = pd.DataFrame({column: value_counts.index, 'Cantidad de estudiantes': value_counts.values})
        # Crear el gráfico de barras utilizando Seaborn
        fig, ax = plt.subplots(figsize=(8,6))
        ax = sns.barplot(x='Cantidad de estudiantes', y=column, data=data, order=value_counts.index)
        wrap_labels(ax, 60)
        # Configurar el título y las etiquetas de los ejes
        titulo = def_dic[column] if column in def_dic else None
        plt.title('Gráfico de ' + column)
        plt.xlabel('Cantidad de estudiantes')
        plt.ylabel(column)
        ax.set_xlim(right=ax.get_xlim()[1] * 1.1)
        descripcion_recortada = '\n'.join(textwrap.wrap(titulo, width=60))
        plt.text(0.5, -0.20, descripcion_recortada, ha='center', va='center', transform=ax.transAxes)
        # Agregar los valores en las barras
        for p in ax.patches:
            width = p.get_width()
            height = p.get_height()
            x, y = p.get_xy() 
            value = int(width)
            ax.annotate(f'{value}', (x + width, y + height/2), ha='left', va='center')
        
        num_titulo = next((clave for clave, valor in num_dic.items() if valor == titulo), None)
        nombre_archivo = f"{num_titulo}_gra_{column}.png" if titulo else "grafico.png"
        plt.tight_layout()
        # Guardar el gráfico en una imagen
        plt.savefig(os.path.join(ruta, nombre_archivo))
        plt.close()
        
        print(f"Gráfico guardado en '{ruta}/{nombre_archivo}'!")
# Out:
# Gráfico guardado en 'carreras\MEDICINA VETERINARIA - Santiago/1_gra_declaracion_uso_datos.png'!
# Gráfico guardado en 'carreras\MEDICINA VETERINARIA - Santiago/2_gra_t_desde_egreso.png'!
# Gráfico guardado en 'carreras\MEDICINA VETERINARIA - Santiago/4_gra_estudia_antes_edsup.png'!
# Gráfico guardado en 'carreras\MEDICINA VETERINARIA - Santiago/5_gra_finalizo_est_antes_edsup.png'!
# Gráfico guardado en 'carreras\MEDICINA VETERINARIA - Santiago/6_gra_estado_civil.png'!
# Gráfico guardado en 'carreras\MEDICINA VETERINARIA - Santiago/7_gra_tiene_hijos.png'!
# Gráfico guardado en 'carreras\MEDICINA VETERINARIA - Santiago/8_gra_red_apoyo.png'!
# Gráfico guardado en 'carreras\MEDICINA VETERINARIA - Santiago/10_gra_etnia.png'!
# Gráfico guardado en 'carreras\MEDICINA VETERINARIA - Santiago/14_gra_declara_discapacidad.png'!
# Gráfico guardado en 'carreras\MEDICINA VETERINARIA - Santiago/19_gra_cuidados_dentro_campus.png'!
# Gráfico guardado en 'carreras\MEDICINA VETERINARIA - Santiago/23_gra_tramo_registro_social.png'!
# Gráfico guardado en 'carreras\MEDICINA VETERINARIA - Santiago/24_gra_cuantos_convive_2023.png'!
# Gráfico guardado en 'carreras\MEDICINA VETERINARIA - Santiago/26_gra_situacion_laboral.png'!
# Gráfico guardado en 'carreras\MEDICINA VETERINARIA - Santiago/27_gra_horas_semanales_laboral.png'!
# Gráfico guardado en 'carreras\MEDICINA VETERINARIA - Santiago/28_gra_dependencia_grupo_familiar.png'!
# Gráfico guardado en 'carreras\MEDICINA VETERINARIA - Santiago/31_gra_horas_cuidado_estudiante.png'!
# Gráfico guardado en 'carreras\MEDICINA VETERINARIA - Santiago/33_gra_acceso_medio_digital.png'!
# Gráfico guardado en 'carreras\MEDICINA VETERINARIA - Santiago/34_gra_uso_exclusivo_medio_digital.png'!
# Gráfico guardado en 'carreras\MEDICINA VETERINARIA - Santiago/35_gra_acceso_internet_alumno.png'!
# Gráfico guardado en 'carreras\MEDICINA VETERINARIA - Santiago/37_gra_dificultad_trayecto.png'!
# Gráfico guardado en 'carreras\MEDICINA VETERINARIA - Santiago/42_gra_requiere_pares_mentores.png'!
# Gráfico guardado en 'carreras\MEDICINA VETERINARIA - Santiago/43_gra_tiempo_traslado.png'!
# Gráfico guardado en 'carreras\MEDICINA VETERINARIA - Santiago/44_gra_medio_transporte.png'!
# Gráfico guardado en 'carreras\MEDICINA VETERINARIA - Santiago/47_gra_practica_deporte_hobbie.png'!
# Gráfico guardado en 'carreras\MEDICINA VETERINARIA - Santiago/12_gra_orientacion_sexual.png'!
# Gráfico guardado en 'carreras\MEDICINA VETERINARIA - Santiago/17_gra_condicion_dificultad_clases.png'!
# Gráfico guardado en 'carreras\MEDICINA VETERINARIA - Santiago/25_gra_situacion_laboral_jefe_hogar.png'!
# Gráfico guardado en 'carreras\MEDICINA VETERINARIA - Santiago/32_gra_lugar_estudio_alumno.png'!
# Gráfico guardado en 'carreras\MEDICINA VETERINARIA - Santiago/11_gra_genero_identifica_mfo.png'!
# Gráfico guardado en 'carreras\PSICOLOGÍA - Santiago/1_gra_declaracion_uso_datos.png'!
# Gráfico guardado en 'carreras\PSICOLOGÍA - Santiago/2_gra_t_desde_egreso.png'!
# Gráfico guardado en 'carreras\PSICOLOGÍA - Santiago/4_gra_estudia_antes_edsup.png'!
# Gráfico guardado en 'carreras\PSICOLOGÍA - Santiago/5_gra_finalizo_est_antes_edsup.png'!
# Gráfico guardado en 'carreras\PSICOLOGÍA - Santiago/6_gra_estado_civil.png'!
# Gráfico guardado en 'carreras\PSICOLOGÍA - Santiago/7_gra_tiene_hijos.png'!
# Gráfico guardado en 'carreras\PSICOLOGÍA - Santiago/8_gra_red_apoyo.png'!
# Gráfico guardado en 'carreras\PSICOLOGÍA - Santiago/10_gra_etnia.png'!
# Gráfico guardado en 'carreras\PSICOLOGÍA - Santiago/14_gra_declara_discapacidad.png'!
# Gráfico guardado en 'carreras\PSICOLOGÍA - Santiago/19_gra_cuidados_dentro_campus.png'!
# Gráfico guardado en 'carreras\PSICOLOGÍA - Santiago/23_gra_tramo_registro_social.png'!
# Gráfico guardado en 'carreras\PSICOLOGÍA - Santiago/24_gra_cuantos_convive_2023.png'!
# Gráfico guardado en 'carreras\PSICOLOGÍA - Santiago/26_gra_situacion_laboral.png'!
# Gráfico guardado en 'carreras\PSICOLOGÍA - Santiago/27_gra_horas_semanales_laboral.png'!
# Gráfico guardado en 'carreras\PSICOLOGÍA - Santiago/28_gra_dependencia_grupo_familiar.png'!
# Gráfico guardado en 'carreras\PSICOLOGÍA - Santiago/31_gra_horas_cuidado_estudiante.png'!
# Gráfico guardado en 'carreras\PSICOLOGÍA - Santiago/33_gra_acceso_medio_digital.png'!
# Gráfico guardado en 'carreras\PSICOLOGÍA - Santiago/34_gra_uso_exclusivo_medio_digital.png'!
# Gráfico guardado en 'carreras\PSICOLOGÍA - Santiago/35_gra_acceso_internet_alumno.png'!
# Gráfico guardado en 'carreras\PSICOLOGÍA - Santiago/37_gra_dificultad_trayecto.png'!
# Gráfico guardado en 'carreras\PSICOLOGÍA - Santiago/42_gra_requiere_pares_mentores.png'!
# Gráfico guardado en 'carreras\PSICOLOGÍA - Santiago/43_gra_tiempo_traslado.png'!
# Gráfico guardado en 'carreras\PSICOLOGÍA - Santiago/44_gra_medio_transporte.png'!
# Gráfico guardado en 'carreras\PSICOLOGÍA - Santiago/47_gra_practica_deporte_hobbie.png'!
# Gráfico guardado en 'carreras\PSICOLOGÍA - Santiago/12_gra_orientacion_sexual.png'!
# Gráfico guardado en 'carreras\PSICOLOGÍA - Santiago/17_gra_condicion_dificultad_clases.png'!
# Gráfico guardado en 'carreras\PSICOLOGÍA - Santiago/25_gra_situacion_laboral_jefe_hogar.png'!
# Gráfico guardado en 'carreras\PSICOLOGÍA - Santiago/32_gra_lugar_estudio_alumno.png'!
# Gráfico guardado en 'carreras\PSICOLOGÍA - Santiago/11_gra_genero_identifica_mfo.png'!
# Gráfico guardado en 'carreras\TECNOLOGÍA MÉDICA - Santiago/1_gra_declaracion_uso_datos.png'!
# Gráfico guardado en 'carreras\TECNOLOGÍA MÉDICA - Santiago/2_gra_t_desde_egreso.png'!
# Gráfico guardado en 'carreras\TECNOLOGÍA MÉDICA - Santiago/4_gra_estudia_antes_edsup.png'!
# Gráfico guardado en 'carreras\TECNOLOGÍA MÉDICA - Santiago/5_gra_finalizo_est_antes_edsup.png'!
# Gráfico guardado en 'carreras\TECNOLOGÍA MÉDICA - Santiago/6_gra_estado_civil.png'!
# Gráfico guardado en 'carreras\TECNOLOGÍA MÉDICA - Santiago/7_gra_tiene_hijos.png'!
# Gráfico guardado en 'carreras\TECNOLOGÍA MÉDICA - Santiago/8_gra_red_apoyo.png'!
# Gráfico guardado en 'carreras\TECNOLOGÍA MÉDICA - Santiago/10_gra_etnia.png'!
# Gráfico guardado en 'carreras\TECNOLOGÍA MÉDICA - Santiago/14_gra_declara_discapacidad.png'!
# Gráfico guardado en 'carreras\TECNOLOGÍA MÉDICA - Santiago/19_gra_cuidados_dentro_campus.png'!
# Gráfico guardado en 'carreras\TECNOLOGÍA MÉDICA - Santiago/23_gra_tramo_registro_social.png'!
# Gráfico guardado en 'carreras\TECNOLOGÍA MÉDICA - Santiago/24_gra_cuantos_convive_2023.png'!
# Gráfico guardado en 'carreras\TECNOLOGÍA MÉDICA - Santiago/26_gra_situacion_laboral.png'!
# Gráfico guardado en 'carreras\TECNOLOGÍA MÉDICA - Santiago/27_gra_horas_semanales_laboral.png'!
# Gráfico guardado en 'carreras\TECNOLOGÍA MÉDICA - Santiago/28_gra_dependencia_grupo_familiar.png'!
# Gráfico guardado en 'carreras\TECNOLOGÍA MÉDICA - Santiago/31_gra_horas_cuidado_estudiante.png'!
# Gráfico guardado en 'carreras\TECNOLOGÍA MÉDICA - Santiago/33_gra_acceso_medio_digital.png'!
# Gráfico guardado en 'carreras\TECNOLOGÍA MÉDICA - Santiago/34_gra_uso_exclusivo_medio_digital.png'!
# Gráfico guardado en 'carreras\TECNOLOGÍA MÉDICA - Santiago/35_gra_acceso_internet_alumno.png'!
# Gráfico guardado en 'carreras\TECNOLOGÍA MÉDICA - Santiago/37_gra_dificultad_trayecto.png'!
# Gráfico guardado en 'carreras\TECNOLOGÍA MÉDICA - Santiago/42_gra_requiere_pares_mentores.png'!
# Gráfico guardado en 'carreras\TECNOLOGÍA MÉDICA - Santiago/43_gra_tiempo_traslado.png'!
# Gráfico guardado en 'carreras\TECNOLOGÍA MÉDICA - Santiago/44_gra_medio_transporte.png'!
# Gráfico guardado en 'carreras\TECNOLOGÍA MÉDICA - Santiago/47_gra_practica_deporte_hobbie.png'!
# Gráfico guardado en 'carreras\TECNOLOGÍA MÉDICA - Santiago/12_gra_orientacion_sexual.png'!
# Gráfico guardado en 'carreras\TECNOLOGÍA MÉDICA - Santiago/17_gra_condicion_dificultad_clases.png'!
# Gráfico guardado en 'carreras\TECNOLOGÍA MÉDICA - Santiago/25_gra_situacion_laboral_jefe_hogar.png'!
# Gráfico guardado en 'carreras\TECNOLOGÍA MÉDICA - Santiago/32_gra_lugar_estudio_alumno.png'!
# Gráfico guardado en 'carreras\TECNOLOGÍA MÉDICA - Santiago/11_gra_genero_identifica_mfo.png'!
# Gráfico guardado en 'carreras\ADMINISTRACIÓN PÚBLICA  CONT. (ON-LINE) - Santiago/1_gra_declaracion_uso_datos.png'!
# Gráfico guardado en 'carreras\ADMINISTRACIÓN PÚBLICA  CONT. (ON-LINE) - Santiago/2_gra_t_desde_egreso.png'!
# Gráfico guardado en 'carreras\ADMINISTRACIÓN PÚBLICA  CONT. (ON-LINE) - Santiago/4_gra_estudia_antes_edsup.png'!
# Gráfico guardado en 'carreras\ADMINISTRACIÓN PÚBLICA  CONT. (ON-LINE) - Santiago/5_gra_finalizo_est_antes_edsup.png'!
# Gráfico guardado en 'carreras\ADMINISTRACIÓN PÚBLICA  CONT. (ON-LINE) - Santiago/6_gra_estado_civil.png'!
# Gráfico guardado en 'carreras\ADMINISTRACIÓN PÚBLICA  CONT. (ON-LINE) - Santiago/7_gra_tiene_hijos.png'!
# Gráfico guardado en 'carreras\ADMINISTRACIÓN PÚBLICA  CONT. (ON-LINE) - Santiago/8_gra_red_apoyo.png'!
# Gráfico guardado en 'carreras\ADMINISTRACIÓN PÚBLICA  CONT. (ON-LINE) - Santiago/10_gra_etnia.png'!
# Gráfico guardado en 'carreras\ADMINISTRACIÓN PÚBLICA  CONT. (ON-LINE) - Santiago/14_gra_declara_discapacidad.png'!
# Gráfico guardado en 'carreras\ADMINISTRACIÓN PÚBLICA  CONT. (ON-LINE) - Santiago/19_gra_cuidados_dentro_campus.png'!
# Gráfico guardado en 'carreras\ADMINISTRACIÓN PÚBLICA  CONT. (ON-LINE) - Santiago/23_gra_tramo_registro_social.png'!
# Gráfico guardado en 'carreras\ADMINISTRACIÓN PÚBLICA  CONT. (ON-LINE) - Santiago/24_gra_cuantos_convive_2023.png'!
# Gráfico guardado en 'carreras\ADMINISTRACIÓN PÚBLICA  CONT. (ON-LINE) - Santiago/26_gra_situacion_laboral.png'!
# Gráfico guardado en 'carreras\ADMINISTRACIÓN PÚBLICA  CONT. (ON-LINE) - Santiago/27_gra_horas_semanales_laboral.png'!
# Gráfico guardado en 'carreras\ADMINISTRACIÓN PÚBLICA  CONT. (ON-LINE) - Santiago/28_gra_dependencia_grupo_familiar.png'!
# Gráfico guardado en 'carreras\ADMINISTRACIÓN PÚBLICA  CONT. (ON-LINE) - Santiago/31_gra_horas_cuidado_estudiante.png'!
# Gráfico guardado en 'carreras\ADMINISTRACIÓN PÚBLICA  CONT. (ON-LINE) - Santiago/33_gra_acceso_medio_digital.png'!
# Gráfico guardado en 'carreras\ADMINISTRACIÓN PÚBLICA  CONT. (ON-LINE) - Santiago/34_gra_uso_exclusivo_medio_digital.png'!
# Gráfico guardado en 'carreras\ADMINISTRACIÓN PÚBLICA  CONT. (ON-LINE) - Santiago/35_gra_acceso_internet_alumno.png'!
# Gráfico guardado en 'carreras\ADMINISTRACIÓN PÚBLICA  CONT. (ON-LINE) - Santiago/37_gra_dificultad_trayecto.png'!
# Gráfico guardado en 'carreras\ADMINISTRACIÓN PÚBLICA  CONT. (ON-LINE) - Santiago/42_gra_requiere_pares_mentores.png'!
# Gráfico guardado en 'carreras\ADMINISTRACIÓN PÚBLICA  CONT. (ON-LINE) - Santiago/43_gra_tiempo_traslado.png'!
# Gráfico guardado en 'carreras\ADMINISTRACIÓN PÚBLICA  CONT. (ON-LINE) - Santiago/44_gra_medio_transporte.png'!
# Gráfico guardado en 'carreras\ADMINISTRACIÓN PÚBLICA  CONT. (ON-LINE) - Santiago/47_gra_practica_deporte_hobbie.png'!
# Gráfico guardado en 'carreras\ADMINISTRACIÓN PÚBLICA  CONT. (ON-LINE) - Santiago/12_gra_orientacion_sexual.png'!
# Gráfico guardado en 'carreras\ADMINISTRACIÓN PÚBLICA  CONT. (ON-LINE) - Santiago/17_gra_condicion_dificultad_clases.png'!
# Gráfico guardado en 'carreras\ADMINISTRACIÓN PÚBLICA  CONT. (ON-LINE) - Santiago/25_gra_situacion_laboral_jefe_hogar.png'!
# Gráfico guardado en 'carreras\ADMINISTRACIÓN PÚBLICA  CONT. (ON-LINE) - Santiago/32_gra_lugar_estudio_alumno.png'!
# Gráfico guardado en 'carreras\ADMINISTRACIÓN PÚBLICA  CONT. (ON-LINE) - Santiago/11_gra_genero_identifica_mfo.png'!
# Gráfico guardado en 'carreras\ING. CIVIL INDUSTRIAL  (CONTI.-ONL) - Santiago/1_gra_declaracion_uso_datos.png'!
# Gráfico guardado en 'carreras\ING. CIVIL INDUSTRIAL  (CONTI.-ONL) - Santiago/2_gra_t_desde_egreso.png'!
# Gráfico guardado en 'carreras\ING. CIVIL INDUSTRIAL  (CONTI.-ONL) - Santiago/4_gra_estudia_antes_edsup.png'!
# Gráfico guardado en 'carreras\ING. CIVIL INDUSTRIAL  (CONTI.-ONL) - Santiago/5_gra_finalizo_est_antes_edsup.png'!
# Gráfico guardado en 'carreras\ING. CIVIL INDUSTRIAL  (CONTI.-ONL) - Santiago/6_gra_estado_civil.png'!
# Gráfico guardado en 'carreras\ING. CIVIL INDUSTRIAL  (CONTI.-ONL) - Santiago/7_gra_tiene_hijos.png'!
# Gráfico guardado en 'carreras\ING. CIVIL INDUSTRIAL  (CONTI.-ONL) - Santiago/8_gra_red_apoyo.png'!
# Gráfico guardado en 'carreras\ING. CIVIL INDUSTRIAL  (CONTI.-ONL) - Santiago/10_gra_etnia.png'!
# Gráfico guardado en 'carreras\ING. CIVIL INDUSTRIAL  (CONTI.-ONL) - Santiago/14_gra_declara_discapacidad.png'!
# Gráfico guardado en 'carreras\ING. CIVIL INDUSTRIAL  (CONTI.-ONL) - Santiago/19_gra_cuidados_dentro_campus.png'!
# Gráfico guardado en 'carreras\ING. CIVIL INDUSTRIAL  (CONTI.-ONL) - Santiago/23_gra_tramo_registro_social.png'!
# Gráfico guardado en 'carreras\ING. CIVIL INDUSTRIAL  (CONTI.-ONL) - Santiago/24_gra_cuantos_convive_2023.png'!
# Gráfico guardado en 'carreras\ING. CIVIL INDUSTRIAL  (CONTI.-ONL) - Santiago/26_gra_situacion_laboral.png'!
# Gráfico guardado en 'carreras\ING. CIVIL INDUSTRIAL  (CONTI.-ONL) - Santiago/27_gra_horas_semanales_laboral.png'!
# Gráfico guardado en 'carreras\ING. CIVIL INDUSTRIAL  (CONTI.-ONL) - Santiago/28_gra_dependencia_grupo_familiar.png'!
# Gráfico guardado en 'carreras\ING. CIVIL INDUSTRIAL  (CONTI.-ONL) - Santiago/31_gra_horas_cuidado_estudiante.png'!
# Gráfico guardado en 'carreras\ING. CIVIL INDUSTRIAL  (CONTI.-ONL) - Santiago/33_gra_acceso_medio_digital.png'!
# Gráfico guardado en 'carreras\ING. CIVIL INDUSTRIAL  (CONTI.-ONL) - Santiago/34_gra_uso_exclusivo_medio_digital.png'!
# Gráfico guardado en 'carreras\ING. CIVIL INDUSTRIAL  (CONTI.-ONL) - Santiago/35_gra_acceso_internet_alumno.png'!
# Gráfico guardado en 'carreras\ING. CIVIL INDUSTRIAL  (CONTI.-ONL) - Santiago/37_gra_dificultad_trayecto.png'!
# Gráfico guardado en 'carreras\ING. CIVIL INDUSTRIAL  (CONTI.-ONL) - Santiago/42_gra_requiere_pares_mentores.png'!
# Gráfico guardado en 'carreras\ING. CIVIL INDUSTRIAL  (CONTI.-ONL) - Santiago/43_gra_tiempo_traslado.png'!
# Gráfico guardado en 'carreras\ING. CIVIL INDUSTRIAL  (CONTI.-ONL) - Santiago/44_gra_medio_transporte.png'!
# Gráfico guardado en 'carreras\ING. CIVIL INDUSTRIAL  (CONTI.-ONL) - Santiago/47_gra_practica_deporte_hobbie.png'!
# Gráfico guardado en 'carreras\ING. CIVIL INDUSTRIAL  (CONTI.-ONL) - Santiago/12_gra_orientacion_sexual.png'!
# Gráfico guardado en 'carreras\ING. CIVIL INDUSTRIAL  (CONTI.-ONL) - Santiago/17_gra_condicion_dificultad_clases.png'!
# Gráfico guardado en 'carreras\ING. CIVIL INDUSTRIAL  (CONTI.-ONL) - Santiago/25_gra_situacion_laboral_jefe_hogar.png'!
# Gráfico guardado en 'carreras\ING. CIVIL INDUSTRIAL  (CONTI.-ONL) - Santiago/32_gra_lugar_estudio_alumno.png'!
# Gráfico guardado en 'carreras\ING. CIVIL INDUSTRIAL  (CONTI.-ONL) - Santiago/11_gra_genero_identifica_mfo.png'!
# Gráfico guardado en 'carreras\ANIMACIÓN DIGITAL - Santiago/1_gra_declaracion_uso_datos.png'!
# Gráfico guardado en 'carreras\ANIMACIÓN DIGITAL - Santiago/2_gra_t_desde_egreso.png'!
# Gráfico guardado en 'carreras\ANIMACIÓN DIGITAL - Santiago/4_gra_estudia_antes_edsup.png'!
# Gráfico guardado en 'carreras\ANIMACIÓN DIGITAL - Santiago/5_gra_finalizo_est_antes_edsup.png'!
# Gráfico guardado en 'carreras\ANIMACIÓN DIGITAL - Santiago/6_gra_estado_civil.png'!
# Gráfico guardado en 'carreras\ANIMACIÓN DIGITAL - Santiago/7_gra_tiene_hijos.png'!
# No hay valores únicos disponibles para la columna 'red_apoyo'.
# Gráfico guardado en 'carreras\ANIMACIÓN DIGITAL - Santiago/10_gra_etnia.png'!
# Gráfico guardado en 'carreras\ANIMACIÓN DIGITAL - Santiago/14_gra_declara_discapacidad.png'!
# Gráfico guardado en 'carreras\ANIMACIÓN DIGITAL - Santiago/19_gra_cuidados_dentro_campus.png'!
# Gráfico guardado en 'carreras\ANIMACIÓN DIGITAL - Santiago/23_gra_tramo_registro_social.png'!
# Gráfico guardado en 'carreras\ANIMACIÓN DIGITAL - Santiago/24_gra_cuantos_convive_2023.png'!
# Gráfico guardado en 'carreras\ANIMACIÓN DIGITAL - Santiago/26_gra_situacion_laboral.png'!
# Gráfico guardado en 'carreras\ANIMACIÓN DIGITAL - Santiago/27_gra_horas_semanales_laboral.png'!
# Gráfico guardado en 'carreras\ANIMACIÓN DIGITAL - Santiago/28_gra_dependencia_grupo_familiar.png'!
# Gráfico guardado en 'carreras\ANIMACIÓN DIGITAL - Santiago/31_gra_horas_cuidado_estudiante.png'!
# Gráfico guardado en 'carreras\ANIMACIÓN DIGITAL - Santiago/33_gra_acceso_medio_digital.png'!
# Gráfico guardado en 'carreras\ANIMACIÓN DIGITAL - Santiago/34_gra_uso_exclusivo_medio_digital.png'!
# Gráfico guardado en 'carreras\ANIMACIÓN DIGITAL - Santiago/35_gra_acceso_internet_alumno.png'!
# Gráfico guardado en 'carreras\ANIMACIÓN DIGITAL - Santiago/37_gra_dificultad_trayecto.png'!
# Gráfico guardado en 'carreras\ANIMACIÓN DIGITAL - Santiago/42_gra_requiere_pares_mentores.png'!
# Gráfico guardado en 'carreras\ANIMACIÓN DIGITAL - Santiago/43_gra_tiempo_traslado.png'!
# Gráfico guardado en 'carreras\ANIMACIÓN DIGITAL - Santiago/44_gra_medio_transporte.png'!
# Gráfico guardado en 'carreras\ANIMACIÓN DIGITAL - Santiago/47_gra_practica_deporte_hobbie.png'!
# Gráfico guardado en 'carreras\ANIMACIÓN DIGITAL - Santiago/12_gra_orientacion_sexual.png'!
# Gráfico guardado en 'carreras\ANIMACIÓN DIGITAL - Santiago/17_gra_condicion_dificultad_clases.png'!
# Gráfico guardado en 'carreras\ANIMACIÓN DIGITAL - Santiago/25_gra_situacion_laboral_jefe_hogar.png'!
# Gráfico guardado en 'carreras\ANIMACIÓN DIGITAL - Santiago/32_gra_lugar_estudio_alumno.png'!
# Gráfico guardado en 'carreras\ANIMACIÓN DIGITAL - Santiago/11_gra_genero_identifica_mfo.png'!
# Gráfico guardado en 'carreras\ARQUITECTURA - Santiago/1_gra_declaracion_uso_datos.png'!
# Gráfico guardado en 'carreras\ARQUITECTURA - Santiago/2_gra_t_desde_egreso.png'!
# Gráfico guardado en 'carreras\ARQUITECTURA - Santiago/4_gra_estudia_antes_edsup.png'!
# Gráfico guardado en 'carreras\ARQUITECTURA - Santiago/5_gra_finalizo_est_antes_edsup.png'!
# Gráfico guardado en 'carreras\ARQUITECTURA - Santiago/6_gra_estado_civil.png'!
# Gráfico guardado en 'carreras\ARQUITECTURA - Santiago/7_gra_tiene_hijos.png'!
# Gráfico guardado en 'carreras\ARQUITECTURA - Santiago/8_gra_red_apoyo.png'!
# Gráfico guardado en 'carreras\ARQUITECTURA - Santiago/10_gra_etnia.png'!
# Gráfico guardado en 'carreras\ARQUITECTURA - Santiago/14_gra_declara_discapacidad.png'!
# Gráfico guardado en 'carreras\ARQUITECTURA - Santiago/19_gra_cuidados_dentro_campus.png'!
# Gráfico guardado en 'carreras\ARQUITECTURA - Santiago/23_gra_tramo_registro_social.png'!
# Gráfico guardado en 'carreras\ARQUITECTURA - Santiago/24_gra_cuantos_convive_2023.png'!
# Gráfico guardado en 'carreras\ARQUITECTURA - Santiago/26_gra_situacion_laboral.png'!
# Gráfico guardado en 'carreras\ARQUITECTURA - Santiago/27_gra_horas_semanales_laboral.png'!
# Gráfico guardado en 'carreras\ARQUITECTURA - Santiago/28_gra_dependencia_grupo_familiar.png'!
# Gráfico guardado en 'carreras\ARQUITECTURA - Santiago/31_gra_horas_cuidado_estudiante.png'!
# Gráfico guardado en 'carreras\ARQUITECTURA - Santiago/33_gra_acceso_medio_digital.png'!
# Gráfico guardado en 'carreras\ARQUITECTURA - Santiago/34_gra_uso_exclusivo_medio_digital.png'!
# Gráfico guardado en 'carreras\ARQUITECTURA - Santiago/35_gra_acceso_internet_alumno.png'!
# Gráfico guardado en 'carreras\ARQUITECTURA - Santiago/37_gra_dificultad_trayecto.png'!
# Gráfico guardado en 'carreras\ARQUITECTURA - Santiago/42_gra_requiere_pares_mentores.png'!
# Gráfico guardado en 'carreras\ARQUITECTURA - Santiago/43_gra_tiempo_traslado.png'!
# Gráfico guardado en 'carreras\ARQUITECTURA - Santiago/44_gra_medio_transporte.png'!
# Gráfico guardado en 'carreras\ARQUITECTURA - Santiago/47_gra_practica_deporte_hobbie.png'!
# Gráfico guardado en 'carreras\ARQUITECTURA - Santiago/12_gra_orientacion_sexual.png'!
# Gráfico guardado en 'carreras\ARQUITECTURA - Santiago/17_gra_condicion_dificultad_clases.png'!
# Gráfico guardado en 'carreras\ARQUITECTURA - Santiago/25_gra_situacion_laboral_jefe_hogar.png'!
# Gráfico guardado en 'carreras\ARQUITECTURA - Santiago/32_gra_lugar_estudio_alumno.png'!
# Gráfico guardado en 'carreras\ARQUITECTURA - Santiago/11_gra_genero_identifica_mfo.png'!
# Gráfico guardado en 'carreras\KINESIOLOGÍA - Santiago/1_gra_declaracion_uso_datos.png'!
# Gráfico guardado en 'carreras\KINESIOLOGÍA - Santiago/2_gra_t_desde_egreso.png'!
# Gráfico guardado en 'carreras\KINESIOLOGÍA - Santiago/4_gra_estudia_antes_edsup.png'!
# Gráfico guardado en 'carreras\KINESIOLOGÍA - Santiago/5_gra_finalizo_est_antes_edsup.png'!
# Gráfico guardado en 'carreras\KINESIOLOGÍA - Santiago/6_gra_estado_civil.png'!
# Gráfico guardado en 'carreras\KINESIOLOGÍA - Santiago/7_gra_tiene_hijos.png'!
# Gráfico guardado en 'carreras\KINESIOLOGÍA - Santiago/8_gra_red_apoyo.png'!
# Gráfico guardado en 'carreras\KINESIOLOGÍA - Santiago/10_gra_etnia.png'!
# Gráfico guardado en 'carreras\KINESIOLOGÍA - Santiago/14_gra_declara_discapacidad.png'!
# Gráfico guardado en 'carreras\KINESIOLOGÍA - Santiago/19_gra_cuidados_dentro_campus.png'!
# Gráfico guardado en 'carreras\KINESIOLOGÍA - Santiago/23_gra_tramo_registro_social.png'!
# Gráfico guardado en 'carreras\KINESIOLOGÍA - Santiago/24_gra_cuantos_convive_2023.png'!
# Gráfico guardado en 'carreras\KINESIOLOGÍA - Santiago/26_gra_situacion_laboral.png'!
# Gráfico guardado en 'carreras\KINESIOLOGÍA - Santiago/27_gra_horas_semanales_laboral.png'!
# Gráfico guardado en 'carreras\KINESIOLOGÍA - Santiago/28_gra_dependencia_grupo_familiar.png'!
# Gráfico guardado en 'carreras\KINESIOLOGÍA - Santiago/31_gra_horas_cuidado_estudiante.png'!
# Gráfico guardado en 'carreras\KINESIOLOGÍA - Santiago/33_gra_acceso_medio_digital.png'!
# Gráfico guardado en 'carreras\KINESIOLOGÍA - Santiago/34_gra_uso_exclusivo_medio_digital.png'!
# Gráfico guardado en 'carreras\KINESIOLOGÍA - Santiago/35_gra_acceso_internet_alumno.png'!
# Gráfico guardado en 'carreras\KINESIOLOGÍA - Santiago/37_gra_dificultad_trayecto.png'!
# Gráfico guardado en 'carreras\KINESIOLOGÍA - Santiago/42_gra_requiere_pares_mentores.png'!
# Gráfico guardado en 'carreras\KINESIOLOGÍA - Santiago/43_gra_tiempo_traslado.png'!
# Gráfico guardado en 'carreras\KINESIOLOGÍA - Santiago/44_gra_medio_transporte.png'!
# Gráfico guardado en 'carreras\KINESIOLOGÍA - Santiago/47_gra_practica_deporte_hobbie.png'!
# Gráfico guardado en 'carreras\KINESIOLOGÍA - Santiago/12_gra_orientacion_sexual.png'!
# Gráfico guardado en 'carreras\KINESIOLOGÍA - Santiago/17_gra_condicion_dificultad_clases.png'!
# Gráfico guardado en 'carreras\KINESIOLOGÍA - Santiago/25_gra_situacion_laboral_jefe_hogar.png'!
# Gráfico guardado en 'carreras\KINESIOLOGÍA - Santiago/32_gra_lugar_estudio_alumno.png'!
# Gráfico guardado en 'carreras\KINESIOLOGÍA - Santiago/11_gra_genero_identifica_mfo.png'!
# Gráfico guardado en 'carreras\INGENIERÍA  EN LOGÍSTICA ( CONT. ONLINE) - Santiago/1_gra_declaracion_uso_datos.png'!
# Gráfico guardado en 'carreras\INGENIERÍA  EN LOGÍSTICA ( CONT. ONLINE) - Santiago/2_gra_t_desde_egreso.png'!
# Gráfico guardado en 'carreras\INGENIERÍA  EN LOGÍSTICA ( CONT. ONLINE) - Santiago/4_gra_estudia_antes_edsup.png'!
# Gráfico guardado en 'carreras\INGENIERÍA  EN LOGÍSTICA ( CONT. ONLINE) - Santiago/5_gra_finalizo_est_antes_edsup.png'!
# Gráfico guardado en 'carreras\INGENIERÍA  EN LOGÍSTICA ( CONT. ONLINE) - Santiago/6_gra_estado_civil.png'!
# Gráfico guardado en 'carreras\INGENIERÍA  EN LOGÍSTICA ( CONT. ONLINE) - Santiago/7_gra_tiene_hijos.png'!
# Gráfico guardado en 'carreras\INGENIERÍA  EN LOGÍSTICA ( CONT. ONLINE) - Santiago/8_gra_red_apoyo.png'!
# Gráfico guardado en 'carreras\INGENIERÍA  EN LOGÍSTICA ( CONT. ONLINE) - Santiago/10_gra_etnia.png'!
# Gráfico guardado en 'carreras\INGENIERÍA  EN LOGÍSTICA ( CONT. ONLINE) - Santiago/14_gra_declara_discapacidad.png'!
# Gráfico guardado en 'carreras\INGENIERÍA  EN LOGÍSTICA ( CONT. ONLINE) - Santiago/19_gra_cuidados_dentro_campus.png'!
# Gráfico guardado en 'carreras\INGENIERÍA  EN LOGÍSTICA ( CONT. ONLINE) - Santiago/23_gra_tramo_registro_social.png'!
# Gráfico guardado en 'carreras\INGENIERÍA  EN LOGÍSTICA ( CONT. ONLINE) - Santiago/24_gra_cuantos_convive_2023.png'!
# Gráfico guardado en 'carreras\INGENIERÍA  EN LOGÍSTICA ( CONT. ONLINE) - Santiago/26_gra_situacion_laboral.png'!
# Gráfico guardado en 'carreras\INGENIERÍA  EN LOGÍSTICA ( CONT. ONLINE) - Santiago/27_gra_horas_semanales_laboral.png'!
# Gráfico guardado en 'carreras\INGENIERÍA  EN LOGÍSTICA ( CONT. ONLINE) - Santiago/28_gra_dependencia_grupo_familiar.png'!
# Gráfico guardado en 'carreras\INGENIERÍA  EN LOGÍSTICA ( CONT. ONLINE) - Santiago/31_gra_horas_cuidado_estudiante.png'!
# Gráfico guardado en 'carreras\INGENIERÍA  EN LOGÍSTICA ( CONT. ONLINE) - Santiago/33_gra_acceso_medio_digital.png'!
# Gráfico guardado en 'carreras\INGENIERÍA  EN LOGÍSTICA ( CONT. ONLINE) - Santiago/34_gra_uso_exclusivo_medio_digital.png'!
# Gráfico guardado en 'carreras\INGENIERÍA  EN LOGÍSTICA ( CONT. ONLINE) - Santiago/35_gra_acceso_internet_alumno.png'!
# Gráfico guardado en 'carreras\INGENIERÍA  EN LOGÍSTICA ( CONT. ONLINE) - Santiago/37_gra_dificultad_trayecto.png'!
# Gráfico guardado en 'carreras\INGENIERÍA  EN LOGÍSTICA ( CONT. ONLINE) - Santiago/42_gra_requiere_pares_mentores.png'!
# Gráfico guardado en 'carreras\INGENIERÍA  EN LOGÍSTICA ( CONT. ONLINE) - Santiago/43_gra_tiempo_traslado.png'!
# Gráfico guardado en 'carreras\INGENIERÍA  EN LOGÍSTICA ( CONT. ONLINE) - Santiago/44_gra_medio_transporte.png'!
# Gráfico guardado en 'carreras\INGENIERÍA  EN LOGÍSTICA ( CONT. ONLINE) - Santiago/47_gra_practica_deporte_hobbie.png'!
# Gráfico guardado en 'carreras\INGENIERÍA  EN LOGÍSTICA ( CONT. ONLINE) - Santiago/12_gra_orientacion_sexual.png'!
# Gráfico guardado en 'carreras\INGENIERÍA  EN LOGÍSTICA ( CONT. ONLINE) - Santiago/17_gra_condicion_dificultad_clases.png'!
# Gráfico guardado en 'carreras\INGENIERÍA  EN LOGÍSTICA ( CONT. ONLINE) - Santiago/25_gra_situacion_laboral_jefe_hogar.png'!
# Gráfico guardado en 'carreras\INGENIERÍA  EN LOGÍSTICA ( CONT. ONLINE) - Santiago/32_gra_lugar_estudio_alumno.png'!
# Gráfico guardado en 'carreras\INGENIERÍA  EN LOGÍSTICA ( CONT. ONLINE) - Santiago/11_gra_genero_identifica_mfo.png'!
# Gráfico guardado en 'carreras\DERECHO - Santiago/1_gra_declaracion_uso_datos.png'!
# Gráfico guardado en 'carreras\DERECHO - Santiago/2_gra_t_desde_egreso.png'!
# Gráfico guardado en 'carreras\DERECHO - Santiago/4_gra_estudia_antes_edsup.png'!
# Gráfico guardado en 'carreras\DERECHO - Santiago/5_gra_finalizo_est_antes_edsup.png'!
# Gráfico guardado en 'carreras\DERECHO - Santiago/6_gra_estado_civil.png'!
# Gráfico guardado en 'carreras\DERECHO - Santiago/7_gra_tiene_hijos.png'!
# Gráfico guardado en 'carreras\DERECHO - Santiago/8_gra_red_apoyo.png'!
# Gráfico guardado en 'carreras\DERECHO - Santiago/10_gra_etnia.png'!
# Gráfico guardado en 'carreras\DERECHO - Santiago/14_gra_declara_discapacidad.png'!
# Gráfico guardado en 'carreras\DERECHO - Santiago/19_gra_cuidados_dentro_campus.png'!
# Gráfico guardado en 'carreras\DERECHO - Santiago/23_gra_tramo_registro_social.png'!
# Gráfico guardado en 'carreras\DERECHO - Santiago/24_gra_cuantos_convive_2023.png'!
# Gráfico guardado en 'carreras\DERECHO - Santiago/26_gra_situacion_laboral.png'!
# Gráfico guardado en 'carreras\DERECHO - Santiago/27_gra_horas_semanales_laboral.png'!
# Gráfico guardado en 'carreras\DERECHO - Santiago/28_gra_dependencia_grupo_familiar.png'!
# Gráfico guardado en 'carreras\DERECHO - Santiago/31_gra_horas_cuidado_estudiante.png'!
# Gráfico guardado en 'carreras\DERECHO - Santiago/33_gra_acceso_medio_digital.png'!
# Gráfico guardado en 'carreras\DERECHO - Santiago/34_gra_uso_exclusivo_medio_digital.png'!
# Gráfico guardado en 'carreras\DERECHO - Santiago/35_gra_acceso_internet_alumno.png'!
# Gráfico guardado en 'carreras\DERECHO - Santiago/37_gra_dificultad_trayecto.png'!
# Gráfico guardado en 'carreras\DERECHO - Santiago/42_gra_requiere_pares_mentores.png'!
# Gráfico guardado en 'carreras\DERECHO - Santiago/43_gra_tiempo_traslado.png'!
# Gráfico guardado en 'carreras\DERECHO - Santiago/44_gra_medio_transporte.png'!
# Gráfico guardado en 'carreras\DERECHO - Santiago/47_gra_practica_deporte_hobbie.png'!
# Gráfico guardado en 'carreras\DERECHO - Santiago/12_gra_orientacion_sexual.png'!
# Gráfico guardado en 'carreras\DERECHO - Santiago/17_gra_condicion_dificultad_clases.png'!
# Gráfico guardado en 'carreras\DERECHO - Santiago/25_gra_situacion_laboral_jefe_hogar.png'!
# Gráfico guardado en 'carreras\DERECHO - Santiago/32_gra_lugar_estudio_alumno.png'!
# Gráfico guardado en 'carreras\DERECHO - Santiago/11_gra_genero_identifica_mfo.png'!
# Gráfico guardado en 'carreras\ING. PREVENCIÓN EN RIESGOS CON.(ON-LINE) - Santiago/1_gra_declaracion_uso_datos.png'!
# Gráfico guardado en 'carreras\ING. PREVENCIÓN EN RIESGOS CON.(ON-LINE) - Santiago/2_gra_t_desde_egreso.png'!
# Gráfico guardado en 'carreras\ING. PREVENCIÓN EN RIESGOS CON.(ON-LINE) - Santiago/4_gra_estudia_antes_edsup.png'!
# Gráfico guardado en 'carreras\ING. PREVENCIÓN EN RIESGOS CON.(ON-LINE) - Santiago/5_gra_finalizo_est_antes_edsup.png'!
# Gráfico guardado en 'carreras\ING. PREVENCIÓN EN RIESGOS CON.(ON-LINE) - Santiago/6_gra_estado_civil.png'!
# Gráfico guardado en 'carreras\ING. PREVENCIÓN EN RIESGOS CON.(ON-LINE) - Santiago/7_gra_tiene_hijos.png'!
# Gráfico guardado en 'carreras\ING. PREVENCIÓN EN RIESGOS CON.(ON-LINE) - Santiago/8_gra_red_apoyo.png'!
# Gráfico guardado en 'carreras\ING. PREVENCIÓN EN RIESGOS CON.(ON-LINE) - Santiago/10_gra_etnia.png'!
# Gráfico guardado en 'carreras\ING. PREVENCIÓN EN RIESGOS CON.(ON-LINE) - Santiago/14_gra_declara_discapacidad.png'!
# Gráfico guardado en 'carreras\ING. PREVENCIÓN EN RIESGOS CON.(ON-LINE) - Santiago/19_gra_cuidados_dentro_campus.png'!
# Gráfico guardado en 'carreras\ING. PREVENCIÓN EN RIESGOS CON.(ON-LINE) - Santiago/23_gra_tramo_registro_social.png'!
# Gráfico guardado en 'carreras\ING. PREVENCIÓN EN RIESGOS CON.(ON-LINE) - Santiago/24_gra_cuantos_convive_2023.png'!
# Gráfico guardado en 'carreras\ING. PREVENCIÓN EN RIESGOS CON.(ON-LINE) - Santiago/26_gra_situacion_laboral.png'!
# Gráfico guardado en 'carreras\ING. PREVENCIÓN EN RIESGOS CON.(ON-LINE) - Santiago/27_gra_horas_semanales_laboral.png'!
# Gráfico guardado en 'carreras\ING. PREVENCIÓN EN RIESGOS CON.(ON-LINE) - Santiago/28_gra_dependencia_grupo_familiar.png'!
# Gráfico guardado en 'carreras\ING. PREVENCIÓN EN RIESGOS CON.(ON-LINE) - Santiago/31_gra_horas_cuidado_estudiante.png'!
# Gráfico guardado en 'carreras\ING. PREVENCIÓN EN RIESGOS CON.(ON-LINE) - Santiago/33_gra_acceso_medio_digital.png'!
# Gráfico guardado en 'carreras\ING. PREVENCIÓN EN RIESGOS CON.(ON-LINE) - Santiago/34_gra_uso_exclusivo_medio_digital.png'!
# Gráfico guardado en 'carreras\ING. PREVENCIÓN EN RIESGOS CON.(ON-LINE) - Santiago/35_gra_acceso_internet_alumno.png'!
# Gráfico guardado en 'carreras\ING. PREVENCIÓN EN RIESGOS CON.(ON-LINE) - Santiago/37_gra_dificultad_trayecto.png'!
# Gráfico guardado en 'carreras\ING. PREVENCIÓN EN RIESGOS CON.(ON-LINE) - Santiago/42_gra_requiere_pares_mentores.png'!
# Gráfico guardado en 'carreras\ING. PREVENCIÓN EN RIESGOS CON.(ON-LINE) - Santiago/43_gra_tiempo_traslado.png'!
# Gráfico guardado en 'carreras\ING. PREVENCIÓN EN RIESGOS CON.(ON-LINE) - Santiago/44_gra_medio_transporte.png'!
# Gráfico guardado en 'carreras\ING. PREVENCIÓN EN RIESGOS CON.(ON-LINE) - Santiago/47_gra_practica_deporte_hobbie.png'!
# Gráfico guardado en 'carreras\ING. PREVENCIÓN EN RIESGOS CON.(ON-LINE) - Santiago/12_gra_orientacion_sexual.png'!
# Gráfico guardado en 'carreras\ING. PREVENCIÓN EN RIESGOS CON.(ON-LINE) - Santiago/17_gra_condicion_dificultad_clases.png'!
# Gráfico guardado en 'carreras\ING. PREVENCIÓN EN RIESGOS CON.(ON-LINE) - Santiago/25_gra_situacion_laboral_jefe_hogar.png'!
# Gráfico guardado en 'carreras\ING. PREVENCIÓN EN RIESGOS CON.(ON-LINE) - Santiago/32_gra_lugar_estudio_alumno.png'!
# Gráfico guardado en 'carreras\ING. PREVENCIÓN EN RIESGOS CON.(ON-LINE) - Santiago/11_gra_genero_identifica_mfo.png'!
# Gráfico guardado en 'carreras\INGENIERÍA COMERCIAL (DIURNO) - Santiago/1_gra_declaracion_uso_datos.png'!
# Gráfico guardado en 'carreras\INGENIERÍA COMERCIAL (DIURNO) - Santiago/2_gra_t_desde_egreso.png'!
# Gráfico guardado en 'carreras\INGENIERÍA COMERCIAL (DIURNO) - Santiago/4_gra_estudia_antes_edsup.png'!
# Gráfico guardado en 'carreras\INGENIERÍA COMERCIAL (DIURNO) - Santiago/5_gra_finalizo_est_antes_edsup.png'!
# Gráfico guardado en 'carreras\INGENIERÍA COMERCIAL (DIURNO) - Santiago/6_gra_estado_civil.png'!
# Gráfico guardado en 'carreras\INGENIERÍA COMERCIAL (DIURNO) - Santiago/7_gra_tiene_hijos.png'!
# Gráfico guardado en 'carreras\INGENIERÍA COMERCIAL (DIURNO) - Santiago/8_gra_red_apoyo.png'!
# Gráfico guardado en 'carreras\INGENIERÍA COMERCIAL (DIURNO) - Santiago/10_gra_etnia.png'!
# Gráfico guardado en 'carreras\INGENIERÍA COMERCIAL (DIURNO) - Santiago/14_gra_declara_discapacidad.png'!
# Gráfico guardado en 'carreras\INGENIERÍA COMERCIAL (DIURNO) - Santiago/19_gra_cuidados_dentro_campus.png'!
# Gráfico guardado en 'carreras\INGENIERÍA COMERCIAL (DIURNO) - Santiago/23_gra_tramo_registro_social.png'!
# Gráfico guardado en 'carreras\INGENIERÍA COMERCIAL (DIURNO) - Santiago/24_gra_cuantos_convive_2023.png'!
# Gráfico guardado en 'carreras\INGENIERÍA COMERCIAL (DIURNO) - Santiago/26_gra_situacion_laboral.png'!
# Gráfico guardado en 'carreras\INGENIERÍA COMERCIAL (DIURNO) - Santiago/27_gra_horas_semanales_laboral.png'!
# Gráfico guardado en 'carreras\INGENIERÍA COMERCIAL (DIURNO) - Santiago/28_gra_dependencia_grupo_familiar.png'!
# Gráfico guardado en 'carreras\INGENIERÍA COMERCIAL (DIURNO) - Santiago/31_gra_horas_cuidado_estudiante.png'!
# Gráfico guardado en 'carreras\INGENIERÍA COMERCIAL (DIURNO) - Santiago/33_gra_acceso_medio_digital.png'!
# Gráfico guardado en 'carreras\INGENIERÍA COMERCIAL (DIURNO) - Santiago/34_gra_uso_exclusivo_medio_digital.png'!
# Gráfico guardado en 'carreras\INGENIERÍA COMERCIAL (DIURNO) - Santiago/35_gra_acceso_internet_alumno.png'!
# Gráfico guardado en 'carreras\INGENIERÍA COMERCIAL (DIURNO) - Santiago/37_gra_dificultad_trayecto.png'!
# Gráfico guardado en 'carreras\INGENIERÍA COMERCIAL (DIURNO) - Santiago/42_gra_requiere_pares_mentores.png'!
# Gráfico guardado en 'carreras\INGENIERÍA COMERCIAL (DIURNO) - Santiago/43_gra_tiempo_traslado.png'!
# Gráfico guardado en 'carreras\INGENIERÍA COMERCIAL (DIURNO) - Santiago/44_gra_medio_transporte.png'!
# Gráfico guardado en 'carreras\INGENIERÍA COMERCIAL (DIURNO) - Santiago/47_gra_practica_deporte_hobbie.png'!
# Gráfico guardado en 'carreras\INGENIERÍA COMERCIAL (DIURNO) - Santiago/12_gra_orientacion_sexual.png'!
# Gráfico guardado en 'carreras\INGENIERÍA COMERCIAL (DIURNO) - Santiago/17_gra_condicion_dificultad_clases.png'!
# Gráfico guardado en 'carreras\INGENIERÍA COMERCIAL (DIURNO) - Santiago/25_gra_situacion_laboral_jefe_hogar.png'!
# Gráfico guardado en 'carreras\INGENIERÍA COMERCIAL (DIURNO) - Santiago/32_gra_lugar_estudio_alumno.png'!
# Gráfico guardado en 'carreras\INGENIERÍA COMERCIAL (DIURNO) - Santiago/11_gra_genero_identifica_mfo.png'!
# Gráfico guardado en 'carreras\ENFERMERÍA - Santiago/1_gra_declaracion_uso_datos.png'!
# Gráfico guardado en 'carreras\ENFERMERÍA - Santiago/2_gra_t_desde_egreso.png'!
# Gráfico guardado en 'carreras\ENFERMERÍA - Santiago/4_gra_estudia_antes_edsup.png'!
# Gráfico guardado en 'carreras\ENFERMERÍA - Santiago/5_gra_finalizo_est_antes_edsup.png'!
# Gráfico guardado en 'carreras\ENFERMERÍA - Santiago/6_gra_estado_civil.png'!
# Gráfico guardado en 'carreras\ENFERMERÍA - Santiago/7_gra_tiene_hijos.png'!
# Gráfico guardado en 'carreras\ENFERMERÍA - Santiago/8_gra_red_apoyo.png'!
# Gráfico guardado en 'carreras\ENFERMERÍA - Santiago/10_gra_etnia.png'!
# Gráfico guardado en 'carreras\ENFERMERÍA - Santiago/14_gra_declara_discapacidad.png'!
# Gráfico guardado en 'carreras\ENFERMERÍA - Santiago/19_gra_cuidados_dentro_campus.png'!
# Gráfico guardado en 'carreras\ENFERMERÍA - Santiago/23_gra_tramo_registro_social.png'!
# Gráfico guardado en 'carreras\ENFERMERÍA - Santiago/24_gra_cuantos_convive_2023.png'!
# Gráfico guardado en 'carreras\ENFERMERÍA - Santiago/26_gra_situacion_laboral.png'!
# Gráfico guardado en 'carreras\ENFERMERÍA - Santiago/27_gra_horas_semanales_laboral.png'!
# Gráfico guardado en 'carreras\ENFERMERÍA - Santiago/28_gra_dependencia_grupo_familiar.png'!
# Gráfico guardado en 'carreras\ENFERMERÍA - Santiago/31_gra_horas_cuidado_estudiante.png'!
# Gráfico guardado en 'carreras\ENFERMERÍA - Santiago/33_gra_acceso_medio_digital.png'!
# Gráfico guardado en 'carreras\ENFERMERÍA - Santiago/34_gra_uso_exclusivo_medio_digital.png'!
# Gráfico guardado en 'carreras\ENFERMERÍA - Santiago/35_gra_acceso_internet_alumno.png'!
# Gráfico guardado en 'carreras\ENFERMERÍA - Santiago/37_gra_dificultad_trayecto.png'!
# Gráfico guardado en 'carreras\ENFERMERÍA - Santiago/42_gra_requiere_pares_mentores.png'!
# Gráfico guardado en 'carreras\ENFERMERÍA - Santiago/43_gra_tiempo_traslado.png'!
# Gráfico guardado en 'carreras\ENFERMERÍA - Santiago/44_gra_medio_transporte.png'!
# Gráfico guardado en 'carreras\ENFERMERÍA - Santiago/47_gra_practica_deporte_hobbie.png'!
# Gráfico guardado en 'carreras\ENFERMERÍA - Santiago/12_gra_orientacion_sexual.png'!
# Gráfico guardado en 'carreras\ENFERMERÍA - Santiago/17_gra_condicion_dificultad_clases.png'!
# Gráfico guardado en 'carreras\ENFERMERÍA - Santiago/25_gra_situacion_laboral_jefe_hogar.png'!
# Gráfico guardado en 'carreras\ENFERMERÍA - Santiago/32_gra_lugar_estudio_alumno.png'!
# Gráfico guardado en 'carreras\ENFERMERÍA - Santiago/11_gra_genero_identifica_mfo.png'!
# Gráfico guardado en 'carreras\INGENIERÍA  CIVIL  EN  COMP. E  INF. - Santiago/1_gra_declaracion_uso_datos.png'!
# Gráfico guardado en 'carreras\INGENIERÍA  CIVIL  EN  COMP. E  INF. - Santiago/2_gra_t_desde_egreso.png'!
# Gráfico guardado en 'carreras\INGENIERÍA  CIVIL  EN  COMP. E  INF. - Santiago/4_gra_estudia_antes_edsup.png'!
# Gráfico guardado en 'carreras\INGENIERÍA  CIVIL  EN  COMP. E  INF. - Santiago/5_gra_finalizo_est_antes_edsup.png'!
# Gráfico guardado en 'carreras\INGENIERÍA  CIVIL  EN  COMP. E  INF. - Santiago/6_gra_estado_civil.png'!
# Gráfico guardado en 'carreras\INGENIERÍA  CIVIL  EN  COMP. E  INF. - Santiago/7_gra_tiene_hijos.png'!
# Gráfico guardado en 'carreras\INGENIERÍA  CIVIL  EN  COMP. E  INF. - Santiago/8_gra_red_apoyo.png'!
# Gráfico guardado en 'carreras\INGENIERÍA  CIVIL  EN  COMP. E  INF. - Santiago/10_gra_etnia.png'!
# Gráfico guardado en 'carreras\INGENIERÍA  CIVIL  EN  COMP. E  INF. - Santiago/14_gra_declara_discapacidad.png'!
# Gráfico guardado en 'carreras\INGENIERÍA  CIVIL  EN  COMP. E  INF. - Santiago/19_gra_cuidados_dentro_campus.png'!
# Gráfico guardado en 'carreras\INGENIERÍA  CIVIL  EN  COMP. E  INF. - Santiago/23_gra_tramo_registro_social.png'!
# Gráfico guardado en 'carreras\INGENIERÍA  CIVIL  EN  COMP. E  INF. - Santiago/24_gra_cuantos_convive_2023.png'!
# Gráfico guardado en 'carreras\INGENIERÍA  CIVIL  EN  COMP. E  INF. - Santiago/26_gra_situacion_laboral.png'!
# Gráfico guardado en 'carreras\INGENIERÍA  CIVIL  EN  COMP. E  INF. - Santiago/27_gra_horas_semanales_laboral.png'!
# Gráfico guardado en 'carreras\INGENIERÍA  CIVIL  EN  COMP. E  INF. - Santiago/28_gra_dependencia_grupo_familiar.png'!
# Gráfico guardado en 'carreras\INGENIERÍA  CIVIL  EN  COMP. E  INF. - Santiago/31_gra_horas_cuidado_estudiante.png'!
# Gráfico guardado en 'carreras\INGENIERÍA  CIVIL  EN  COMP. E  INF. - Santiago/33_gra_acceso_medio_digital.png'!
# Gráfico guardado en 'carreras\INGENIERÍA  CIVIL  EN  COMP. E  INF. - Santiago/34_gra_uso_exclusivo_medio_digital.png'!
# Gráfico guardado en 'carreras\INGENIERÍA  CIVIL  EN  COMP. E  INF. - Santiago/35_gra_acceso_internet_alumno.png'!
# Gráfico guardado en 'carreras\INGENIERÍA  CIVIL  EN  COMP. E  INF. - Santiago/37_gra_dificultad_trayecto.png'!
# Gráfico guardado en 'carreras\INGENIERÍA  CIVIL  EN  COMP. E  INF. - Santiago/42_gra_requiere_pares_mentores.png'!
# Gráfico guardado en 'carreras\INGENIERÍA  CIVIL  EN  COMP. E  INF. - Santiago/43_gra_tiempo_traslado.png'!
# Gráfico guardado en 'carreras\INGENIERÍA  CIVIL  EN  COMP. E  INF. - Santiago/44_gra_medio_transporte.png'!
# Gráfico guardado en 'carreras\INGENIERÍA  CIVIL  EN  COMP. E  INF. - Santiago/47_gra_practica_deporte_hobbie.png'!
# Gráfico guardado en 'carreras\INGENIERÍA  CIVIL  EN  COMP. E  INF. - Santiago/12_gra_orientacion_sexual.png'!
# Gráfico guardado en 'carreras\INGENIERÍA  CIVIL  EN  COMP. E  INF. - Santiago/17_gra_condicion_dificultad_clases.png'!
# Gráfico guardado en 'carreras\INGENIERÍA  CIVIL  EN  COMP. E  INF. - Santiago/25_gra_situacion_laboral_jefe_hogar.png'!
# Gráfico guardado en 'carreras\INGENIERÍA  CIVIL  EN  COMP. E  INF. - Santiago/32_gra_lugar_estudio_alumno.png'!
# Gráfico guardado en 'carreras\INGENIERÍA  CIVIL  EN  COMP. E  INF. - Santiago/11_gra_genero_identifica_mfo.png'!
# Gráfico guardado en 'carreras\OBSTETRICIA Y PUERICULTURA - Santiago/1_gra_declaracion_uso_datos.png'!
# Gráfico guardado en 'carreras\OBSTETRICIA Y PUERICULTURA - Santiago/2_gra_t_desde_egreso.png'!
# Gráfico guardado en 'carreras\OBSTETRICIA Y PUERICULTURA - Santiago/4_gra_estudia_antes_edsup.png'!
# Gráfico guardado en 'carreras\OBSTETRICIA Y PUERICULTURA - Santiago/5_gra_finalizo_est_antes_edsup.png'!
# Gráfico guardado en 'carreras\OBSTETRICIA Y PUERICULTURA - Santiago/6_gra_estado_civil.png'!
# Gráfico guardado en 'carreras\OBSTETRICIA Y PUERICULTURA - Santiago/7_gra_tiene_hijos.png'!
# No hay valores únicos disponibles para la columna 'red_apoyo'.
# Gráfico guardado en 'carreras\OBSTETRICIA Y PUERICULTURA - Santiago/10_gra_etnia.png'!
# Gráfico guardado en 'carreras\OBSTETRICIA Y PUERICULTURA - Santiago/14_gra_declara_discapacidad.png'!
# Gráfico guardado en 'carreras\OBSTETRICIA Y PUERICULTURA - Santiago/19_gra_cuidados_dentro_campus.png'!
# Gráfico guardado en 'carreras\OBSTETRICIA Y PUERICULTURA - Santiago/23_gra_tramo_registro_social.png'!
# Gráfico guardado en 'carreras\OBSTETRICIA Y PUERICULTURA - Santiago/24_gra_cuantos_convive_2023.png'!
# Gráfico guardado en 'carreras\OBSTETRICIA Y PUERICULTURA - Santiago/26_gra_situacion_laboral.png'!
# Gráfico guardado en 'carreras\OBSTETRICIA Y PUERICULTURA - Santiago/27_gra_horas_semanales_laboral.png'!
# Gráfico guardado en 'carreras\OBSTETRICIA Y PUERICULTURA - Santiago/28_gra_dependencia_grupo_familiar.png'!
# Gráfico guardado en 'carreras\OBSTETRICIA Y PUERICULTURA - Santiago/31_gra_horas_cuidado_estudiante.png'!
# Gráfico guardado en 'carreras\OBSTETRICIA Y PUERICULTURA - Santiago/33_gra_acceso_medio_digital.png'!
# Gráfico guardado en 'carreras\OBSTETRICIA Y PUERICULTURA - Santiago/34_gra_uso_exclusivo_medio_digital.png'!
# Gráfico guardado en 'carreras\OBSTETRICIA Y PUERICULTURA - Santiago/35_gra_acceso_internet_alumno.png'!
# Gráfico guardado en 'carreras\OBSTETRICIA Y PUERICULTURA - Santiago/37_gra_dificultad_trayecto.png'!
# Gráfico guardado en 'carreras\OBSTETRICIA Y PUERICULTURA - Santiago/42_gra_requiere_pares_mentores.png'!
# Gráfico guardado en 'carreras\OBSTETRICIA Y PUERICULTURA - Santiago/43_gra_tiempo_traslado.png'!
# Gráfico guardado en 'carreras\OBSTETRICIA Y PUERICULTURA - Santiago/44_gra_medio_transporte.png'!
# Gráfico guardado en 'carreras\OBSTETRICIA Y PUERICULTURA - Santiago/47_gra_practica_deporte_hobbie.png'!
# Gráfico guardado en 'carreras\OBSTETRICIA Y PUERICULTURA - Santiago/12_gra_orientacion_sexual.png'!
# Gráfico guardado en 'carreras\OBSTETRICIA Y PUERICULTURA - Santiago/17_gra_condicion_dificultad_clases.png'!
# Gráfico guardado en 'carreras\OBSTETRICIA Y PUERICULTURA - Santiago/25_gra_situacion_laboral_jefe_hogar.png'!
# Gráfico guardado en 'carreras\OBSTETRICIA Y PUERICULTURA - Santiago/32_gra_lugar_estudio_alumno.png'!
# Gráfico guardado en 'carreras\OBSTETRICIA Y PUERICULTURA - Santiago/11_gra_genero_identifica_mfo.png'!
# Gráfico guardado en 'carreras\ENFERMERÍA - Temuco/1_gra_declaracion_uso_datos.png'!
# Gráfico guardado en 'carreras\ENFERMERÍA - Temuco/2_gra_t_desde_egreso.png'!
# Gráfico guardado en 'carreras\ENFERMERÍA - Temuco/4_gra_estudia_antes_edsup.png'!
# Gráfico guardado en 'carreras\ENFERMERÍA - Temuco/5_gra_finalizo_est_antes_edsup.png'!
# Gráfico guardado en 'carreras\ENFERMERÍA - Temuco/6_gra_estado_civil.png'!
# Gráfico guardado en 'carreras\ENFERMERÍA - Temuco/7_gra_tiene_hijos.png'!
# No hay valores únicos disponibles para la columna 'red_apoyo'.
# Gráfico guardado en 'carreras\ENFERMERÍA - Temuco/10_gra_etnia.png'!
# Gráfico guardado en 'carreras\ENFERMERÍA - Temuco/14_gra_declara_discapacidad.png'!
# Gráfico guardado en 'carreras\ENFERMERÍA - Temuco/19_gra_cuidados_dentro_campus.png'!
# Gráfico guardado en 'carreras\ENFERMERÍA - Temuco/23_gra_tramo_registro_social.png'!
# Gráfico guardado en 'carreras\ENFERMERÍA - Temuco/24_gra_cuantos_convive_2023.png'!
# Gráfico guardado en 'carreras\ENFERMERÍA - Temuco/26_gra_situacion_laboral.png'!
# Gráfico guardado en 'carreras\ENFERMERÍA - Temuco/27_gra_horas_semanales_laboral.png'!
# Gráfico guardado en 'carreras\ENFERMERÍA - Temuco/28_gra_dependencia_grupo_familiar.png'!
# Gráfico guardado en 'carreras\ENFERMERÍA - Temuco/31_gra_horas_cuidado_estudiante.png'!
# Gráfico guardado en 'carreras\ENFERMERÍA - Temuco/33_gra_acceso_medio_digital.png'!
# Gráfico guardado en 'carreras\ENFERMERÍA - Temuco/34_gra_uso_exclusivo_medio_digital.png'!
# Gráfico guardado en 'carreras\ENFERMERÍA - Temuco/35_gra_acceso_internet_alumno.png'!
# Gráfico guardado en 'carreras\ENFERMERÍA - Temuco/37_gra_dificultad_trayecto.png'!
# Gráfico guardado en 'carreras\ENFERMERÍA - Temuco/42_gra_requiere_pares_mentores.png'!
# Gráfico guardado en 'carreras\ENFERMERÍA - Temuco/43_gra_tiempo_traslado.png'!
# Gráfico guardado en 'carreras\ENFERMERÍA - Temuco/44_gra_medio_transporte.png'!
# Gráfico guardado en 'carreras\ENFERMERÍA - Temuco/47_gra_practica_deporte_hobbie.png'!
# Gráfico guardado en 'carreras\ENFERMERÍA - Temuco/12_gra_orientacion_sexual.png'!
# Gráfico guardado en 'carreras\ENFERMERÍA - Temuco/17_gra_condicion_dificultad_clases.png'!
# Gráfico guardado en 'carreras\ENFERMERÍA - Temuco/25_gra_situacion_laboral_jefe_hogar.png'!
# Gráfico guardado en 'carreras\ENFERMERÍA - Temuco/32_gra_lugar_estudio_alumno.png'!
# Gráfico guardado en 'carreras\ENFERMERÍA - Temuco/11_gra_genero_identifica_mfo.png'!
# Gráfico guardado en 'carreras\INGENIERÍA CIVIL INDUSTRIAL - Santiago/1_gra_declaracion_uso_datos.png'!
# Gráfico guardado en 'carreras\INGENIERÍA CIVIL INDUSTRIAL - Santiago/2_gra_t_desde_egreso.png'!
# Gráfico guardado en 'carreras\INGENIERÍA CIVIL INDUSTRIAL - Santiago/4_gra_estudia_antes_edsup.png'!
# Gráfico guardado en 'carreras\INGENIERÍA CIVIL INDUSTRIAL - Santiago/5_gra_finalizo_est_antes_edsup.png'!
# Gráfico guardado en 'carreras\INGENIERÍA CIVIL INDUSTRIAL - Santiago/6_gra_estado_civil.png'!
# Gráfico guardado en 'carreras\INGENIERÍA CIVIL INDUSTRIAL - Santiago/7_gra_tiene_hijos.png'!
# No hay valores únicos disponibles para la columna 'red_apoyo'.
# Gráfico guardado en 'carreras\INGENIERÍA CIVIL INDUSTRIAL - Santiago/10_gra_etnia.png'!
# Gráfico guardado en 'carreras\INGENIERÍA CIVIL INDUSTRIAL - Santiago/14_gra_declara_discapacidad.png'!
# Gráfico guardado en 'carreras\INGENIERÍA CIVIL INDUSTRIAL - Santiago/19_gra_cuidados_dentro_campus.png'!
# Gráfico guardado en 'carreras\INGENIERÍA CIVIL INDUSTRIAL - Santiago/23_gra_tramo_registro_social.png'!
# Gráfico guardado en 'carreras\INGENIERÍA CIVIL INDUSTRIAL - Santiago/24_gra_cuantos_convive_2023.png'!
# Gráfico guardado en 'carreras\INGENIERÍA CIVIL INDUSTRIAL - Santiago/26_gra_situacion_laboral.png'!
# Gráfico guardado en 'carreras\INGENIERÍA CIVIL INDUSTRIAL - Santiago/27_gra_horas_semanales_laboral.png'!
# Gráfico guardado en 'carreras\INGENIERÍA CIVIL INDUSTRIAL - Santiago/28_gra_dependencia_grupo_familiar.png'!
# Gráfico guardado en 'carreras\INGENIERÍA CIVIL INDUSTRIAL - Santiago/31_gra_horas_cuidado_estudiante.png'!
# Gráfico guardado en 'carreras\INGENIERÍA CIVIL INDUSTRIAL - Santiago/33_gra_acceso_medio_digital.png'!
# Gráfico guardado en 'carreras\INGENIERÍA CIVIL INDUSTRIAL - Santiago/34_gra_uso_exclusivo_medio_digital.png'!
# Gráfico guardado en 'carreras\INGENIERÍA CIVIL INDUSTRIAL - Santiago/35_gra_acceso_internet_alumno.png'!
# Gráfico guardado en 'carreras\INGENIERÍA CIVIL INDUSTRIAL - Santiago/37_gra_dificultad_trayecto.png'!
# Gráfico guardado en 'carreras\INGENIERÍA CIVIL INDUSTRIAL - Santiago/42_gra_requiere_pares_mentores.png'!
# Gráfico guardado en 'carreras\INGENIERÍA CIVIL INDUSTRIAL - Santiago/43_gra_tiempo_traslado.png'!
# Gráfico guardado en 'carreras\INGENIERÍA CIVIL INDUSTRIAL - Santiago/44_gra_medio_transporte.png'!
# Gráfico guardado en 'carreras\INGENIERÍA CIVIL INDUSTRIAL - Santiago/47_gra_practica_deporte_hobbie.png'!
# Gráfico guardado en 'carreras\INGENIERÍA CIVIL INDUSTRIAL - Santiago/12_gra_orientacion_sexual.png'!
# Gráfico guardado en 'carreras\INGENIERÍA CIVIL INDUSTRIAL - Santiago/17_gra_condicion_dificultad_clases.png'!
# ...
# Gráfico guardado en 'carreras\INTERP. MUSICAL SUPERIOR EN CORNO - Santiago/35_gra_acceso_internet_alumno.png'!
# Gráfico guardado en 'carreras\INTERP. MUSICAL SUPERIOR EN CORNO - Santiago/37_gra_dificultad_trayecto.png'!
# Gráfico guardado en 'carreras\INTERP. MUSICAL SUPERIOR EN CORNO - Santiago/42_gra_requiere_pares_mentores.png'!
# Gráfico guardado en 'carreras\INTERP. MUSICAL SUPERIOR EN CORNO - Santiago/43_gra_tiempo_traslado.png'!
# Gráfico guardado en 'carreras\INTERP. MUSICAL SUPERIOR EN CORNO - Santiago/44_gra_medio_transporte.png'!
# Gráfico guardado en 'carreras\INTERP. MUSICAL SUPERIOR EN CORNO - Santiago/47_gra_practica_deporte_hobbie.png'!
# Gráfico guardado en 'carreras\INTERP. MUSICAL SUPERIOR EN CORNO - Santiago/12_gra_orientacion_sexual.png'!
# Gráfico guardado en 'carreras\INTERP. MUSICAL SUPERIOR EN CORNO - Santiago/17_gra_condicion_dificultad_clases.png'!
# Gráfico guardado en 'carreras\INTERP. MUSICAL SUPERIOR EN CORNO - Santiago/25_gra_situacion_laboral_jefe_hogar.png'!
# Gráfico guardado en 'carreras\INTERP. MUSICAL SUPERIOR EN CORNO - Santiago/32_gra_lugar_estudio_alumno.png'!
# Gráfico guardado en 'carreras\INTERP. MUSICAL SUPERIOR EN CORNO - Santiago/11_gra_genero_identifica_mfo.png'!
# Gráfico guardado en 'carreras\CONSTRUCCIÓN  CIVIL - Santiago/1_gra_declaracion_uso_datos.png'!
# Gráfico guardado en 'carreras\CONSTRUCCIÓN  CIVIL - Santiago/2_gra_t_desde_egreso.png'!
# Gráfico guardado en 'carreras\CONSTRUCCIÓN  CIVIL - Santiago/4_gra_estudia_antes_edsup.png'!
# Gráfico guardado en 'carreras\CONSTRUCCIÓN  CIVIL - Santiago/5_gra_finalizo_est_antes_edsup.png'!
# Gráfico guardado en 'carreras\CONSTRUCCIÓN  CIVIL - Santiago/6_gra_estado_civil.png'!
# Gráfico guardado en 'carreras\CONSTRUCCIÓN  CIVIL - Santiago/7_gra_tiene_hijos.png'!
# Gráfico guardado en 'carreras\CONSTRUCCIÓN  CIVIL - Santiago/8_gra_red_apoyo.png'!
# Gráfico guardado en 'carreras\CONSTRUCCIÓN  CIVIL - Santiago/10_gra_etnia.png'!
# Gráfico guardado en 'carreras\CONSTRUCCIÓN  CIVIL - Santiago/14_gra_declara_discapacidad.png'!
# Gráfico guardado en 'carreras\CONSTRUCCIÓN  CIVIL - Santiago/19_gra_cuidados_dentro_campus.png'!
# Gráfico guardado en 'carreras\CONSTRUCCIÓN  CIVIL - Santiago/23_gra_tramo_registro_social.png'!
# Gráfico guardado en 'carreras\CONSTRUCCIÓN  CIVIL - Santiago/24_gra_cuantos_convive_2023.png'!
# Gráfico guardado en 'carreras\CONSTRUCCIÓN  CIVIL - Santiago/26_gra_situacion_laboral.png'!
# Gráfico guardado en 'carreras\CONSTRUCCIÓN  CIVIL - Santiago/27_gra_horas_semanales_laboral.png'!
# Gráfico guardado en 'carreras\CONSTRUCCIÓN  CIVIL - Santiago/28_gra_dependencia_grupo_familiar.png'!
# Gráfico guardado en 'carreras\CONSTRUCCIÓN  CIVIL - Santiago/31_gra_horas_cuidado_estudiante.png'!
# Gráfico guardado en 'carreras\CONSTRUCCIÓN  CIVIL - Santiago/33_gra_acceso_medio_digital.png'!
# Gráfico guardado en 'carreras\CONSTRUCCIÓN  CIVIL - Santiago/34_gra_uso_exclusivo_medio_digital.png'!
# Gráfico guardado en 'carreras\CONSTRUCCIÓN  CIVIL - Santiago/35_gra_acceso_internet_alumno.png'!
# Gráfico guardado en 'carreras\CONSTRUCCIÓN  CIVIL - Santiago/37_gra_dificultad_trayecto.png'!
# Gráfico guardado en 'carreras\CONSTRUCCIÓN  CIVIL - Santiago/42_gra_requiere_pares_mentores.png'!
# Gráfico guardado en 'carreras\CONSTRUCCIÓN  CIVIL - Santiago/43_gra_tiempo_traslado.png'!
# Gráfico guardado en 'carreras\CONSTRUCCIÓN  CIVIL - Santiago/44_gra_medio_transporte.png'!
# Gráfico guardado en 'carreras\CONSTRUCCIÓN  CIVIL - Santiago/47_gra_practica_deporte_hobbie.png'!
# Gráfico guardado en 'carreras\CONSTRUCCIÓN  CIVIL - Santiago/12_gra_orientacion_sexual.png'!
# Gráfico guardado en 'carreras\CONSTRUCCIÓN  CIVIL - Santiago/17_gra_condicion_dificultad_clases.png'!
# Gráfico guardado en 'carreras\CONSTRUCCIÓN  CIVIL - Santiago/25_gra_situacion_laboral_jefe_hogar.png'!
# Gráfico guardado en 'carreras\CONSTRUCCIÓN  CIVIL - Santiago/32_gra_lugar_estudio_alumno.png'!
# Gráfico guardado en 'carreras\CONSTRUCCIÓN  CIVIL - Santiago/11_gra_genero_identifica_mfo.png'!
# Gráfico guardado en 'carreras\INTERPRETE MUSICAL SUPERIOR EN VIOLÍN - Santiago/1_gra_declaracion_uso_datos.png'!
# Gráfico guardado en 'carreras\INTERPRETE MUSICAL SUPERIOR EN VIOLÍN - Santiago/2_gra_t_desde_egreso.png'!
# Gráfico guardado en 'carreras\INTERPRETE MUSICAL SUPERIOR EN VIOLÍN - Santiago/4_gra_estudia_antes_edsup.png'!
# No hay valores únicos disponibles para la columna 'finalizo_est_antes_edsup'.
# Gráfico guardado en 'carreras\INTERPRETE MUSICAL SUPERIOR EN VIOLÍN - Santiago/6_gra_estado_civil.png'!
# Gráfico guardado en 'carreras\INTERPRETE MUSICAL SUPERIOR EN VIOLÍN - Santiago/7_gra_tiene_hijos.png'!
# No hay valores únicos disponibles para la columna 'red_apoyo'.
# Gráfico guardado en 'carreras\INTERPRETE MUSICAL SUPERIOR EN VIOLÍN - Santiago/10_gra_etnia.png'!
# Gráfico guardado en 'carreras\INTERPRETE MUSICAL SUPERIOR EN VIOLÍN - Santiago/14_gra_declara_discapacidad.png'!
# Gráfico guardado en 'carreras\INTERPRETE MUSICAL SUPERIOR EN VIOLÍN - Santiago/19_gra_cuidados_dentro_campus.png'!
# Gráfico guardado en 'carreras\INTERPRETE MUSICAL SUPERIOR EN VIOLÍN - Santiago/23_gra_tramo_registro_social.png'!
# Gráfico guardado en 'carreras\INTERPRETE MUSICAL SUPERIOR EN VIOLÍN - Santiago/24_gra_cuantos_convive_2023.png'!
# Gráfico guardado en 'carreras\INTERPRETE MUSICAL SUPERIOR EN VIOLÍN - Santiago/26_gra_situacion_laboral.png'!
# No hay valores únicos disponibles para la columna 'horas_semanales_laboral'.
# Gráfico guardado en 'carreras\INTERPRETE MUSICAL SUPERIOR EN VIOLÍN - Santiago/28_gra_dependencia_grupo_familiar.png'!
# No hay valores únicos disponibles para la columna 'horas_cuidado_estudiante'.
# Gráfico guardado en 'carreras\INTERPRETE MUSICAL SUPERIOR EN VIOLÍN - Santiago/33_gra_acceso_medio_digital.png'!
# Gráfico guardado en 'carreras\INTERPRETE MUSICAL SUPERIOR EN VIOLÍN - Santiago/34_gra_uso_exclusivo_medio_digital.png'!
# Gráfico guardado en 'carreras\INTERPRETE MUSICAL SUPERIOR EN VIOLÍN - Santiago/35_gra_acceso_internet_alumno.png'!
# Gráfico guardado en 'carreras\INTERPRETE MUSICAL SUPERIOR EN VIOLÍN - Santiago/37_gra_dificultad_trayecto.png'!
# Gráfico guardado en 'carreras\INTERPRETE MUSICAL SUPERIOR EN VIOLÍN - Santiago/42_gra_requiere_pares_mentores.png'!
# Gráfico guardado en 'carreras\INTERPRETE MUSICAL SUPERIOR EN VIOLÍN - Santiago/43_gra_tiempo_traslado.png'!
# Gráfico guardado en 'carreras\INTERPRETE MUSICAL SUPERIOR EN VIOLÍN - Santiago/44_gra_medio_transporte.png'!
# Gráfico guardado en 'carreras\INTERPRETE MUSICAL SUPERIOR EN VIOLÍN - Santiago/47_gra_practica_deporte_hobbie.png'!
# Gráfico guardado en 'carreras\INTERPRETE MUSICAL SUPERIOR EN VIOLÍN - Santiago/12_gra_orientacion_sexual.png'!
# Gráfico guardado en 'carreras\INTERPRETE MUSICAL SUPERIOR EN VIOLÍN - Santiago/17_gra_condicion_dificultad_clases.png'!
# Gráfico guardado en 'carreras\INTERPRETE MUSICAL SUPERIOR EN VIOLÍN - Santiago/25_gra_situacion_laboral_jefe_hogar.png'!
# Gráfico guardado en 'carreras\INTERPRETE MUSICAL SUPERIOR EN VIOLÍN - Santiago/32_gra_lugar_estudio_alumno.png'!
# Gráfico guardado en 'carreras\INTERPRETE MUSICAL SUPERIOR EN VIOLÍN - Santiago/11_gra_genero_identifica_mfo.png'!
# Gráfico guardado en 'carreras\INTERPRETE MUSICAL SUPERIOR VIOLONCELLO - Santiago/1_gra_declaracion_uso_datos.png'!
# Gráfico guardado en 'carreras\INTERPRETE MUSICAL SUPERIOR VIOLONCELLO - Santiago/2_gra_t_desde_egreso.png'!
# Gráfico guardado en 'carreras\INTERPRETE MUSICAL SUPERIOR VIOLONCELLO - Santiago/4_gra_estudia_antes_edsup.png'!
# Gráfico guardado en 'carreras\INTERPRETE MUSICAL SUPERIOR VIOLONCELLO - Santiago/5_gra_finalizo_est_antes_edsup.png'!
# Gráfico guardado en 'carreras\INTERPRETE MUSICAL SUPERIOR VIOLONCELLO - Santiago/6_gra_estado_civil.png'!
# Gráfico guardado en 'carreras\INTERPRETE MUSICAL SUPERIOR VIOLONCELLO - Santiago/7_gra_tiene_hijos.png'!
# No hay valores únicos disponibles para la columna 'red_apoyo'.
# Gráfico guardado en 'carreras\INTERPRETE MUSICAL SUPERIOR VIOLONCELLO - Santiago/10_gra_etnia.png'!
# Gráfico guardado en 'carreras\INTERPRETE MUSICAL SUPERIOR VIOLONCELLO - Santiago/14_gra_declara_discapacidad.png'!
# Gráfico guardado en 'carreras\INTERPRETE MUSICAL SUPERIOR VIOLONCELLO - Santiago/19_gra_cuidados_dentro_campus.png'!
# Gráfico guardado en 'carreras\INTERPRETE MUSICAL SUPERIOR VIOLONCELLO - Santiago/23_gra_tramo_registro_social.png'!
# Gráfico guardado en 'carreras\INTERPRETE MUSICAL SUPERIOR VIOLONCELLO - Santiago/24_gra_cuantos_convive_2023.png'!
# Gráfico guardado en 'carreras\INTERPRETE MUSICAL SUPERIOR VIOLONCELLO - Santiago/26_gra_situacion_laboral.png'!
# No hay valores únicos disponibles para la columna 'horas_semanales_laboral'.
# Gráfico guardado en 'carreras\INTERPRETE MUSICAL SUPERIOR VIOLONCELLO - Santiago/28_gra_dependencia_grupo_familiar.png'!
# No hay valores únicos disponibles para la columna 'horas_cuidado_estudiante'.
# Gráfico guardado en 'carreras\INTERPRETE MUSICAL SUPERIOR VIOLONCELLO - Santiago/33_gra_acceso_medio_digital.png'!
# Gráfico guardado en 'carreras\INTERPRETE MUSICAL SUPERIOR VIOLONCELLO - Santiago/34_gra_uso_exclusivo_medio_digital.png'!
# Gráfico guardado en 'carreras\INTERPRETE MUSICAL SUPERIOR VIOLONCELLO - Santiago/35_gra_acceso_internet_alumno.png'!
# Gráfico guardado en 'carreras\INTERPRETE MUSICAL SUPERIOR VIOLONCELLO - Santiago/37_gra_dificultad_trayecto.png'!
# Gráfico guardado en 'carreras\INTERPRETE MUSICAL SUPERIOR VIOLONCELLO - Santiago/42_gra_requiere_pares_mentores.png'!
# Gráfico guardado en 'carreras\INTERPRETE MUSICAL SUPERIOR VIOLONCELLO - Santiago/43_gra_tiempo_traslado.png'!
# Gráfico guardado en 'carreras\INTERPRETE MUSICAL SUPERIOR VIOLONCELLO - Santiago/44_gra_medio_transporte.png'!
# Gráfico guardado en 'carreras\INTERPRETE MUSICAL SUPERIOR VIOLONCELLO - Santiago/47_gra_practica_deporte_hobbie.png'!
# Gráfico guardado en 'carreras\INTERPRETE MUSICAL SUPERIOR VIOLONCELLO - Santiago/12_gra_orientacion_sexual.png'!
# Gráfico guardado en 'carreras\INTERPRETE MUSICAL SUPERIOR VIOLONCELLO - Santiago/17_gra_condicion_dificultad_clases.png'!
# Gráfico guardado en 'carreras\INTERPRETE MUSICAL SUPERIOR VIOLONCELLO - Santiago/25_gra_situacion_laboral_jefe_hogar.png'!
# Gráfico guardado en 'carreras\INTERPRETE MUSICAL SUPERIOR VIOLONCELLO - Santiago/32_gra_lugar_estudio_alumno.png'!
# Gráfico guardado en 'carreras\INTERPRETE MUSICAL SUPERIOR VIOLONCELLO - Santiago/11_gra_genero_identifica_mfo.png'!
# Gráfico guardado en 'carreras\INTERPRETACIÓN MUSICAL BÁSICO (8) C/M - Santiago/1_gra_declaracion_uso_datos.png'!
# Gráfico guardado en 'carreras\INTERPRETACIÓN MUSICAL BÁSICO (8) C/M - Santiago/2_gra_t_desde_egreso.png'!
# Gráfico guardado en 'carreras\INTERPRETACIÓN MUSICAL BÁSICO (8) C/M - Santiago/4_gra_estudia_antes_edsup.png'!
# Gráfico guardado en 'carreras\INTERPRETACIÓN MUSICAL BÁSICO (8) C/M - Santiago/5_gra_finalizo_est_antes_edsup.png'!
# Gráfico guardado en 'carreras\INTERPRETACIÓN MUSICAL BÁSICO (8) C/M - Santiago/6_gra_estado_civil.png'!
# Gráfico guardado en 'carreras\INTERPRETACIÓN MUSICAL BÁSICO (8) C/M - Santiago/7_gra_tiene_hijos.png'!
# No hay valores únicos disponibles para la columna 'red_apoyo'.
# Gráfico guardado en 'carreras\INTERPRETACIÓN MUSICAL BÁSICO (8) C/M - Santiago/10_gra_etnia.png'!
# Gráfico guardado en 'carreras\INTERPRETACIÓN MUSICAL BÁSICO (8) C/M - Santiago/14_gra_declara_discapacidad.png'!
# Gráfico guardado en 'carreras\INTERPRETACIÓN MUSICAL BÁSICO (8) C/M - Santiago/19_gra_cuidados_dentro_campus.png'!
# Gráfico guardado en 'carreras\INTERPRETACIÓN MUSICAL BÁSICO (8) C/M - Santiago/23_gra_tramo_registro_social.png'!
# Gráfico guardado en 'carreras\INTERPRETACIÓN MUSICAL BÁSICO (8) C/M - Santiago/24_gra_cuantos_convive_2023.png'!
# Gráfico guardado en 'carreras\INTERPRETACIÓN MUSICAL BÁSICO (8) C/M - Santiago/26_gra_situacion_laboral.png'!
# Gráfico guardado en 'carreras\INTERPRETACIÓN MUSICAL BÁSICO (8) C/M - Santiago/27_gra_horas_semanales_laboral.png'!
# Gráfico guardado en 'carreras\INTERPRETACIÓN MUSICAL BÁSICO (8) C/M - Santiago/28_gra_dependencia_grupo_familiar.png'!
# No hay valores únicos disponibles para la columna 'horas_cuidado_estudiante'.
# Gráfico guardado en 'carreras\INTERPRETACIÓN MUSICAL BÁSICO (8) C/M - Santiago/33_gra_acceso_medio_digital.png'!
# Gráfico guardado en 'carreras\INTERPRETACIÓN MUSICAL BÁSICO (8) C/M - Santiago/34_gra_uso_exclusivo_medio_digital.png'!
# Gráfico guardado en 'carreras\INTERPRETACIÓN MUSICAL BÁSICO (8) C/M - Santiago/35_gra_acceso_internet_alumno.png'!
# Gráfico guardado en 'carreras\INTERPRETACIÓN MUSICAL BÁSICO (8) C/M - Santiago/37_gra_dificultad_trayecto.png'!
# Gráfico guardado en 'carreras\INTERPRETACIÓN MUSICAL BÁSICO (8) C/M - Santiago/42_gra_requiere_pares_mentores.png'!
# Gráfico guardado en 'carreras\INTERPRETACIÓN MUSICAL BÁSICO (8) C/M - Santiago/43_gra_tiempo_traslado.png'!
# Gráfico guardado en 'carreras\INTERPRETACIÓN MUSICAL BÁSICO (8) C/M - Santiago/44_gra_medio_transporte.png'!
# Gráfico guardado en 'carreras\INTERPRETACIÓN MUSICAL BÁSICO (8) C/M - Santiago/47_gra_practica_deporte_hobbie.png'!
# Gráfico guardado en 'carreras\INTERPRETACIÓN MUSICAL BÁSICO (8) C/M - Santiago/12_gra_orientacion_sexual.png'!
# Gráfico guardado en 'carreras\INTERPRETACIÓN MUSICAL BÁSICO (8) C/M - Santiago/17_gra_condicion_dificultad_clases.png'!
# Gráfico guardado en 'carreras\INTERPRETACIÓN MUSICAL BÁSICO (8) C/M - Santiago/25_gra_situacion_laboral_jefe_hogar.png'!
# Gráfico guardado en 'carreras\INTERPRETACIÓN MUSICAL BÁSICO (8) C/M - Santiago/32_gra_lugar_estudio_alumno.png'!
# Gráfico guardado en 'carreras\INTERPRETACIÓN MUSICAL BÁSICO (8) C/M - Santiago/11_gra_genero_identifica_mfo.png'!
# Gráfico guardado en 'carreras\SOCIOLOGÍA (V) - Santiago/1_gra_declaracion_uso_datos.png'!
# Gráfico guardado en 'carreras\SOCIOLOGÍA (V) - Santiago/2_gra_t_desde_egreso.png'!
# Gráfico guardado en 'carreras\SOCIOLOGÍA (V) - Santiago/4_gra_estudia_antes_edsup.png'!
# No hay valores únicos disponibles para la columna 'finalizo_est_antes_edsup'.
# Gráfico guardado en 'carreras\SOCIOLOGÍA (V) - Santiago/6_gra_estado_civil.png'!
# Gráfico guardado en 'carreras\SOCIOLOGÍA (V) - Santiago/7_gra_tiene_hijos.png'!
# Gráfico guardado en 'carreras\SOCIOLOGÍA (V) - Santiago/8_gra_red_apoyo.png'!
# Gráfico guardado en 'carreras\SOCIOLOGÍA (V) - Santiago/10_gra_etnia.png'!
# Gráfico guardado en 'carreras\SOCIOLOGÍA (V) - Santiago/14_gra_declara_discapacidad.png'!
# Gráfico guardado en 'carreras\SOCIOLOGÍA (V) - Santiago/19_gra_cuidados_dentro_campus.png'!
# Gráfico guardado en 'carreras\SOCIOLOGÍA (V) - Santiago/23_gra_tramo_registro_social.png'!
# Gráfico guardado en 'carreras\SOCIOLOGÍA (V) - Santiago/24_gra_cuantos_convive_2023.png'!
# Gráfico guardado en 'carreras\SOCIOLOGÍA (V) - Santiago/26_gra_situacion_laboral.png'!
# No hay valores únicos disponibles para la columna 'horas_semanales_laboral'.
# Gráfico guardado en 'carreras\SOCIOLOGÍA (V) - Santiago/28_gra_dependencia_grupo_familiar.png'!
# No hay valores únicos disponibles para la columna 'horas_cuidado_estudiante'.
# Gráfico guardado en 'carreras\SOCIOLOGÍA (V) - Santiago/33_gra_acceso_medio_digital.png'!
# Gráfico guardado en 'carreras\SOCIOLOGÍA (V) - Santiago/34_gra_uso_exclusivo_medio_digital.png'!
# Gráfico guardado en 'carreras\SOCIOLOGÍA (V) - Santiago/35_gra_acceso_internet_alumno.png'!
# Gráfico guardado en 'carreras\SOCIOLOGÍA (V) - Santiago/37_gra_dificultad_trayecto.png'!
# Gráfico guardado en 'carreras\SOCIOLOGÍA (V) - Santiago/42_gra_requiere_pares_mentores.png'!
# Gráfico guardado en 'carreras\SOCIOLOGÍA (V) - Santiago/43_gra_tiempo_traslado.png'!
# Gráfico guardado en 'carreras\SOCIOLOGÍA (V) - Santiago/44_gra_medio_transporte.png'!
# Gráfico guardado en 'carreras\SOCIOLOGÍA (V) - Santiago/47_gra_practica_deporte_hobbie.png'!
# Gráfico guardado en 'carreras\SOCIOLOGÍA (V) - Santiago/12_gra_orientacion_sexual.png'!
# Gráfico guardado en 'carreras\SOCIOLOGÍA (V) - Santiago/17_gra_condicion_dificultad_clases.png'!
# Gráfico guardado en 'carreras\SOCIOLOGÍA (V) - Santiago/25_gra_situacion_laboral_jefe_hogar.png'!
# Gráfico guardado en 'carreras\SOCIOLOGÍA (V) - Santiago/32_gra_lugar_estudio_alumno.png'!
# Gráfico guardado en 'carreras\SOCIOLOGÍA (V) - Santiago/11_gra_genero_identifica_mfo.png'!

# %%
## Diccionario con las variables a graficar y con la cantidad de respuestas originales
multi_dic = {
    'acreditacion_discapacidad': 5,
    'estudios_familiar': 6,
    'mayores_habilidades': 8,
    'area_aprendizaje_quiere_potenciar': 8,
    'apoyo_pedadogico_requiere': 5,
    'actividades_de_interes': 8,
    'preferencias_estudio': 6,
    'preferencia_act_extracurricular': 4,
}

# %%
## Esta función cuenta realiza la suma de los valores dummies, los junta en un nuevo dataset y los ordena
def rep_otros(dataset, num): 
    sum_values = dataset.sum().sort_values(ascending=False)
    sorted_dataset = dataset[sum_values.index]
    originales = sorted_dataset.iloc[:, :num]
    columnas_a_contar = sorted_dataset.iloc[:, num:]
    suma_total_coincidencias = columnas_a_contar.sum().sum()
    nueva_fila = pd.DataFrame({'Otros': [suma_total_coincidencias]})
    multi_un = pd.concat([originales, nueva_fila], ignore_index=True).fillna(0)
    sum_values = multi_un.sum().sort_values(ascending=False)
    sorted_dataset = multi_un[sum_values.index]
    multi_sorted = sorted_dataset.copy()
    return multi_sorted

# %%
def gra_multi_resp(multi, op, column, ruta):
    multi_sor = rep_otros(multi, op)
    #column = columna
    fig, ax = plt.subplots(figsize=(8,6))
    sns.barplot(x=multi_sor.sum().values, y=multi_sor.columns, ax=ax, order=multi_sor.sum().sort_values(ascending=False).index)
    plt.yticks(fontsize=8)
    wrap_labels(ax, 40)
    titulo = def_dic[column] if column in def_dic else None
    #plt.title('Gráfico de ' + column)
    plt.title('Gráfico de ' + str(column))
    plt.xlabel('Cantidad de estudiantes')
    plt.ylabel(column)
    ax.set_xlim(right=ax.get_xlim()[1] * 1.1)
    #descripcion_recortada = '\n'.join(textwrap.wrap(titulo, width=60))
    descripcion_recortada = '\n'.join(textwrap.wrap(titulo, width=60)) if titulo is not None else ''
    plt.text(0.5, -0.20, descripcion_recortada, ha='center', va='center', transform=ax.transAxes)
    # Agregar los valores en las barras
    for p in ax.patches:
        width = p.get_width()
        height = p.get_height()
        x, y = p.get_xy() 
        value = int(width)
        ax.annotate(f'{value}', (x + width, y + height/2), ha='left', va='center')
    num_titulo = next((clave for clave, valor in num_dic.items() if valor == titulo), None)
    nombre_archivo = f"{num_titulo}_gra_op_{column}.png" if titulo else "grafico_op.png"
    plt.tight_layout()
    # Guardar el gráfico en una imagen
    plt.savefig(os.path.join(ruta, nombre_archivo))
    plt.close()
        
    print(f"Gráfico guardado en '{ruta}/{nombre_archivo}'!")

# %%
for carr in carreras.index:
    ruta = os.path.join(directorio_base, carr)
    df_carrera = df[df['carrera_sede'] == carr]
    for columna, op in multi_dic.items():
        mul = df_carrera[columna].str.get_dummies(sep=';')
        gra_multi_resp(mul, op, columna, ruta)
# Out:
# Gráfico guardado en 'carreras\MEDICINA VETERINARIA - Santiago/16_gra_op_acreditacion_discapacidad.png'!
# Gráfico guardado en 'carreras\MEDICINA VETERINARIA - Santiago/22_gra_op_estudios_familiar.png'!
# Gráfico guardado en 'carreras\MEDICINA VETERINARIA - Santiago/39_gra_op_mayores_habilidades.png'!
# Gráfico guardado en 'carreras\MEDICINA VETERINARIA - Santiago/40_gra_op_area_aprendizaje_quiere_potenciar.png'!
# Gráfico guardado en 'carreras\MEDICINA VETERINARIA - Santiago/41_gra_op_apoyo_pedadogico_requiere.png'!
# Gráfico guardado en 'carreras\MEDICINA VETERINARIA - Santiago/45_gra_op_actividades_de_interes.png'!
# Gráfico guardado en 'carreras\MEDICINA VETERINARIA - Santiago/46_gra_op_preferencias_estudio.png'!
# Gráfico guardado en 'carreras\MEDICINA VETERINARIA - Santiago/49_gra_op_preferencia_act_extracurricular.png'!
# Gráfico guardado en 'carreras\PSICOLOGÍA - Santiago/16_gra_op_acreditacion_discapacidad.png'!
# Gráfico guardado en 'carreras\PSICOLOGÍA - Santiago/22_gra_op_estudios_familiar.png'!
# Gráfico guardado en 'carreras\PSICOLOGÍA - Santiago/39_gra_op_mayores_habilidades.png'!
# Gráfico guardado en 'carreras\PSICOLOGÍA - Santiago/40_gra_op_area_aprendizaje_quiere_potenciar.png'!
# Gráfico guardado en 'carreras\PSICOLOGÍA - Santiago/41_gra_op_apoyo_pedadogico_requiere.png'!
# Gráfico guardado en 'carreras\PSICOLOGÍA - Santiago/45_gra_op_actividades_de_interes.png'!
# Gráfico guardado en 'carreras\PSICOLOGÍA - Santiago/46_gra_op_preferencias_estudio.png'!
# Gráfico guardado en 'carreras\PSICOLOGÍA - Santiago/49_gra_op_preferencia_act_extracurricular.png'!
# Gráfico guardado en 'carreras\TECNOLOGÍA MÉDICA - Santiago/16_gra_op_acreditacion_discapacidad.png'!
# Gráfico guardado en 'carreras\TECNOLOGÍA MÉDICA - Santiago/22_gra_op_estudios_familiar.png'!
# Gráfico guardado en 'carreras\TECNOLOGÍA MÉDICA - Santiago/39_gra_op_mayores_habilidades.png'!
# Gráfico guardado en 'carreras\TECNOLOGÍA MÉDICA - Santiago/40_gra_op_area_aprendizaje_quiere_potenciar.png'!
# Gráfico guardado en 'carreras\TECNOLOGÍA MÉDICA - Santiago/41_gra_op_apoyo_pedadogico_requiere.png'!
# Gráfico guardado en 'carreras\TECNOLOGÍA MÉDICA - Santiago/45_gra_op_actividades_de_interes.png'!
# Gráfico guardado en 'carreras\TECNOLOGÍA MÉDICA - Santiago/46_gra_op_preferencias_estudio.png'!
# Gráfico guardado en 'carreras\TECNOLOGÍA MÉDICA - Santiago/49_gra_op_preferencia_act_extracurricular.png'!
# Gráfico guardado en 'carreras\ADMINISTRACIÓN PÚBLICA  CONT. (ON-LINE) - Santiago/16_gra_op_acreditacion_discapacidad.png'!
# Gráfico guardado en 'carreras\ADMINISTRACIÓN PÚBLICA  CONT. (ON-LINE) - Santiago/22_gra_op_estudios_familiar.png'!
# Gráfico guardado en 'carreras\ADMINISTRACIÓN PÚBLICA  CONT. (ON-LINE) - Santiago/39_gra_op_mayores_habilidades.png'!
# Gráfico guardado en 'carreras\ADMINISTRACIÓN PÚBLICA  CONT. (ON-LINE) - Santiago/40_gra_op_area_aprendizaje_quiere_potenciar.png'!
# Gráfico guardado en 'carreras\ADMINISTRACIÓN PÚBLICA  CONT. (ON-LINE) - Santiago/41_gra_op_apoyo_pedadogico_requiere.png'!
# Gráfico guardado en 'carreras\ADMINISTRACIÓN PÚBLICA  CONT. (ON-LINE) - Santiago/45_gra_op_actividades_de_interes.png'!
# Gráfico guardado en 'carreras\ADMINISTRACIÓN PÚBLICA  CONT. (ON-LINE) - Santiago/46_gra_op_preferencias_estudio.png'!
# Gráfico guardado en 'carreras\ADMINISTRACIÓN PÚBLICA  CONT. (ON-LINE) - Santiago/49_gra_op_preferencia_act_extracurricular.png'!
# Gráfico guardado en 'carreras\ING. CIVIL INDUSTRIAL  (CONTI.-ONL) - Santiago/16_gra_op_acreditacion_discapacidad.png'!
# Gráfico guardado en 'carreras\ING. CIVIL INDUSTRIAL  (CONTI.-ONL) - Santiago/22_gra_op_estudios_familiar.png'!
# Gráfico guardado en 'carreras\ING. CIVIL INDUSTRIAL  (CONTI.-ONL) - Santiago/39_gra_op_mayores_habilidades.png'!
# Gráfico guardado en 'carreras\ING. CIVIL INDUSTRIAL  (CONTI.-ONL) - Santiago/40_gra_op_area_aprendizaje_quiere_potenciar.png'!
# Gráfico guardado en 'carreras\ING. CIVIL INDUSTRIAL  (CONTI.-ONL) - Santiago/41_gra_op_apoyo_pedadogico_requiere.png'!
# Gráfico guardado en 'carreras\ING. CIVIL INDUSTRIAL  (CONTI.-ONL) - Santiago/45_gra_op_actividades_de_interes.png'!
# Gráfico guardado en 'carreras\ING. CIVIL INDUSTRIAL  (CONTI.-ONL) - Santiago/46_gra_op_preferencias_estudio.png'!
# Gráfico guardado en 'carreras\ING. CIVIL INDUSTRIAL  (CONTI.-ONL) - Santiago/49_gra_op_preferencia_act_extracurricular.png'!
# Gráfico guardado en 'carreras\ANIMACIÓN DIGITAL - Santiago/16_gra_op_acreditacion_discapacidad.png'!
# Gráfico guardado en 'carreras\ANIMACIÓN DIGITAL - Santiago/22_gra_op_estudios_familiar.png'!
# Gráfico guardado en 'carreras\ANIMACIÓN DIGITAL - Santiago/39_gra_op_mayores_habilidades.png'!
# Gráfico guardado en 'carreras\ANIMACIÓN DIGITAL - Santiago/40_gra_op_area_aprendizaje_quiere_potenciar.png'!
# Gráfico guardado en 'carreras\ANIMACIÓN DIGITAL - Santiago/41_gra_op_apoyo_pedadogico_requiere.png'!
# Gráfico guardado en 'carreras\ANIMACIÓN DIGITAL - Santiago/45_gra_op_actividades_de_interes.png'!
# Gráfico guardado en 'carreras\ANIMACIÓN DIGITAL - Santiago/46_gra_op_preferencias_estudio.png'!
# Gráfico guardado en 'carreras\ANIMACIÓN DIGITAL - Santiago/49_gra_op_preferencia_act_extracurricular.png'!
# Gráfico guardado en 'carreras\ARQUITECTURA - Santiago/16_gra_op_acreditacion_discapacidad.png'!
# Gráfico guardado en 'carreras\ARQUITECTURA - Santiago/22_gra_op_estudios_familiar.png'!
# Gráfico guardado en 'carreras\ARQUITECTURA - Santiago/39_gra_op_mayores_habilidades.png'!
# Gráfico guardado en 'carreras\ARQUITECTURA - Santiago/40_gra_op_area_aprendizaje_quiere_potenciar.png'!
# Gráfico guardado en 'carreras\ARQUITECTURA - Santiago/41_gra_op_apoyo_pedadogico_requiere.png'!
# Gráfico guardado en 'carreras\ARQUITECTURA - Santiago/45_gra_op_actividades_de_interes.png'!
# Gráfico guardado en 'carreras\ARQUITECTURA - Santiago/46_gra_op_preferencias_estudio.png'!
# Gráfico guardado en 'carreras\ARQUITECTURA - Santiago/49_gra_op_preferencia_act_extracurricular.png'!
# Gráfico guardado en 'carreras\KINESIOLOGÍA - Santiago/16_gra_op_acreditacion_discapacidad.png'!
# Gráfico guardado en 'carreras\KINESIOLOGÍA - Santiago/22_gra_op_estudios_familiar.png'!
# Gráfico guardado en 'carreras\KINESIOLOGÍA - Santiago/39_gra_op_mayores_habilidades.png'!
# Gráfico guardado en 'carreras\KINESIOLOGÍA - Santiago/40_gra_op_area_aprendizaje_quiere_potenciar.png'!
# Gráfico guardado en 'carreras\KINESIOLOGÍA - Santiago/41_gra_op_apoyo_pedadogico_requiere.png'!
# Gráfico guardado en 'carreras\KINESIOLOGÍA - Santiago/45_gra_op_actividades_de_interes.png'!
# Gráfico guardado en 'carreras\KINESIOLOGÍA - Santiago/46_gra_op_preferencias_estudio.png'!
# Gráfico guardado en 'carreras\KINESIOLOGÍA - Santiago/49_gra_op_preferencia_act_extracurricular.png'!
# Gráfico guardado en 'carreras\INGENIERÍA  EN LOGÍSTICA ( CONT. ONLINE) - Santiago/16_gra_op_acreditacion_discapacidad.png'!
# Gráfico guardado en 'carreras\INGENIERÍA  EN LOGÍSTICA ( CONT. ONLINE) - Santiago/22_gra_op_estudios_familiar.png'!
# Gráfico guardado en 'carreras\INGENIERÍA  EN LOGÍSTICA ( CONT. ONLINE) - Santiago/39_gra_op_mayores_habilidades.png'!
# Gráfico guardado en 'carreras\INGENIERÍA  EN LOGÍSTICA ( CONT. ONLINE) - Santiago/40_gra_op_area_aprendizaje_quiere_potenciar.png'!
# Gráfico guardado en 'carreras\INGENIERÍA  EN LOGÍSTICA ( CONT. ONLINE) - Santiago/41_gra_op_apoyo_pedadogico_requiere.png'!
# Gráfico guardado en 'carreras\INGENIERÍA  EN LOGÍSTICA ( CONT. ONLINE) - Santiago/45_gra_op_actividades_de_interes.png'!
# Gráfico guardado en 'carreras\INGENIERÍA  EN LOGÍSTICA ( CONT. ONLINE) - Santiago/46_gra_op_preferencias_estudio.png'!
# Gráfico guardado en 'carreras\INGENIERÍA  EN LOGÍSTICA ( CONT. ONLINE) - Santiago/49_gra_op_preferencia_act_extracurricular.png'!
# Gráfico guardado en 'carreras\DERECHO - Santiago/16_gra_op_acreditacion_discapacidad.png'!
# Gráfico guardado en 'carreras\DERECHO - Santiago/22_gra_op_estudios_familiar.png'!
# Gráfico guardado en 'carreras\DERECHO - Santiago/39_gra_op_mayores_habilidades.png'!
# Gráfico guardado en 'carreras\DERECHO - Santiago/40_gra_op_area_aprendizaje_quiere_potenciar.png'!
# Gráfico guardado en 'carreras\DERECHO - Santiago/41_gra_op_apoyo_pedadogico_requiere.png'!
# Gráfico guardado en 'carreras\DERECHO - Santiago/45_gra_op_actividades_de_interes.png'!
# Gráfico guardado en 'carreras\DERECHO - Santiago/46_gra_op_preferencias_estudio.png'!
# Gráfico guardado en 'carreras\DERECHO - Santiago/49_gra_op_preferencia_act_extracurricular.png'!
# Gráfico guardado en 'carreras\ING. PREVENCIÓN EN RIESGOS CON.(ON-LINE) - Santiago/16_gra_op_acreditacion_discapacidad.png'!
# Gráfico guardado en 'carreras\ING. PREVENCIÓN EN RIESGOS CON.(ON-LINE) - Santiago/22_gra_op_estudios_familiar.png'!
# Gráfico guardado en 'carreras\ING. PREVENCIÓN EN RIESGOS CON.(ON-LINE) - Santiago/39_gra_op_mayores_habilidades.png'!
# Gráfico guardado en 'carreras\ING. PREVENCIÓN EN RIESGOS CON.(ON-LINE) - Santiago/40_gra_op_area_aprendizaje_quiere_potenciar.png'!
# Gráfico guardado en 'carreras\ING. PREVENCIÓN EN RIESGOS CON.(ON-LINE) - Santiago/41_gra_op_apoyo_pedadogico_requiere.png'!
# Gráfico guardado en 'carreras\ING. PREVENCIÓN EN RIESGOS CON.(ON-LINE) - Santiago/45_gra_op_actividades_de_interes.png'!
# Gráfico guardado en 'carreras\ING. PREVENCIÓN EN RIESGOS CON.(ON-LINE) - Santiago/46_gra_op_preferencias_estudio.png'!
# Gráfico guardado en 'carreras\ING. PREVENCIÓN EN RIESGOS CON.(ON-LINE) - Santiago/49_gra_op_preferencia_act_extracurricular.png'!
# Gráfico guardado en 'carreras\INGENIERÍA COMERCIAL (DIURNO) - Santiago/16_gra_op_acreditacion_discapacidad.png'!
# Gráfico guardado en 'carreras\INGENIERÍA COMERCIAL (DIURNO) - Santiago/22_gra_op_estudios_familiar.png'!
# Gráfico guardado en 'carreras\INGENIERÍA COMERCIAL (DIURNO) - Santiago/39_gra_op_mayores_habilidades.png'!
# Gráfico guardado en 'carreras\INGENIERÍA COMERCIAL (DIURNO) - Santiago/40_gra_op_area_aprendizaje_quiere_potenciar.png'!
# Gráfico guardado en 'carreras\INGENIERÍA COMERCIAL (DIURNO) - Santiago/41_gra_op_apoyo_pedadogico_requiere.png'!
# Gráfico guardado en 'carreras\INGENIERÍA COMERCIAL (DIURNO) - Santiago/45_gra_op_actividades_de_interes.png'!
# Gráfico guardado en 'carreras\INGENIERÍA COMERCIAL (DIURNO) - Santiago/46_gra_op_preferencias_estudio.png'!
# Gráfico guardado en 'carreras\INGENIERÍA COMERCIAL (DIURNO) - Santiago/49_gra_op_preferencia_act_extracurricular.png'!
# Gráfico guardado en 'carreras\ENFERMERÍA - Santiago/16_gra_op_acreditacion_discapacidad.png'!
# Gráfico guardado en 'carreras\ENFERMERÍA - Santiago/22_gra_op_estudios_familiar.png'!
# Gráfico guardado en 'carreras\ENFERMERÍA - Santiago/39_gra_op_mayores_habilidades.png'!
# Gráfico guardado en 'carreras\ENFERMERÍA - Santiago/40_gra_op_area_aprendizaje_quiere_potenciar.png'!
# Gráfico guardado en 'carreras\ENFERMERÍA - Santiago/41_gra_op_apoyo_pedadogico_requiere.png'!
# Gráfico guardado en 'carreras\ENFERMERÍA - Santiago/45_gra_op_actividades_de_interes.png'!
# Gráfico guardado en 'carreras\ENFERMERÍA - Santiago/46_gra_op_preferencias_estudio.png'!
# Gráfico guardado en 'carreras\ENFERMERÍA - Santiago/49_gra_op_preferencia_act_extracurricular.png'!
# Gráfico guardado en 'carreras\INGENIERÍA  CIVIL  EN  COMP. E  INF. - Santiago/16_gra_op_acreditacion_discapacidad.png'!
# Gráfico guardado en 'carreras\INGENIERÍA  CIVIL  EN  COMP. E  INF. - Santiago/22_gra_op_estudios_familiar.png'!
# Gráfico guardado en 'carreras\INGENIERÍA  CIVIL  EN  COMP. E  INF. - Santiago/39_gra_op_mayores_habilidades.png'!
# Gráfico guardado en 'carreras\INGENIERÍA  CIVIL  EN  COMP. E  INF. - Santiago/40_gra_op_area_aprendizaje_quiere_potenciar.png'!
# Gráfico guardado en 'carreras\INGENIERÍA  CIVIL  EN  COMP. E  INF. - Santiago/41_gra_op_apoyo_pedadogico_requiere.png'!
# Gráfico guardado en 'carreras\INGENIERÍA  CIVIL  EN  COMP. E  INF. - Santiago/45_gra_op_actividades_de_interes.png'!
# Gráfico guardado en 'carreras\INGENIERÍA  CIVIL  EN  COMP. E  INF. - Santiago/46_gra_op_preferencias_estudio.png'!
# Gráfico guardado en 'carreras\INGENIERÍA  CIVIL  EN  COMP. E  INF. - Santiago/49_gra_op_preferencia_act_extracurricular.png'!
# Gráfico guardado en 'carreras\OBSTETRICIA Y PUERICULTURA - Santiago/16_gra_op_acreditacion_discapacidad.png'!
# Gráfico guardado en 'carreras\OBSTETRICIA Y PUERICULTURA - Santiago/22_gra_op_estudios_familiar.png'!
# Gráfico guardado en 'carreras\OBSTETRICIA Y PUERICULTURA - Santiago/39_gra_op_mayores_habilidades.png'!
# Gráfico guardado en 'carreras\OBSTETRICIA Y PUERICULTURA - Santiago/40_gra_op_area_aprendizaje_quiere_potenciar.png'!
# Gráfico guardado en 'carreras\OBSTETRICIA Y PUERICULTURA - Santiago/41_gra_op_apoyo_pedadogico_requiere.png'!
# Gráfico guardado en 'carreras\OBSTETRICIA Y PUERICULTURA - Santiago/45_gra_op_actividades_de_interes.png'!
# Gráfico guardado en 'carreras\OBSTETRICIA Y PUERICULTURA - Santiago/46_gra_op_preferencias_estudio.png'!
# Gráfico guardado en 'carreras\OBSTETRICIA Y PUERICULTURA - Santiago/49_gra_op_preferencia_act_extracurricular.png'!
# Gráfico guardado en 'carreras\ENFERMERÍA - Temuco/16_gra_op_acreditacion_discapacidad.png'!
# Gráfico guardado en 'carreras\ENFERMERÍA - Temuco/22_gra_op_estudios_familiar.png'!
# Gráfico guardado en 'carreras\ENFERMERÍA - Temuco/39_gra_op_mayores_habilidades.png'!
# Gráfico guardado en 'carreras\ENFERMERÍA - Temuco/40_gra_op_area_aprendizaje_quiere_potenciar.png'!
# Gráfico guardado en 'carreras\ENFERMERÍA - Temuco/41_gra_op_apoyo_pedadogico_requiere.png'!
# Gráfico guardado en 'carreras\ENFERMERÍA - Temuco/45_gra_op_actividades_de_interes.png'!
# Gráfico guardado en 'carreras\ENFERMERÍA - Temuco/46_gra_op_preferencias_estudio.png'!
# Gráfico guardado en 'carreras\ENFERMERÍA - Temuco/49_gra_op_preferencia_act_extracurricular.png'!
# Gráfico guardado en 'carreras\INGENIERÍA CIVIL INDUSTRIAL - Santiago/16_gra_op_acreditacion_discapacidad.png'!
# Gráfico guardado en 'carreras\INGENIERÍA CIVIL INDUSTRIAL - Santiago/22_gra_op_estudios_familiar.png'!
# Gráfico guardado en 'carreras\INGENIERÍA CIVIL INDUSTRIAL - Santiago/39_gra_op_mayores_habilidades.png'!
# Gráfico guardado en 'carreras\INGENIERÍA CIVIL INDUSTRIAL - Santiago/40_gra_op_area_aprendizaje_quiere_potenciar.png'!
# Gráfico guardado en 'carreras\INGENIERÍA CIVIL INDUSTRIAL - Santiago/41_gra_op_apoyo_pedadogico_requiere.png'!
# Gráfico guardado en 'carreras\INGENIERÍA CIVIL INDUSTRIAL - Santiago/45_gra_op_actividades_de_interes.png'!
# Gráfico guardado en 'carreras\INGENIERÍA CIVIL INDUSTRIAL - Santiago/46_gra_op_preferencias_estudio.png'!
# Gráfico guardado en 'carreras\INGENIERÍA CIVIL INDUSTRIAL - Santiago/49_gra_op_preferencia_act_extracurricular.png'!
# Gráfico guardado en 'carreras\DISEÑO - Santiago/16_gra_op_acreditacion_discapacidad.png'!
# Gráfico guardado en 'carreras\DISEÑO - Santiago/22_gra_op_estudios_familiar.png'!
# Gráfico guardado en 'carreras\DISEÑO - Santiago/39_gra_op_mayores_habilidades.png'!
# Gráfico guardado en 'carreras\DISEÑO - Santiago/40_gra_op_area_aprendizaje_quiere_potenciar.png'!
# Gráfico guardado en 'carreras\DISEÑO - Santiago/41_gra_op_apoyo_pedadogico_requiere.png'!
# Gráfico guardado en 'carreras\DISEÑO - Santiago/45_gra_op_actividades_de_interes.png'!
# Gráfico guardado en 'carreras\DISEÑO - Santiago/46_gra_op_preferencias_estudio.png'!
# Gráfico guardado en 'carreras\DISEÑO - Santiago/49_gra_op_preferencia_act_extracurricular.png'!
# Gráfico guardado en 'carreras\INGENIERÍA INDUSTRIAL (ONL) - Santiago/16_gra_op_acreditacion_discapacidad.png'!
# Gráfico guardado en 'carreras\INGENIERÍA INDUSTRIAL (ONL) - Santiago/22_gra_op_estudios_familiar.png'!
# Gráfico guardado en 'carreras\INGENIERÍA INDUSTRIAL (ONL) - Santiago/39_gra_op_mayores_habilidades.png'!
# Gráfico guardado en 'carreras\INGENIERÍA INDUSTRIAL (ONL) - Santiago/40_gra_op_area_aprendizaje_quiere_potenciar.png'!
# Gráfico guardado en 'carreras\INGENIERÍA INDUSTRIAL (ONL) - Santiago/41_gra_op_apoyo_pedadogico_requiere.png'!
# Gráfico guardado en 'carreras\INGENIERÍA INDUSTRIAL (ONL) - Santiago/45_gra_op_actividades_de_interes.png'!
# Gráfico guardado en 'carreras\INGENIERÍA INDUSTRIAL (ONL) - Santiago/46_gra_op_preferencias_estudio.png'!
# Gráfico guardado en 'carreras\INGENIERÍA INDUSTRIAL (ONL) - Santiago/49_gra_op_preferencia_act_extracurricular.png'!
# Gráfico guardado en 'carreras\INGENIERÍA EN ADMINISTRACIÓN (ON-LINE) - Santiago/16_gra_op_acreditacion_discapacidad.png'!
# Gráfico guardado en 'carreras\INGENIERÍA EN ADMINISTRACIÓN (ON-LINE) - Santiago/22_gra_op_estudios_familiar.png'!
# Gráfico guardado en 'carreras\INGENIERÍA EN ADMINISTRACIÓN (ON-LINE) - Santiago/39_gra_op_mayores_habilidades.png'!
# Gráfico guardado en 'carreras\INGENIERÍA EN ADMINISTRACIÓN (ON-LINE) - Santiago/40_gra_op_area_aprendizaje_quiere_potenciar.png'!
# Gráfico guardado en 'carreras\INGENIERÍA EN ADMINISTRACIÓN (ON-LINE) - Santiago/41_gra_op_apoyo_pedadogico_requiere.png'!
# Gráfico guardado en 'carreras\INGENIERÍA EN ADMINISTRACIÓN (ON-LINE) - Santiago/45_gra_op_actividades_de_interes.png'!
# Gráfico guardado en 'carreras\INGENIERÍA EN ADMINISTRACIÓN (ON-LINE) - Santiago/46_gra_op_preferencias_estudio.png'!
# Gráfico guardado en 'carreras\INGENIERÍA EN ADMINISTRACIÓN (ON-LINE) - Santiago/49_gra_op_preferencia_act_extracurricular.png'!
# Gráfico guardado en 'carreras\MEDICINA - Santiago/16_gra_op_acreditacion_discapacidad.png'!
# Gráfico guardado en 'carreras\MEDICINA - Santiago/22_gra_op_estudios_familiar.png'!
# Gráfico guardado en 'carreras\MEDICINA - Santiago/39_gra_op_mayores_habilidades.png'!
# Gráfico guardado en 'carreras\MEDICINA - Santiago/40_gra_op_area_aprendizaje_quiere_potenciar.png'!
# Gráfico guardado en 'carreras\MEDICINA - Santiago/41_gra_op_apoyo_pedadogico_requiere.png'!
# Gráfico guardado en 'carreras\MEDICINA - Santiago/45_gra_op_actividades_de_interes.png'!
# Gráfico guardado en 'carreras\MEDICINA - Santiago/46_gra_op_preferencias_estudio.png'!
# Gráfico guardado en 'carreras\MEDICINA - Santiago/49_gra_op_preferencia_act_extracurricular.png'!
# Gráfico guardado en 'carreras\BACHILLERATO EN CIENCIAS DE LA SALUD - Santiago/16_gra_op_acreditacion_discapacidad.png'!
# Gráfico guardado en 'carreras\BACHILLERATO EN CIENCIAS DE LA SALUD - Santiago/22_gra_op_estudios_familiar.png'!
# Gráfico guardado en 'carreras\BACHILLERATO EN CIENCIAS DE LA SALUD - Santiago/39_gra_op_mayores_habilidades.png'!
# Gráfico guardado en 'carreras\BACHILLERATO EN CIENCIAS DE LA SALUD - Santiago/40_gra_op_area_aprendizaje_quiere_potenciar.png'!
# Gráfico guardado en 'carreras\BACHILLERATO EN CIENCIAS DE LA SALUD - Santiago/41_gra_op_apoyo_pedadogico_requiere.png'!
# Gráfico guardado en 'carreras\BACHILLERATO EN CIENCIAS DE LA SALUD - Santiago/45_gra_op_actividades_de_interes.png'!
# Gráfico guardado en 'carreras\BACHILLERATO EN CIENCIAS DE LA SALUD - Santiago/46_gra_op_preferencias_estudio.png'!
# Gráfico guardado en 'carreras\BACHILLERATO EN CIENCIAS DE LA SALUD - Santiago/49_gra_op_preferencia_act_extracurricular.png'!
# Gráfico guardado en 'carreras\ODONTOLOGÍA - Santiago/16_gra_op_acreditacion_discapacidad.png'!
# Gráfico guardado en 'carreras\ODONTOLOGÍA - Santiago/22_gra_op_estudios_familiar.png'!
# Gráfico guardado en 'carreras\ODONTOLOGÍA - Santiago/39_gra_op_mayores_habilidades.png'!
# Gráfico guardado en 'carreras\ODONTOLOGÍA - Santiago/40_gra_op_area_aprendizaje_quiere_potenciar.png'!
# Gráfico guardado en 'carreras\ODONTOLOGÍA - Santiago/41_gra_op_apoyo_pedadogico_requiere.png'!
# Gráfico guardado en 'carreras\ODONTOLOGÍA - Santiago/45_gra_op_actividades_de_interes.png'!
# Gráfico guardado en 'carreras\ODONTOLOGÍA - Santiago/46_gra_op_preferencias_estudio.png'!
# Gráfico guardado en 'carreras\ODONTOLOGÍA - Santiago/49_gra_op_preferencia_act_extracurricular.png'!
# Gráfico guardado en 'carreras\PSICOLOGÍA - Temuco/16_gra_op_acreditacion_discapacidad.png'!
# Gráfico guardado en 'carreras\PSICOLOGÍA - Temuco/22_gra_op_estudios_familiar.png'!
# Gráfico guardado en 'carreras\PSICOLOGÍA - Temuco/39_gra_op_mayores_habilidades.png'!
# Gráfico guardado en 'carreras\PSICOLOGÍA - Temuco/40_gra_op_area_aprendizaje_quiere_potenciar.png'!
# Gráfico guardado en 'carreras\PSICOLOGÍA - Temuco/41_gra_op_apoyo_pedadogico_requiere.png'!
# Gráfico guardado en 'carreras\PSICOLOGÍA - Temuco/45_gra_op_actividades_de_interes.png'!
# Gráfico guardado en 'carreras\PSICOLOGÍA - Temuco/46_gra_op_preferencias_estudio.png'!
# Gráfico guardado en 'carreras\PSICOLOGÍA - Temuco/49_gra_op_preferencia_act_extracurricular.png'!
# Gráfico guardado en 'carreras\TERAPIA OCUPACIONAL - Santiago/16_gra_op_acreditacion_discapacidad.png'!
# Gráfico guardado en 'carreras\TERAPIA OCUPACIONAL - Santiago/22_gra_op_estudios_familiar.png'!
# Gráfico guardado en 'carreras\TERAPIA OCUPACIONAL - Santiago/39_gra_op_mayores_habilidades.png'!
# Gráfico guardado en 'carreras\TERAPIA OCUPACIONAL - Santiago/40_gra_op_area_aprendizaje_quiere_potenciar.png'!
# Gráfico guardado en 'carreras\TERAPIA OCUPACIONAL - Santiago/41_gra_op_apoyo_pedadogico_requiere.png'!
# Gráfico guardado en 'carreras\TERAPIA OCUPACIONAL - Santiago/45_gra_op_actividades_de_interes.png'!
# Gráfico guardado en 'carreras\TERAPIA OCUPACIONAL - Santiago/46_gra_op_preferencias_estudio.png'!
# Gráfico guardado en 'carreras\TERAPIA OCUPACIONAL - Santiago/49_gra_op_preferencia_act_extracurricular.png'!
# Gráfico guardado en 'carreras\PSICOLOGÍA (B) - Santiago/16_gra_op_acreditacion_discapacidad.png'!
# Gráfico guardado en 'carreras\PSICOLOGÍA (B) - Santiago/22_gra_op_estudios_familiar.png'!
# Gráfico guardado en 'carreras\PSICOLOGÍA (B) - Santiago/39_gra_op_mayores_habilidades.png'!
# Gráfico guardado en 'carreras\PSICOLOGÍA (B) - Santiago/40_gra_op_area_aprendizaje_quiere_potenciar.png'!
# Gráfico guardado en 'carreras\PSICOLOGÍA (B) - Santiago/41_gra_op_apoyo_pedadogico_requiere.png'!
# Gráfico guardado en 'carreras\PSICOLOGÍA (B) - Santiago/45_gra_op_actividades_de_interes.png'!
# Gráfico guardado en 'carreras\PSICOLOGÍA (B) - Santiago/46_gra_op_preferencias_estudio.png'!
# Gráfico guardado en 'carreras\PSICOLOGÍA (B) - Santiago/49_gra_op_preferencia_act_extracurricular.png'!
# Gráfico guardado en 'carreras\GEOLOGÍA - Santiago/16_gra_op_acreditacion_discapacidad.png'!
# Gráfico guardado en 'carreras\GEOLOGÍA - Santiago/22_gra_op_estudios_familiar.png'!
# Gráfico guardado en 'carreras\GEOLOGÍA - Santiago/39_gra_op_mayores_habilidades.png'!
# Gráfico guardado en 'carreras\GEOLOGÍA - Santiago/40_gra_op_area_aprendizaje_quiere_potenciar.png'!
# Gráfico guardado en 'carreras\GEOLOGÍA - Santiago/41_gra_op_apoyo_pedadogico_requiere.png'!
# Gráfico guardado en 'carreras\GEOLOGÍA - Santiago/45_gra_op_actividades_de_interes.png'!
# Gráfico guardado en 'carreras\GEOLOGÍA - Santiago/46_gra_op_preferencias_estudio.png'!
# Gráfico guardado en 'carreras\GEOLOGÍA - Santiago/49_gra_op_preferencia_act_extracurricular.png'!
# Gráfico guardado en 'carreras\INGENIERÍA EN INFORMÁTICA (ONL) - Santiago/16_gra_op_acreditacion_discapacidad.png'!
# Gráfico guardado en 'carreras\INGENIERÍA EN INFORMÁTICA (ONL) - Santiago/22_gra_op_estudios_familiar.png'!
# Gráfico guardado en 'carreras\INGENIERÍA EN INFORMÁTICA (ONL) - Santiago/39_gra_op_mayores_habilidades.png'!
# Gráfico guardado en 'carreras\INGENIERÍA EN INFORMÁTICA (ONL) - Santiago/40_gra_op_area_aprendizaje_quiere_potenciar.png'!
# Gráfico guardado en 'carreras\INGENIERÍA EN INFORMÁTICA (ONL) - Santiago/41_gra_op_apoyo_pedadogico_requiere.png'!
# Gráfico guardado en 'carreras\INGENIERÍA EN INFORMÁTICA (ONL) - Santiago/45_gra_op_actividades_de_interes.png'!
# Gráfico guardado en 'carreras\INGENIERÍA EN INFORMÁTICA (ONL) - Santiago/46_gra_op_preferencias_estudio.png'!
# Gráfico guardado en 'carreras\INGENIERÍA EN INFORMÁTICA (ONL) - Santiago/49_gra_op_preferencia_act_extracurricular.png'!
# Gráfico guardado en 'carreras\OBSTETRICIA Y PUERICULTURA - Temuco/16_gra_op_acreditacion_discapacidad.png'!
# Gráfico guardado en 'carreras\OBSTETRICIA Y PUERICULTURA - Temuco/22_gra_op_estudios_familiar.png'!
# Gráfico guardado en 'carreras\OBSTETRICIA Y PUERICULTURA - Temuco/39_gra_op_mayores_habilidades.png'!
# Gráfico guardado en 'carreras\OBSTETRICIA Y PUERICULTURA - Temuco/40_gra_op_area_aprendizaje_quiere_potenciar.png'!
# Gráfico guardado en 'carreras\OBSTETRICIA Y PUERICULTURA - Temuco/41_gra_op_apoyo_pedadogico_requiere.png'!
# Gráfico guardado en 'carreras\OBSTETRICIA Y PUERICULTURA - Temuco/45_gra_op_actividades_de_interes.png'!
# Gráfico guardado en 'carreras\OBSTETRICIA Y PUERICULTURA - Temuco/46_gra_op_preferencias_estudio.png'!
# Gráfico guardado en 'carreras\OBSTETRICIA Y PUERICULTURA - Temuco/49_gra_op_preferencia_act_extracurricular.png'!
# Gráfico guardado en 'carreras\NUTRICIÓN Y DIETÉTICA - Santiago/16_gra_op_acreditacion_discapacidad.png'!
# Gráfico guardado en 'carreras\NUTRICIÓN Y DIETÉTICA - Santiago/22_gra_op_estudios_familiar.png'!
# Gráfico guardado en 'carreras\NUTRICIÓN Y DIETÉTICA - Santiago/39_gra_op_mayores_habilidades.png'!
# Gráfico guardado en 'carreras\NUTRICIÓN Y DIETÉTICA - Santiago/40_gra_op_area_aprendizaje_quiere_potenciar.png'!
# Gráfico guardado en 'carreras\NUTRICIÓN Y DIETÉTICA - Santiago/41_gra_op_apoyo_pedadogico_requiere.png'!
# Gráfico guardado en 'carreras\NUTRICIÓN Y DIETÉTICA - Santiago/45_gra_op_actividades_de_interes.png'!
# Gráfico guardado en 'carreras\NUTRICIÓN Y DIETÉTICA - Santiago/46_gra_op_preferencias_estudio.png'!
# Gráfico guardado en 'carreras\NUTRICIÓN Y DIETÉTICA - Santiago/49_gra_op_preferencia_act_extracurricular.png'!
# Gráfico guardado en 'carreras\ING. EN ADMINISTRACIÓN (CONTIN, ONLINE) - Santiago/16_gra_op_acreditacion_discapacidad.png'!
# Gráfico guardado en 'carreras\ING. EN ADMINISTRACIÓN (CONTIN, ONLINE) - Santiago/22_gra_op_estudios_familiar.png'!
# Gráfico guardado en 'carreras\ING. EN ADMINISTRACIÓN (CONTIN, ONLINE) - Santiago/39_gra_op_mayores_habilidades.png'!
# Gráfico guardado en 'carreras\ING. EN ADMINISTRACIÓN (CONTIN, ONLINE) - Santiago/40_gra_op_area_aprendizaje_quiere_potenciar.png'!
# Gráfico guardado en 'carreras\ING. EN ADMINISTRACIÓN (CONTIN, ONLINE) - Santiago/41_gra_op_apoyo_pedadogico_requiere.png'!
# Gráfico guardado en 'carreras\ING. EN ADMINISTRACIÓN (CONTIN, ONLINE) - Santiago/45_gra_op_actividades_de_interes.png'!
# Gráfico guardado en 'carreras\ING. EN ADMINISTRACIÓN (CONTIN, ONLINE) - Santiago/46_gra_op_preferencias_estudio.png'!
# Gráfico guardado en 'carreras\ING. EN ADMINISTRACIÓN (CONTIN, ONLINE) - Santiago/49_gra_op_preferencia_act_extracurricular.png'!
# Gráfico guardado en 'carreras\DERECHO (V) - Santiago/16_gra_op_acreditacion_discapacidad.png'!
# Gráfico guardado en 'carreras\DERECHO (V) - Santiago/22_gra_op_estudios_familiar.png'!
# Gráfico guardado en 'carreras\DERECHO (V) - Santiago/39_gra_op_mayores_habilidades.png'!
# Gráfico guardado en 'carreras\DERECHO (V) - Santiago/40_gra_op_area_aprendizaje_quiere_potenciar.png'!
# Gráfico guardado en 'carreras\DERECHO (V) - Santiago/41_gra_op_apoyo_pedadogico_requiere.png'!
# Gráfico guardado en 'carreras\DERECHO (V) - Santiago/45_gra_op_actividades_de_interes.png'!
# Gráfico guardado en 'carreras\DERECHO (V) - Santiago/46_gra_op_preferencias_estudio.png'!
# Gráfico guardado en 'carreras\DERECHO (V) - Santiago/49_gra_op_preferencia_act_extracurricular.png'!
# Gráfico guardado en 'carreras\MEDICINA - Temuco/16_gra_op_acreditacion_discapacidad.png'!
# Gráfico guardado en 'carreras\MEDICINA - Temuco/22_gra_op_estudios_familiar.png'!
# Gráfico guardado en 'carreras\MEDICINA - Temuco/39_gra_op_mayores_habilidades.png'!
# Gráfico guardado en 'carreras\MEDICINA - Temuco/40_gra_op_area_aprendizaje_quiere_potenciar.png'!
# Gráfico guardado en 'carreras\MEDICINA - Temuco/41_gra_op_apoyo_pedadogico_requiere.png'!
# Gráfico guardado en 'carreras\MEDICINA - Temuco/45_gra_op_actividades_de_interes.png'!
# Gráfico guardado en 'carreras\MEDICINA - Temuco/46_gra_op_preferencias_estudio.png'!
# Gráfico guardado en 'carreras\MEDICINA - Temuco/49_gra_op_preferencia_act_extracurricular.png'!
# Gráfico guardado en 'carreras\CINE - Santiago/16_gra_op_acreditacion_discapacidad.png'!
# Gráfico guardado en 'carreras\CINE - Santiago/22_gra_op_estudios_familiar.png'!
# Gráfico guardado en 'carreras\CINE - Santiago/39_gra_op_mayores_habilidades.png'!
# Gráfico guardado en 'carreras\CINE - Santiago/40_gra_op_area_aprendizaje_quiere_potenciar.png'!
# Gráfico guardado en 'carreras\CINE - Santiago/41_gra_op_apoyo_pedadogico_requiere.png'!
# Gráfico guardado en 'carreras\CINE - Santiago/45_gra_op_actividades_de_interes.png'!
# Gráfico guardado en 'carreras\CINE - Santiago/46_gra_op_preferencias_estudio.png'!
# Gráfico guardado en 'carreras\CINE - Santiago/49_gra_op_preferencia_act_extracurricular.png'!
# Gráfico guardado en 'carreras\DERECHO - Temuco/16_gra_op_acreditacion_discapacidad.png'!
# Gráfico guardado en 'carreras\DERECHO - Temuco/22_gra_op_estudios_familiar.png'!
# Gráfico guardado en 'carreras\DERECHO - Temuco/39_gra_op_mayores_habilidades.png'!
# Gráfico guardado en 'carreras\DERECHO - Temuco/40_gra_op_area_aprendizaje_quiere_potenciar.png'!
# Gráfico guardado en 'carreras\DERECHO - Temuco/41_gra_op_apoyo_pedadogico_requiere.png'!
# Gráfico guardado en 'carreras\DERECHO - Temuco/45_gra_op_actividades_de_interes.png'!
# Gráfico guardado en 'carreras\DERECHO - Temuco/46_gra_op_preferencias_estudio.png'!
# Gráfico guardado en 'carreras\DERECHO - Temuco/49_gra_op_preferencia_act_extracurricular.png'!
# Gráfico guardado en 'carreras\AGRONOMÍA - Santiago/16_gra_op_acreditacion_discapacidad.png'!
# Gráfico guardado en 'carreras\AGRONOMÍA - Santiago/22_gra_op_estudios_familiar.png'!
# Gráfico guardado en 'carreras\AGRONOMÍA - Santiago/39_gra_op_mayores_habilidades.png'!
# Gráfico guardado en 'carreras\AGRONOMÍA - Santiago/40_gra_op_area_aprendizaje_quiere_potenciar.png'!
# Gráfico guardado en 'carreras\AGRONOMÍA - Santiago/41_gra_op_apoyo_pedadogico_requiere.png'!
# Gráfico guardado en 'carreras\AGRONOMÍA - Santiago/45_gra_op_actividades_de_interes.png'!
# Gráfico guardado en 'carreras\AGRONOMÍA - Santiago/46_gra_op_preferencias_estudio.png'!
# Gráfico guardado en 'carreras\AGRONOMÍA - Santiago/49_gra_op_preferencia_act_extracurricular.png'!
# Gráfico guardado en 'carreras\INGENIERÍA EN ADMINISTRACIÓN - Santiago/16_gra_op_acreditacion_discapacidad.png'!
# Gráfico guardado en 'carreras\INGENIERÍA EN ADMINISTRACIÓN - Santiago/22_gra_op_estudios_familiar.png'!
# Gráfico guardado en 'carreras\INGENIERÍA EN ADMINISTRACIÓN - Santiago/39_gra_op_mayores_habilidades.png'!
# Gráfico guardado en 'carreras\INGENIERÍA EN ADMINISTRACIÓN - Santiago/40_gra_op_area_aprendizaje_quiere_potenciar.png'!
# Gráfico guardado en 'carreras\INGENIERÍA EN ADMINISTRACIÓN - Santiago/41_gra_op_apoyo_pedadogico_requiere.png'!
# Gráfico guardado en 'carreras\INGENIERÍA EN ADMINISTRACIÓN - Santiago/45_gra_op_actividades_de_interes.png'!
# Gráfico guardado en 'carreras\INGENIERÍA EN ADMINISTRACIÓN - Santiago/46_gra_op_preferencias_estudio.png'!
# Gráfico guardado en 'carreras\INGENIERÍA EN ADMINISTRACIÓN - Santiago/49_gra_op_preferencia_act_extracurricular.png'!
# Gráfico guardado en 'carreras\INGENIERÍA EN CIBERSEGURIDAD (CONT.-ONL) - Santiago/16_gra_op_acreditacion_discapacidad.png'!
# Gráfico guardado en 'carreras\INGENIERÍA EN CIBERSEGURIDAD (CONT.-ONL) - Santiago/22_gra_op_estudios_familiar.png'!
# Gráfico guardado en 'carreras\INGENIERÍA EN CIBERSEGURIDAD (CONT.-ONL) - Santiago/39_gra_op_mayores_habilidades.png'!
# Gráfico guardado en 'carreras\INGENIERÍA EN CIBERSEGURIDAD (CONT.-ONL) - Santiago/40_gra_op_area_aprendizaje_quiere_potenciar.png'!
# Gráfico guardado en 'carreras\INGENIERÍA EN CIBERSEGURIDAD (CONT.-ONL) - Santiago/41_gra_op_apoyo_pedadogico_requiere.png'!
# Gráfico guardado en 'carreras\INGENIERÍA EN CIBERSEGURIDAD (CONT.-ONL) - Santiago/45_gra_op_actividades_de_interes.png'!
# Gráfico guardado en 'carreras\INGENIERÍA EN CIBERSEGURIDAD (CONT.-ONL) - Santiago/46_gra_op_preferencias_estudio.png'!
# Gráfico guardado en 'carreras\INGENIERÍA EN CIBERSEGURIDAD (CONT.-ONL) - Santiago/49_gra_op_preferencia_act_extracurricular.png'!
# Gráfico guardado en 'carreras\ARQUITECTURA - Temuco/16_gra_op_acreditacion_discapacidad.png'!
# Gráfico guardado en 'carreras\ARQUITECTURA - Temuco/22_gra_op_estudios_familiar.png'!
# Gráfico guardado en 'carreras\ARQUITECTURA - Temuco/39_gra_op_mayores_habilidades.png'!
# Gráfico guardado en 'carreras\ARQUITECTURA - Temuco/40_gra_op_area_aprendizaje_quiere_potenciar.png'!
# Gráfico guardado en 'carreras\ARQUITECTURA - Temuco/41_gra_op_apoyo_pedadogico_requiere.png'!
# Gráfico guardado en 'carreras\ARQUITECTURA - Temuco/45_gra_op_actividades_de_interes.png'!
# Gráfico guardado en 'carreras\ARQUITECTURA - Temuco/46_gra_op_preferencias_estudio.png'!
# Gráfico guardado en 'carreras\ARQUITECTURA - Temuco/49_gra_op_preferencia_act_extracurricular.png'!
# Gráfico guardado en 'carreras\TECNOLOGÍA MÉDICA - Temuco/16_gra_op_acreditacion_discapacidad.png'!
# Gráfico guardado en 'carreras\TECNOLOGÍA MÉDICA - Temuco/22_gra_op_estudios_familiar.png'!
# Gráfico guardado en 'carreras\TECNOLOGÍA MÉDICA - Temuco/39_gra_op_mayores_habilidades.png'!
# Gráfico guardado en 'carreras\TECNOLOGÍA MÉDICA - Temuco/40_gra_op_area_aprendizaje_quiere_potenciar.png'!
# Gráfico guardado en 'carreras\TECNOLOGÍA MÉDICA - Temuco/41_gra_op_apoyo_pedadogico_requiere.png'!
# Gráfico guardado en 'carreras\TECNOLOGÍA MÉDICA - Temuco/45_gra_op_actividades_de_interes.png'!
# Gráfico guardado en 'carreras\TECNOLOGÍA MÉDICA - Temuco/46_gra_op_preferencias_estudio.png'!
# Gráfico guardado en 'carreras\TECNOLOGÍA MÉDICA - Temuco/49_gra_op_preferencia_act_extracurricular.png'!
# Gráfico guardado en 'carreras\FONOAUDIOLOGÍA - Santiago/16_gra_op_acreditacion_discapacidad.png'!
# Gráfico guardado en 'carreras\FONOAUDIOLOGÍA - Santiago/22_gra_op_estudios_familiar.png'!
# Gráfico guardado en 'carreras\FONOAUDIOLOGÍA - Santiago/39_gra_op_mayores_habilidades.png'!
# Gráfico guardado en 'carreras\FONOAUDIOLOGÍA - Santiago/40_gra_op_area_aprendizaje_quiere_potenciar.png'!
# Gráfico guardado en 'carreras\FONOAUDIOLOGÍA - Santiago/41_gra_op_apoyo_pedadogico_requiere.png'!
# Gráfico guardado en 'carreras\FONOAUDIOLOGÍA - Santiago/45_gra_op_actividades_de_interes.png'!
# Gráfico guardado en 'carreras\FONOAUDIOLOGÍA - Santiago/46_gra_op_preferencias_estudio.png'!
# Gráfico guardado en 'carreras\FONOAUDIOLOGÍA - Santiago/49_gra_op_preferencia_act_extracurricular.png'!
# Gráfico guardado en 'carreras\PEDAGOGÍA EN EDUC. FÍSICA, DEP. Y RECR. - Santiago/16_gra_op_acreditacion_discapacidad.png'!
# Gráfico guardado en 'carreras\PEDAGOGÍA EN EDUC. FÍSICA, DEP. Y RECR. - Santiago/22_gra_op_estudios_familiar.png'!
# Gráfico guardado en 'carreras\PEDAGOGÍA EN EDUC. FÍSICA, DEP. Y RECR. - Santiago/39_gra_op_mayores_habilidades.png'!
# Gráfico guardado en 'carreras\PEDAGOGÍA EN EDUC. FÍSICA, DEP. Y RECR. - Santiago/40_gra_op_area_aprendizaje_quiere_potenciar.png'!
# Gráfico guardado en 'carreras\PEDAGOGÍA EN EDUC. FÍSICA, DEP. Y RECR. - Santiago/41_gra_op_apoyo_pedadogico_requiere.png'!
# Gráfico guardado en 'carreras\PEDAGOGÍA EN EDUC. FÍSICA, DEP. Y RECR. - Santiago/45_gra_op_actividades_de_interes.png'!
# Gráfico guardado en 'carreras\PEDAGOGÍA EN EDUC. FÍSICA, DEP. Y RECR. - Santiago/46_gra_op_preferencias_estudio.png'!
# Gráfico guardado en 'carreras\PEDAGOGÍA EN EDUC. FÍSICA, DEP. Y RECR. - Santiago/49_gra_op_preferencia_act_extracurricular.png'!
# Gráfico guardado en 'carreras\PEDAG. EN EDUCACIÓN DIFERENCIAL C/DISC. - Santiago/16_gra_op_acreditacion_discapacidad.png'!
# Gráfico guardado en 'carreras\PEDAG. EN EDUCACIÓN DIFERENCIAL C/DISC. - Santiago/22_gra_op_estudios_familiar.png'!
# Gráfico guardado en 'carreras\PEDAG. EN EDUCACIÓN DIFERENCIAL C/DISC. - Santiago/39_gra_op_mayores_habilidades.png'!
# Gráfico guardado en 'carreras\PEDAG. EN EDUCACIÓN DIFERENCIAL C/DISC. - Santiago/40_gra_op_area_aprendizaje_quiere_potenciar.png'!
# Gráfico guardado en 'carreras\PEDAG. EN EDUCACIÓN DIFERENCIAL C/DISC. - Santiago/41_gra_op_apoyo_pedadogico_requiere.png'!
# Gráfico guardado en 'carreras\PEDAG. EN EDUCACIÓN DIFERENCIAL C/DISC. - Santiago/45_gra_op_actividades_de_interes.png'!
# Gráfico guardado en 'carreras\PEDAG. EN EDUCACIÓN DIFERENCIAL C/DISC. - Santiago/46_gra_op_preferencias_estudio.png'!
# Gráfico guardado en 'carreras\PEDAG. EN EDUCACIÓN DIFERENCIAL C/DISC. - Santiago/49_gra_op_preferencia_act_extracurricular.png'!
# Gráfico guardado en 'carreras\MEDICINA VETERINARIA - Temuco/16_gra_op_acreditacion_discapacidad.png'!
# Gráfico guardado en 'carreras\MEDICINA VETERINARIA - Temuco/22_gra_op_estudios_familiar.png'!
# Gráfico guardado en 'carreras\MEDICINA VETERINARIA - Temuco/39_gra_op_mayores_habilidades.png'!
# Gráfico guardado en 'carreras\MEDICINA VETERINARIA - Temuco/40_gra_op_area_aprendizaje_quiere_potenciar.png'!
# Gráfico guardado en 'carreras\MEDICINA VETERINARIA - Temuco/41_gra_op_apoyo_pedadogico_requiere.png'!
# Gráfico guardado en 'carreras\MEDICINA VETERINARIA - Temuco/45_gra_op_actividades_de_interes.png'!
# Gráfico guardado en 'carreras\MEDICINA VETERINARIA - Temuco/46_gra_op_preferencias_estudio.png'!
# Gráfico guardado en 'carreras\MEDICINA VETERINARIA - Temuco/49_gra_op_preferencia_act_extracurricular.png'!
# Gráfico guardado en 'carreras\INGENIERÍA COMERCIAL (ONLINE) - Santiago/16_gra_op_acreditacion_discapacidad.png'!
# Gráfico guardado en 'carreras\INGENIERÍA COMERCIAL (ONLINE) - Santiago/22_gra_op_estudios_familiar.png'!
# Gráfico guardado en 'carreras\INGENIERÍA COMERCIAL (ONLINE) - Santiago/39_gra_op_mayores_habilidades.png'!
# Gráfico guardado en 'carreras\INGENIERÍA COMERCIAL (ONLINE) - Santiago/40_gra_op_area_aprendizaje_quiere_potenciar.png'!
# Gráfico guardado en 'carreras\INGENIERÍA COMERCIAL (ONLINE) - Santiago/41_gra_op_apoyo_pedadogico_requiere.png'!
# Gráfico guardado en 'carreras\INGENIERÍA COMERCIAL (ONLINE) - Santiago/45_gra_op_actividades_de_interes.png'!
# Gráfico guardado en 'carreras\INGENIERÍA COMERCIAL (ONLINE) - Santiago/46_gra_op_preferencias_estudio.png'!
# Gráfico guardado en 'carreras\INGENIERÍA COMERCIAL (ONLINE) - Santiago/49_gra_op_preferencia_act_extracurricular.png'!
# Gráfico guardado en 'carreras\INGENIERÍA CIVIL ELECTRÓNICA - Santiago/16_gra_op_acreditacion_discapacidad.png'!
# Gráfico guardado en 'carreras\INGENIERÍA CIVIL ELECTRÓNICA - Santiago/22_gra_op_estudios_familiar.png'!
# Gráfico guardado en 'carreras\INGENIERÍA CIVIL ELECTRÓNICA - Santiago/39_gra_op_mayores_habilidades.png'!
# Gráfico guardado en 'carreras\INGENIERÍA CIVIL ELECTRÓNICA - Santiago/40_gra_op_area_aprendizaje_quiere_potenciar.png'!
# Gráfico guardado en 'carreras\INGENIERÍA CIVIL ELECTRÓNICA - Santiago/41_gra_op_apoyo_pedadogico_requiere.png'!
# Gráfico guardado en 'carreras\INGENIERÍA CIVIL ELECTRÓNICA - Santiago/45_gra_op_actividades_de_interes.png'!
# Gráfico guardado en 'carreras\INGENIERÍA CIVIL ELECTRÓNICA - Santiago/46_gra_op_preferencias_estudio.png'!
# Gráfico guardado en 'carreras\INGENIERÍA CIVIL ELECTRÓNICA - Santiago/49_gra_op_preferencia_act_extracurricular.png'!
# Gráfico guardado en 'carreras\ANIMACIÓN DIGITAL (T) - Temuco/16_gra_op_acreditacion_discapacidad.png'!
# Gráfico guardado en 'carreras\ANIMACIÓN DIGITAL (T) - Temuco/22_gra_op_estudios_familiar.png'!
# Gráfico guardado en 'carreras\ANIMACIÓN DIGITAL (T) - Temuco/39_gra_op_mayores_habilidades.png'!
# Gráfico guardado en 'carreras\ANIMACIÓN DIGITAL (T) - Temuco/40_gra_op_area_aprendizaje_quiere_potenciar.png'!
# Gráfico guardado en 'carreras\ANIMACIÓN DIGITAL (T) - Temuco/41_gra_op_apoyo_pedadogico_requiere.png'!
# Gráfico guardado en 'carreras\ANIMACIÓN DIGITAL (T) - Temuco/45_gra_op_actividades_de_interes.png'!
# Gráfico guardado en 'carreras\ANIMACIÓN DIGITAL (T) - Temuco/46_gra_op_preferencias_estudio.png'!
# Gráfico guardado en 'carreras\ANIMACIÓN DIGITAL (T) - Temuco/49_gra_op_preferencia_act_extracurricular.png'!
# Gráfico guardado en 'carreras\ING. EN MEDIO AMBIENTE Y SUSTENTABILIDAD - Santiago/16_gra_op_acreditacion_discapacidad.png'!
# Gráfico guardado en 'carreras\ING. EN MEDIO AMBIENTE Y SUSTENTABILIDAD - Santiago/22_gra_op_estudios_familiar.png'!
# Gráfico guardado en 'carreras\ING. EN MEDIO AMBIENTE Y SUSTENTABILIDAD - Santiago/39_gra_op_mayores_habilidades.png'!
# Gráfico guardado en 'carreras\ING. EN MEDIO AMBIENTE Y SUSTENTABILIDAD - Santiago/40_gra_op_area_aprendizaje_quiere_potenciar.png'!
# Gráfico guardado en 'carreras\ING. EN MEDIO AMBIENTE Y SUSTENTABILIDAD - Santiago/41_gra_op_apoyo_pedadogico_requiere.png'!
# Gráfico guardado en 'carreras\ING. EN MEDIO AMBIENTE Y SUSTENTABILIDAD - Santiago/45_gra_op_actividades_de_interes.png'!
# Gráfico guardado en 'carreras\ING. EN MEDIO AMBIENTE Y SUSTENTABILIDAD - Santiago/46_gra_op_preferencias_estudio.png'!
# Gráfico guardado en 'carreras\ING. EN MEDIO AMBIENTE Y SUSTENTABILIDAD - Santiago/49_gra_op_preferencia_act_extracurricular.png'!
# Gráfico guardado en 'carreras\PEDAGOGÍA EN  EDUCACIÓN PARVULARIA - Santiago/16_gra_op_acreditacion_discapacidad.png'!
# Gráfico guardado en 'carreras\PEDAGOGÍA EN  EDUCACIÓN PARVULARIA - Santiago/22_gra_op_estudios_familiar.png'!
# Gráfico guardado en 'carreras\PEDAGOGÍA EN  EDUCACIÓN PARVULARIA - Santiago/39_gra_op_mayores_habilidades.png'!
# Gráfico guardado en 'carreras\PEDAGOGÍA EN  EDUCACIÓN PARVULARIA - Santiago/40_gra_op_area_aprendizaje_quiere_potenciar.png'!
# Gráfico guardado en 'carreras\PEDAGOGÍA EN  EDUCACIÓN PARVULARIA - Santiago/41_gra_op_apoyo_pedadogico_requiere.png'!
# Gráfico guardado en 'carreras\PEDAGOGÍA EN  EDUCACIÓN PARVULARIA - Santiago/45_gra_op_actividades_de_interes.png'!
# Gráfico guardado en 'carreras\PEDAGOGÍA EN  EDUCACIÓN PARVULARIA - Santiago/46_gra_op_preferencias_estudio.png'!
# Gráfico guardado en 'carreras\PEDAGOGÍA EN  EDUCACIÓN PARVULARIA - Santiago/49_gra_op_preferencia_act_extracurricular.png'!
# Gráfico guardado en 'carreras\TERAPIA OCUPACIONAL - Temuco/16_gra_op_acreditacion_discapacidad.png'!
# Gráfico guardado en 'carreras\TERAPIA OCUPACIONAL - Temuco/22_gra_op_estudios_familiar.png'!
# Gráfico guardado en 'carreras\TERAPIA OCUPACIONAL - Temuco/39_gra_op_mayores_habilidades.png'!
# Gráfico guardado en 'carreras\TERAPIA OCUPACIONAL - Temuco/40_gra_op_area_aprendizaje_quiere_potenciar.png'!
# Gráfico guardado en 'carreras\TERAPIA OCUPACIONAL - Temuco/41_gra_op_apoyo_pedadogico_requiere.png'!
# Gráfico guardado en 'carreras\TERAPIA OCUPACIONAL - Temuco/45_gra_op_actividades_de_interes.png'!
# Gráfico guardado en 'carreras\TERAPIA OCUPACIONAL - Temuco/46_gra_op_preferencias_estudio.png'!
# Gráfico guardado en 'carreras\TERAPIA OCUPACIONAL - Temuco/49_gra_op_preferencia_act_extracurricular.png'!
# Gráfico guardado en 'carreras\CONTADOR PÚBLICO Y AUDITOR (CONT.-ONL) - Santiago/16_gra_op_acreditacion_discapacidad.png'!
# Gráfico guardado en 'carreras\CONTADOR PÚBLICO Y AUDITOR (CONT.-ONL) - Santiago/22_gra_op_estudios_familiar.png'!
# Gráfico guardado en 'carreras\CONTADOR PÚBLICO Y AUDITOR (CONT.-ONL) - Santiago/39_gra_op_mayores_habilidades.png'!
# Gráfico guardado en 'carreras\CONTADOR PÚBLICO Y AUDITOR (CONT.-ONL) - Santiago/40_gra_op_area_aprendizaje_quiere_potenciar.png'!
# Gráfico guardado en 'carreras\CONTADOR PÚBLICO Y AUDITOR (CONT.-ONL) - Santiago/41_gra_op_apoyo_pedadogico_requiere.png'!
# Gráfico guardado en 'carreras\CONTADOR PÚBLICO Y AUDITOR (CONT.-ONL) - Santiago/45_gra_op_actividades_de_interes.png'!
# Gráfico guardado en 'carreras\CONTADOR PÚBLICO Y AUDITOR (CONT.-ONL) - Santiago/46_gra_op_preferencias_estudio.png'!
# Gráfico guardado en 'carreras\CONTADOR PÚBLICO Y AUDITOR (CONT.-ONL) - Santiago/49_gra_op_preferencia_act_extracurricular.png'!
# Gráfico guardado en 'carreras\FONOAUDIOLOGÍA - Temuco/16_gra_op_acreditacion_discapacidad.png'!
# Gráfico guardado en 'carreras\FONOAUDIOLOGÍA - Temuco/22_gra_op_estudios_familiar.png'!
# Gráfico guardado en 'carreras\FONOAUDIOLOGÍA - Temuco/39_gra_op_mayores_habilidades.png'!
# Gráfico guardado en 'carreras\FONOAUDIOLOGÍA - Temuco/40_gra_op_area_aprendizaje_quiere_potenciar.png'!
# Gráfico guardado en 'carreras\FONOAUDIOLOGÍA - Temuco/41_gra_op_apoyo_pedadogico_requiere.png'!
# Gráfico guardado en 'carreras\FONOAUDIOLOGÍA - Temuco/45_gra_op_actividades_de_interes.png'!
# Gráfico guardado en 'carreras\FONOAUDIOLOGÍA - Temuco/46_gra_op_preferencias_estudio.png'!
# Gráfico guardado en 'carreras\FONOAUDIOLOGÍA - Temuco/49_gra_op_preferencia_act_extracurricular.png'!
# Gráfico guardado en 'carreras\ADMINISTRACIÓN PÚBLICA (ONLINE) - Santiago/16_gra_op_acreditacion_discapacidad.png'!
# Gráfico guardado en 'carreras\ADMINISTRACIÓN PÚBLICA (ONLINE) - Santiago/22_gra_op_estudios_familiar.png'!
# Gráfico guardado en 'carreras\ADMINISTRACIÓN PÚBLICA (ONLINE) - Santiago/39_gra_op_mayores_habilidades.png'!
# Gráfico guardado en 'carreras\ADMINISTRACIÓN PÚBLICA (ONLINE) - Santiago/40_gra_op_area_aprendizaje_quiere_potenciar.png'!
# Gráfico guardado en 'carreras\ADMINISTRACIÓN PÚBLICA (ONLINE) - Santiago/41_gra_op_apoyo_pedadogico_requiere.png'!
# Gráfico guardado en 'carreras\ADMINISTRACIÓN PÚBLICA (ONLINE) - Santiago/45_gra_op_actividades_de_interes.png'!
# Gráfico guardado en 'carreras\ADMINISTRACIÓN PÚBLICA (ONLINE) - Santiago/46_gra_op_preferencias_estudio.png'!
# Gráfico guardado en 'carreras\ADMINISTRACIÓN PÚBLICA (ONLINE) - Santiago/49_gra_op_preferencia_act_extracurricular.png'!
# Gráfico guardado en 'carreras\ADMINISTRACIÓN PÚBLICA - Santiago/16_gra_op_acreditacion_discapacidad.png'!
# Gráfico guardado en 'carreras\ADMINISTRACIÓN PÚBLICA - Santiago/22_gra_op_estudios_familiar.png'!
# Gráfico guardado en 'carreras\ADMINISTRACIÓN PÚBLICA - Santiago/39_gra_op_mayores_habilidades.png'!
# Gráfico guardado en 'carreras\ADMINISTRACIÓN PÚBLICA - Santiago/40_gra_op_area_aprendizaje_quiere_potenciar.png'!
# Gráfico guardado en 'carreras\ADMINISTRACIÓN PÚBLICA - Santiago/41_gra_op_apoyo_pedadogico_requiere.png'!
# Gráfico guardado en 'carreras\ADMINISTRACIÓN PÚBLICA - Santiago/45_gra_op_actividades_de_interes.png'!
# Gráfico guardado en 'carreras\ADMINISTRACIÓN PÚBLICA - Santiago/46_gra_op_preferencias_estudio.png'!
# Gráfico guardado en 'carreras\ADMINISTRACIÓN PÚBLICA - Santiago/49_gra_op_preferencia_act_extracurricular.png'!
# Gráfico guardado en 'carreras\INGENIERIA COMERCIAL (CONT_ONL) - Santiago/16_gra_op_acreditacion_discapacidad.png'!
# Gráfico guardado en 'carreras\INGENIERIA COMERCIAL (CONT_ONL) - Santiago/22_gra_op_estudios_familiar.png'!
# Gráfico guardado en 'carreras\INGENIERIA COMERCIAL (CONT_ONL) - Santiago/39_gra_op_mayores_habilidades.png'!
# Gráfico guardado en 'carreras\INGENIERIA COMERCIAL (CONT_ONL) - Santiago/40_gra_op_area_aprendizaje_quiere_potenciar.png'!
# Gráfico guardado en 'carreras\INGENIERIA COMERCIAL (CONT_ONL) - Santiago/41_gra_op_apoyo_pedadogico_requiere.png'!
# Gráfico guardado en 'carreras\INGENIERIA COMERCIAL (CONT_ONL) - Santiago/45_gra_op_actividades_de_interes.png'!
# Gráfico guardado en 'carreras\INGENIERIA COMERCIAL (CONT_ONL) - Santiago/46_gra_op_preferencias_estudio.png'!
# Gráfico guardado en 'carreras\INGENIERIA COMERCIAL (CONT_ONL) - Santiago/49_gra_op_preferencia_act_extracurricular.png'!
# Gráfico guardado en 'carreras\KINESIOLOGÍA - Temuco/16_gra_op_acreditacion_discapacidad.png'!
# Gráfico guardado en 'carreras\KINESIOLOGÍA - Temuco/22_gra_op_estudios_familiar.png'!
# Gráfico guardado en 'carreras\KINESIOLOGÍA - Temuco/39_gra_op_mayores_habilidades.png'!
# Gráfico guardado en 'carreras\KINESIOLOGÍA - Temuco/40_gra_op_area_aprendizaje_quiere_potenciar.png'!
# Gráfico guardado en 'carreras\KINESIOLOGÍA - Temuco/41_gra_op_apoyo_pedadogico_requiere.png'!
# Gráfico guardado en 'carreras\KINESIOLOGÍA - Temuco/45_gra_op_actividades_de_interes.png'!
# Gráfico guardado en 'carreras\KINESIOLOGÍA - Temuco/46_gra_op_preferencias_estudio.png'!
# Gráfico guardado en 'carreras\KINESIOLOGÍA - Temuco/49_gra_op_preferencia_act_extracurricular.png'!
# Gráfico guardado en 'carreras\TEATRO - Santiago/16_gra_op_acreditacion_discapacidad.png'!
# Gráfico guardado en 'carreras\TEATRO - Santiago/22_gra_op_estudios_familiar.png'!
# Gráfico guardado en 'carreras\TEATRO - Santiago/39_gra_op_mayores_habilidades.png'!
# Gráfico guardado en 'carreras\TEATRO - Santiago/40_gra_op_area_aprendizaje_quiere_potenciar.png'!
# Gráfico guardado en 'carreras\TEATRO - Santiago/41_gra_op_apoyo_pedadogico_requiere.png'!
# Gráfico guardado en 'carreras\TEATRO - Santiago/45_gra_op_actividades_de_interes.png'!
# Gráfico guardado en 'carreras\TEATRO - Santiago/46_gra_op_preferencias_estudio.png'!
# Gráfico guardado en 'carreras\TEATRO - Santiago/49_gra_op_preferencia_act_extracurricular.png'!
# Gráfico guardado en 'carreras\BIOTECNOLOGÍA - Santiago/16_gra_op_acreditacion_discapacidad.png'!
# Gráfico guardado en 'carreras\BIOTECNOLOGÍA - Santiago/22_gra_op_estudios_familiar.png'!
# Gráfico guardado en 'carreras\BIOTECNOLOGÍA - Santiago/39_gra_op_mayores_habilidades.png'!
# ...
# Gráfico guardado en 'carreras\SOCIOLOGÍA  (CONTINUIDAD) - Santiago/41_gra_op_apoyo_pedadogico_requiere.png'!
# Gráfico guardado en 'carreras\SOCIOLOGÍA  (CONTINUIDAD) - Santiago/45_gra_op_actividades_de_interes.png'!
# Gráfico guardado en 'carreras\SOCIOLOGÍA  (CONTINUIDAD) - Santiago/46_gra_op_preferencias_estudio.png'!
# Gráfico guardado en 'carreras\SOCIOLOGÍA  (CONTINUIDAD) - Santiago/49_gra_op_preferencia_act_extracurricular.png'!
# Gráfico guardado en 'carreras\INGENIERÍA INDUSTRIAL (V) - Santiago/16_gra_op_acreditacion_discapacidad.png'!
# Gráfico guardado en 'carreras\INGENIERÍA INDUSTRIAL (V) - Santiago/22_gra_op_estudios_familiar.png'!
# Gráfico guardado en 'carreras\INGENIERÍA INDUSTRIAL (V) - Santiago/39_gra_op_mayores_habilidades.png'!
# Gráfico guardado en 'carreras\INGENIERÍA INDUSTRIAL (V) - Santiago/40_gra_op_area_aprendizaje_quiere_potenciar.png'!
# Gráfico guardado en 'carreras\INGENIERÍA INDUSTRIAL (V) - Santiago/41_gra_op_apoyo_pedadogico_requiere.png'!
# Gráfico guardado en 'carreras\INGENIERÍA INDUSTRIAL (V) - Santiago/45_gra_op_actividades_de_interes.png'!
# Gráfico guardado en 'carreras\INGENIERÍA INDUSTRIAL (V) - Santiago/46_gra_op_preferencias_estudio.png'!
# Gráfico guardado en 'carreras\INGENIERÍA INDUSTRIAL (V) - Santiago/49_gra_op_preferencia_act_extracurricular.png'!
# Gráfico guardado en 'carreras\TÉC. UNIV. EN GESTIÓN DE PERSONAS - Santiago/16_gra_op_acreditacion_discapacidad.png'!
# Gráfico guardado en 'carreras\TÉC. UNIV. EN GESTIÓN DE PERSONAS - Santiago/22_gra_op_estudios_familiar.png'!
# Gráfico guardado en 'carreras\TÉC. UNIV. EN GESTIÓN DE PERSONAS - Santiago/39_gra_op_mayores_habilidades.png'!
# Gráfico guardado en 'carreras\TÉC. UNIV. EN GESTIÓN DE PERSONAS - Santiago/40_gra_op_area_aprendizaje_quiere_potenciar.png'!
# Gráfico guardado en 'carreras\TÉC. UNIV. EN GESTIÓN DE PERSONAS - Santiago/41_gra_op_apoyo_pedadogico_requiere.png'!
# Gráfico guardado en 'carreras\TÉC. UNIV. EN GESTIÓN DE PERSONAS - Santiago/45_gra_op_actividades_de_interes.png'!
# Gráfico guardado en 'carreras\TÉC. UNIV. EN GESTIÓN DE PERSONAS - Santiago/46_gra_op_preferencias_estudio.png'!
# Gráfico guardado en 'carreras\TÉC. UNIV. EN GESTIÓN DE PERSONAS - Santiago/49_gra_op_preferencia_act_extracurricular.png'!
# Gráfico guardado en 'carreras\PSICOPEDAGOGÍA - Santiago/16_gra_op_acreditacion_discapacidad.png'!
# Gráfico guardado en 'carreras\PSICOPEDAGOGÍA - Santiago/22_gra_op_estudios_familiar.png'!
# Gráfico guardado en 'carreras\PSICOPEDAGOGÍA - Santiago/39_gra_op_mayores_habilidades.png'!
# Gráfico guardado en 'carreras\PSICOPEDAGOGÍA - Santiago/40_gra_op_area_aprendizaje_quiere_potenciar.png'!
# Gráfico guardado en 'carreras\PSICOPEDAGOGÍA - Santiago/41_gra_op_apoyo_pedadogico_requiere.png'!
# Gráfico guardado en 'carreras\PSICOPEDAGOGÍA - Santiago/45_gra_op_actividades_de_interes.png'!
# Gráfico guardado en 'carreras\PSICOPEDAGOGÍA - Santiago/46_gra_op_preferencias_estudio.png'!
# Gráfico guardado en 'carreras\PSICOPEDAGOGÍA - Santiago/49_gra_op_preferencia_act_extracurricular.png'!
# Gráfico guardado en 'carreras\CONTADOR PÚBLICO AUDITOR (CONTINUIDAD) - Santiago/16_gra_op_acreditacion_discapacidad.png'!
# Gráfico guardado en 'carreras\CONTADOR PÚBLICO AUDITOR (CONTINUIDAD) - Santiago/22_gra_op_estudios_familiar.png'!
# Gráfico guardado en 'carreras\CONTADOR PÚBLICO AUDITOR (CONTINUIDAD) - Santiago/39_gra_op_mayores_habilidades.png'!
# Gráfico guardado en 'carreras\CONTADOR PÚBLICO AUDITOR (CONTINUIDAD) - Santiago/40_gra_op_area_aprendizaje_quiere_potenciar.png'!
# Gráfico guardado en 'carreras\CONTADOR PÚBLICO AUDITOR (CONTINUIDAD) - Santiago/41_gra_op_apoyo_pedadogico_requiere.png'!
# Gráfico guardado en 'carreras\CONTADOR PÚBLICO AUDITOR (CONTINUIDAD) - Santiago/45_gra_op_actividades_de_interes.png'!
# Gráfico guardado en 'carreras\CONTADOR PÚBLICO AUDITOR (CONTINUIDAD) - Santiago/46_gra_op_preferencias_estudio.png'!
# Gráfico guardado en 'carreras\CONTADOR PÚBLICO AUDITOR (CONTINUIDAD) - Santiago/49_gra_op_preferencia_act_extracurricular.png'!
# Gráfico guardado en 'carreras\INTERPRETE MUSICAL SUP.  FLAUTA TRAVERSA - Santiago/16_gra_op_acreditacion_discapacidad.png'!
# Gráfico guardado en 'carreras\INTERPRETE MUSICAL SUP.  FLAUTA TRAVERSA - Santiago/22_gra_op_estudios_familiar.png'!
# Gráfico guardado en 'carreras\INTERPRETE MUSICAL SUP.  FLAUTA TRAVERSA - Santiago/39_gra_op_mayores_habilidades.png'!
# Gráfico guardado en 'carreras\INTERPRETE MUSICAL SUP.  FLAUTA TRAVERSA - Santiago/40_gra_op_area_aprendizaje_quiere_potenciar.png'!
# Gráfico guardado en 'carreras\INTERPRETE MUSICAL SUP.  FLAUTA TRAVERSA - Santiago/41_gra_op_apoyo_pedadogico_requiere.png'!
# Gráfico guardado en 'carreras\INTERPRETE MUSICAL SUP.  FLAUTA TRAVERSA - Santiago/45_gra_op_actividades_de_interes.png'!
# Gráfico guardado en 'carreras\INTERPRETE MUSICAL SUP.  FLAUTA TRAVERSA - Santiago/46_gra_op_preferencias_estudio.png'!
# Gráfico guardado en 'carreras\INTERPRETE MUSICAL SUP.  FLAUTA TRAVERSA - Santiago/49_gra_op_preferencia_act_extracurricular.png'!
# Gráfico guardado en 'carreras\INGENIERÍA EN ADMINISTRACIÓN (SEMIPR.) - Santiago/16_gra_op_acreditacion_discapacidad.png'!
# Gráfico guardado en 'carreras\INGENIERÍA EN ADMINISTRACIÓN (SEMIPR.) - Santiago/22_gra_op_estudios_familiar.png'!
# Gráfico guardado en 'carreras\INGENIERÍA EN ADMINISTRACIÓN (SEMIPR.) - Santiago/39_gra_op_mayores_habilidades.png'!
# Gráfico guardado en 'carreras\INGENIERÍA EN ADMINISTRACIÓN (SEMIPR.) - Santiago/40_gra_op_area_aprendizaje_quiere_potenciar.png'!
# Gráfico guardado en 'carreras\INGENIERÍA EN ADMINISTRACIÓN (SEMIPR.) - Santiago/41_gra_op_apoyo_pedadogico_requiere.png'!
# Gráfico guardado en 'carreras\INGENIERÍA EN ADMINISTRACIÓN (SEMIPR.) - Santiago/45_gra_op_actividades_de_interes.png'!
# Gráfico guardado en 'carreras\INGENIERÍA EN ADMINISTRACIÓN (SEMIPR.) - Santiago/46_gra_op_preferencias_estudio.png'!
# Gráfico guardado en 'carreras\INGENIERÍA EN ADMINISTRACIÓN (SEMIPR.) - Santiago/49_gra_op_preferencia_act_extracurricular.png'!
# Gráfico guardado en 'carreras\INTERPRETACIÓN MUSICAL BÁSICO (6) C/M - Santiago/16_gra_op_acreditacion_discapacidad.png'!
# Gráfico guardado en 'carreras\INTERPRETACIÓN MUSICAL BÁSICO (6) C/M - Santiago/22_gra_op_estudios_familiar.png'!
# Gráfico guardado en 'carreras\INTERPRETACIÓN MUSICAL BÁSICO (6) C/M - Santiago/39_gra_op_mayores_habilidades.png'!
# Gráfico guardado en 'carreras\INTERPRETACIÓN MUSICAL BÁSICO (6) C/M - Santiago/40_gra_op_area_aprendizaje_quiere_potenciar.png'!
# Gráfico guardado en 'carreras\INTERPRETACIÓN MUSICAL BÁSICO (6) C/M - Santiago/41_gra_op_apoyo_pedadogico_requiere.png'!
# Gráfico guardado en 'carreras\INTERPRETACIÓN MUSICAL BÁSICO (6) C/M - Santiago/45_gra_op_actividades_de_interes.png'!
# Gráfico guardado en 'carreras\INTERPRETACIÓN MUSICAL BÁSICO (6) C/M - Santiago/46_gra_op_preferencias_estudio.png'!
# Gráfico guardado en 'carreras\INTERPRETACIÓN MUSICAL BÁSICO (6) C/M - Santiago/49_gra_op_preferencia_act_extracurricular.png'!
# Gráfico guardado en 'carreras\COMPOSICION MUSICAL SUPERIOR - Santiago/16_gra_op_acreditacion_discapacidad.png'!
# Gráfico guardado en 'carreras\COMPOSICION MUSICAL SUPERIOR - Santiago/22_gra_op_estudios_familiar.png'!
# Gráfico guardado en 'carreras\COMPOSICION MUSICAL SUPERIOR - Santiago/39_gra_op_mayores_habilidades.png'!
# Gráfico guardado en 'carreras\COMPOSICION MUSICAL SUPERIOR - Santiago/40_gra_op_area_aprendizaje_quiere_potenciar.png'!
# Gráfico guardado en 'carreras\COMPOSICION MUSICAL SUPERIOR - Santiago/41_gra_op_apoyo_pedadogico_requiere.png'!
# Gráfico guardado en 'carreras\COMPOSICION MUSICAL SUPERIOR - Santiago/45_gra_op_actividades_de_interes.png'!
# Gráfico guardado en 'carreras\COMPOSICION MUSICAL SUPERIOR - Santiago/46_gra_op_preferencias_estudio.png'!
# Gráfico guardado en 'carreras\COMPOSICION MUSICAL SUPERIOR - Santiago/49_gra_op_preferencia_act_extracurricular.png'!
# Gráfico guardado en 'carreras\SOCIOLOGÍA (blended) - Santiago/16_gra_op_acreditacion_discapacidad.png'!
# Gráfico guardado en 'carreras\SOCIOLOGÍA (blended) - Santiago/22_gra_op_estudios_familiar.png'!
# Gráfico guardado en 'carreras\SOCIOLOGÍA (blended) - Santiago/39_gra_op_mayores_habilidades.png'!
# Gráfico guardado en 'carreras\SOCIOLOGÍA (blended) - Santiago/40_gra_op_area_aprendizaje_quiere_potenciar.png'!
# Gráfico guardado en 'carreras\SOCIOLOGÍA (blended) - Santiago/41_gra_op_apoyo_pedadogico_requiere.png'!
# Gráfico guardado en 'carreras\SOCIOLOGÍA (blended) - Santiago/45_gra_op_actividades_de_interes.png'!
# Gráfico guardado en 'carreras\SOCIOLOGÍA (blended) - Santiago/46_gra_op_preferencias_estudio.png'!
# Gráfico guardado en 'carreras\SOCIOLOGÍA (blended) - Santiago/49_gra_op_preferencia_act_extracurricular.png'!
# Gráfico guardado en 'carreras\TÉC. UNIV. EN TECNOLOGÍAS DE LA INFORM. - Santiago/16_gra_op_acreditacion_discapacidad.png'!
# Gráfico guardado en 'carreras\TÉC. UNIV. EN TECNOLOGÍAS DE LA INFORM. - Santiago/22_gra_op_estudios_familiar.png'!
# Gráfico guardado en 'carreras\TÉC. UNIV. EN TECNOLOGÍAS DE LA INFORM. - Santiago/39_gra_op_mayores_habilidades.png'!
# Gráfico guardado en 'carreras\TÉC. UNIV. EN TECNOLOGÍAS DE LA INFORM. - Santiago/40_gra_op_area_aprendizaje_quiere_potenciar.png'!
# Gráfico guardado en 'carreras\TÉC. UNIV. EN TECNOLOGÍAS DE LA INFORM. - Santiago/41_gra_op_apoyo_pedadogico_requiere.png'!
# Gráfico guardado en 'carreras\TÉC. UNIV. EN TECNOLOGÍAS DE LA INFORM. - Santiago/45_gra_op_actividades_de_interes.png'!
# Gráfico guardado en 'carreras\TÉC. UNIV. EN TECNOLOGÍAS DE LA INFORM. - Santiago/46_gra_op_preferencias_estudio.png'!
# Gráfico guardado en 'carreras\TÉC. UNIV. EN TECNOLOGÍAS DE LA INFORM. - Santiago/49_gra_op_preferencia_act_extracurricular.png'!
# Gráfico guardado en 'carreras\INTERPRETACIÓN MUSICAL SUPERIOR C/M. - Santiago/16_gra_op_acreditacion_discapacidad.png'!
# Gráfico guardado en 'carreras\INTERPRETACIÓN MUSICAL SUPERIOR C/M. - Santiago/22_gra_op_estudios_familiar.png'!
# Gráfico guardado en 'carreras\INTERPRETACIÓN MUSICAL SUPERIOR C/M. - Santiago/39_gra_op_mayores_habilidades.png'!
# Gráfico guardado en 'carreras\INTERPRETACIÓN MUSICAL SUPERIOR C/M. - Santiago/40_gra_op_area_aprendizaje_quiere_potenciar.png'!
# Gráfico guardado en 'carreras\INTERPRETACIÓN MUSICAL SUPERIOR C/M. - Santiago/41_gra_op_apoyo_pedadogico_requiere.png'!
# Gráfico guardado en 'carreras\INTERPRETACIÓN MUSICAL SUPERIOR C/M. - Santiago/45_gra_op_actividades_de_interes.png'!
# Gráfico guardado en 'carreras\INTERPRETACIÓN MUSICAL SUPERIOR C/M. - Santiago/46_gra_op_preferencias_estudio.png'!
# Gráfico guardado en 'carreras\INTERPRETACIÓN MUSICAL SUPERIOR C/M. - Santiago/49_gra_op_preferencia_act_extracurricular.png'!
# Gráfico guardado en 'carreras\INTERP. MUSICAL SUPERIOR EN CORNO - Santiago/16_gra_op_acreditacion_discapacidad.png'!
# Gráfico guardado en 'carreras\INTERP. MUSICAL SUPERIOR EN CORNO - Santiago/22_gra_op_estudios_familiar.png'!
# Gráfico guardado en 'carreras\INTERP. MUSICAL SUPERIOR EN CORNO - Santiago/39_gra_op_mayores_habilidades.png'!
# Gráfico guardado en 'carreras\INTERP. MUSICAL SUPERIOR EN CORNO - Santiago/40_gra_op_area_aprendizaje_quiere_potenciar.png'!
# Gráfico guardado en 'carreras\INTERP. MUSICAL SUPERIOR EN CORNO - Santiago/41_gra_op_apoyo_pedadogico_requiere.png'!
# Gráfico guardado en 'carreras\INTERP. MUSICAL SUPERIOR EN CORNO - Santiago/45_gra_op_actividades_de_interes.png'!
# Gráfico guardado en 'carreras\INTERP. MUSICAL SUPERIOR EN CORNO - Santiago/46_gra_op_preferencias_estudio.png'!
# Gráfico guardado en 'carreras\INTERP. MUSICAL SUPERIOR EN CORNO - Santiago/49_gra_op_preferencia_act_extracurricular.png'!
# Gráfico guardado en 'carreras\CONSTRUCCIÓN  CIVIL - Santiago/16_gra_op_acreditacion_discapacidad.png'!
# Gráfico guardado en 'carreras\CONSTRUCCIÓN  CIVIL - Santiago/22_gra_op_estudios_familiar.png'!
# Gráfico guardado en 'carreras\CONSTRUCCIÓN  CIVIL - Santiago/39_gra_op_mayores_habilidades.png'!
# Gráfico guardado en 'carreras\CONSTRUCCIÓN  CIVIL - Santiago/40_gra_op_area_aprendizaje_quiere_potenciar.png'!
# Gráfico guardado en 'carreras\CONSTRUCCIÓN  CIVIL - Santiago/41_gra_op_apoyo_pedadogico_requiere.png'!
# Gráfico guardado en 'carreras\CONSTRUCCIÓN  CIVIL - Santiago/45_gra_op_actividades_de_interes.png'!
# Gráfico guardado en 'carreras\CONSTRUCCIÓN  CIVIL - Santiago/46_gra_op_preferencias_estudio.png'!
# Gráfico guardado en 'carreras\CONSTRUCCIÓN  CIVIL - Santiago/49_gra_op_preferencia_act_extracurricular.png'!
# Gráfico guardado en 'carreras\INTERPRETE MUSICAL SUPERIOR EN VIOLÍN - Santiago/16_gra_op_acreditacion_discapacidad.png'!
# Gráfico guardado en 'carreras\INTERPRETE MUSICAL SUPERIOR EN VIOLÍN - Santiago/22_gra_op_estudios_familiar.png'!
# Gráfico guardado en 'carreras\INTERPRETE MUSICAL SUPERIOR EN VIOLÍN - Santiago/39_gra_op_mayores_habilidades.png'!
# Gráfico guardado en 'carreras\INTERPRETE MUSICAL SUPERIOR EN VIOLÍN - Santiago/40_gra_op_area_aprendizaje_quiere_potenciar.png'!
# Gráfico guardado en 'carreras\INTERPRETE MUSICAL SUPERIOR EN VIOLÍN - Santiago/41_gra_op_apoyo_pedadogico_requiere.png'!
# Gráfico guardado en 'carreras\INTERPRETE MUSICAL SUPERIOR EN VIOLÍN - Santiago/45_gra_op_actividades_de_interes.png'!
# Gráfico guardado en 'carreras\INTERPRETE MUSICAL SUPERIOR EN VIOLÍN - Santiago/46_gra_op_preferencias_estudio.png'!
# Gráfico guardado en 'carreras\INTERPRETE MUSICAL SUPERIOR EN VIOLÍN - Santiago/49_gra_op_preferencia_act_extracurricular.png'!
# Gráfico guardado en 'carreras\INTERPRETE MUSICAL SUPERIOR VIOLONCELLO - Santiago/16_gra_op_acreditacion_discapacidad.png'!
# Gráfico guardado en 'carreras\INTERPRETE MUSICAL SUPERIOR VIOLONCELLO - Santiago/22_gra_op_estudios_familiar.png'!
# Gráfico guardado en 'carreras\INTERPRETE MUSICAL SUPERIOR VIOLONCELLO - Santiago/39_gra_op_mayores_habilidades.png'!
# Gráfico guardado en 'carreras\INTERPRETE MUSICAL SUPERIOR VIOLONCELLO - Santiago/40_gra_op_area_aprendizaje_quiere_potenciar.png'!
# Gráfico guardado en 'carreras\INTERPRETE MUSICAL SUPERIOR VIOLONCELLO - Santiago/41_gra_op_apoyo_pedadogico_requiere.png'!
# Gráfico guardado en 'carreras\INTERPRETE MUSICAL SUPERIOR VIOLONCELLO - Santiago/45_gra_op_actividades_de_interes.png'!
# Gráfico guardado en 'carreras\INTERPRETE MUSICAL SUPERIOR VIOLONCELLO - Santiago/46_gra_op_preferencias_estudio.png'!
# Gráfico guardado en 'carreras\INTERPRETE MUSICAL SUPERIOR VIOLONCELLO - Santiago/49_gra_op_preferencia_act_extracurricular.png'!
# Gráfico guardado en 'carreras\INTERPRETACIÓN MUSICAL BÁSICO (8) C/M - Santiago/16_gra_op_acreditacion_discapacidad.png'!
# Gráfico guardado en 'carreras\INTERPRETACIÓN MUSICAL BÁSICO (8) C/M - Santiago/22_gra_op_estudios_familiar.png'!
# Gráfico guardado en 'carreras\INTERPRETACIÓN MUSICAL BÁSICO (8) C/M - Santiago/39_gra_op_mayores_habilidades.png'!
# Gráfico guardado en 'carreras\INTERPRETACIÓN MUSICAL BÁSICO (8) C/M - Santiago/40_gra_op_area_aprendizaje_quiere_potenciar.png'!
# Gráfico guardado en 'carreras\INTERPRETACIÓN MUSICAL BÁSICO (8) C/M - Santiago/41_gra_op_apoyo_pedadogico_requiere.png'!
# Gráfico guardado en 'carreras\INTERPRETACIÓN MUSICAL BÁSICO (8) C/M - Santiago/45_gra_op_actividades_de_interes.png'!
# Gráfico guardado en 'carreras\INTERPRETACIÓN MUSICAL BÁSICO (8) C/M - Santiago/46_gra_op_preferencias_estudio.png'!
# Gráfico guardado en 'carreras\INTERPRETACIÓN MUSICAL BÁSICO (8) C/M - Santiago/49_gra_op_preferencia_act_extracurricular.png'!
# Gráfico guardado en 'carreras\SOCIOLOGÍA (V) - Santiago/16_gra_op_acreditacion_discapacidad.png'!
# Gráfico guardado en 'carreras\SOCIOLOGÍA (V) - Santiago/22_gra_op_estudios_familiar.png'!
# Gráfico guardado en 'carreras\SOCIOLOGÍA (V) - Santiago/39_gra_op_mayores_habilidades.png'!
# Gráfico guardado en 'carreras\SOCIOLOGÍA (V) - Santiago/40_gra_op_area_aprendizaje_quiere_potenciar.png'!
# Gráfico guardado en 'carreras\SOCIOLOGÍA (V) - Santiago/41_gra_op_apoyo_pedadogico_requiere.png'!
# Gráfico guardado en 'carreras\SOCIOLOGÍA (V) - Santiago/45_gra_op_actividades_de_interes.png'!
# Gráfico guardado en 'carreras\SOCIOLOGÍA (V) - Santiago/46_gra_op_preferencias_estudio.png'!
# Gráfico guardado en 'carreras\SOCIOLOGÍA (V) - Santiago/49_gra_op_preferencia_act_extracurricular.png'!
